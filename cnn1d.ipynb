# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 기본 directory 설정
import os
os.chdir('/content/drive/MyDrive/Monthly_Workout')

# %%
# 모듈 불러오기
import random
import pandas as pd
import numpy as np
from tqdm import tqdm
from math import pi

# %%
# 데이터 불러오기
path = './' # 기본 directory 경로에 추가 할 경로

train = pd.read_csv(path + 'train_features.csv')
train_labels = pd.read_csv(path + 'train_labels.csv')
test = pd.read_csv(path + 'test_features.csv')
submission = pd.read_csv(path + 'sample_submission.csv')

# %%
act_list=train.iloc[:,2:].columns
acc_list=['acc_x','acc_y','acc_z']
gy_list=['gy_x','gy_y','gy_z']
act_list
# Out:
# Index(['acc_x', 'acc_y', 'acc_z', 'gy_x', 'gy_y', 'gy_z'], dtype='object')

# %%
# acc 데이터와 gy 데이터로 분할
def sensor_split(data):
    X_acc = []
    X_gy = []

    for i in tqdm(data['id'].unique()):
        temp_acc = np.array(data[data['id'] == i].loc[:,acc_list])
        temp_gy = np.array(data[data['id'] == i].loc[:,gy_list])
        X_acc.append(temp_acc)
        X_gy.append(temp_gy)
      
    X_acc = np.array(X_acc).reshape(-1,600,3)
    X_gy = np.array(X_gy).reshape(-1,600,3)

    return X_acc, X_gy

# %%
# 데이터 증강

def permutation(X, nPerm=4, minSegLength=10):
    X_new = np.zeros(X.shape)
    idx = np.random.permutation(nPerm)
    bWhile = True
    while bWhile == True:
        segs = np.zeros(nPerm+1, dtype=int)
        segs[1:-1] = np.sort(np.random.randint(minSegLength, X.shape[0]-minSegLength, nPerm-1))
        segs[-1] = X.shape[0]
        if np.min(segs[1:]-segs[0:-1]) > minSegLength:
            bWhile = False
    pp = 0
    for ii in range(nPerm):
        x_temp = X[segs[idx[ii]]:segs[idx[ii]+1],:]
        X_new[pp:pp+len(x_temp),:] = x_temp
        pp += len(x_temp)
    return (X_new)

def aug(data, uid, shift):
    shift_data = np.roll(data[uid], shift, axis=0)
    return shift_data
def rolling(data):
    aug_data=[]
    for i in range(data.shape[0]):
        temp=list((aug(data,i,int(random.random()*600))))
        aug_data.append(temp)
    return np.array(aug_data)

# %%
# 데이터 증강 (반복하고 싶은 만큼 조정)
def start_augmentation(train, train_labels):
    # acc, gy 데이터 분할
    X_train_mod=pd.merge(train,train_labels,how='left',on='id')
    X_train_acc, X_train_gy= sensor_split(X_train_mod)

    # 증강시키고 추가할 임시 데이터 복사본
    X_train_acc_temp = X_train_acc.copy()
    X_train_gy_temp = X_train_gy.copy()

    # label 데이터 변환
    y_train = train_labels['label']
    y_train_total = np.append(y_train, y_train, axis=0)

    rep = 4 # 5이상의 경우 reshape 과정에서 reset될 가능성 높음
    for i in range(rep):
        X_train_acc_roll = rolling(X_train_acc_temp)
        X_train_acc_rp = permutation(rolling(X_train_acc_temp)) # rolling + permutation

        X_train_gy_roll = rolling(X_train_gy_temp)
        X_train_gy_rp = permutation(rolling(X_train_gy_temp)) # rolling + permutation

        # 증강시킨 데이터 원래 데이터에 추가
        X_train_acc = np.append(X_train_acc, X_train_acc_roll, axis=0)
        X_train_acc = np.append(X_train_acc, X_train_acc_rp, axis=0)

        X_train_gy = np.append(X_train_gy, X_train_gy_roll, axis=0)
        X_train_gy = np.append(X_train_gy, X_train_gy_rp, axis=0)

        y_train_total = np.append(y_train_total, y_train, axis=0)
        if i != (rep-1): # 마지막 한 번 제외
            y_train_total = np.append(y_train_total, y_train, axis=0)

    return X_train_acc, X_train_gy, y_train_total

# %%
X_train_acc, X_train_gy, y_train_total = start_augmentation(train, train_labels)

X_train_acc.shape, X_train_gy.shape, y_train_total.shape
# Out:
# 100%|██████████| 3125/3125 [00:16<00:00, 195.25it/s]
# ((40625, 600, 3), (40625, 600, 3), (40625,))

# %%
# np array 형태를 dataframe 으로 변환
def np_to_df(X_train_acc, X_train_gy):
    acc = [e for sl in X_train_acc for e in sl]
    gy = [e for sl in X_train_gy for e in sl]

    df_report_acc = np.stack(acc, axis = 0)
    df_report_gy = np.stack(gy, axis = 0)

    df_acc = pd.DataFrame(df_report_acc, columns= ['acc_x', 'acc_y', 'acc_z']) 
    df_gy = pd.DataFrame(df_report_gy, columns= ['gy_x', 'gy_y', 'gy_z']) 

    # acc, gy 데이터프레임 병합
    df_aug_result = pd.concat([df_acc, df_gy], axis = 1)
    
    return df_aug_result

# %%
train = np_to_df(X_train_acc, X_train_gy)
train
# Out:
#              acc_x     acc_y     acc_z      gy_x       gy_y       gy_z
# 0         1.206087 -0.179371 -0.148447 -0.591608 -30.549010 -31.676112
# 1         1.287696 -0.198974 -0.182444  0.303100 -39.139103 -24.927216
# 2         1.304609 -0.195114 -0.253382 -3.617278 -44.122565 -25.019629
# 3         1.293095 -0.230366 -0.215210  2.712986 -53.597843 -27.454013
# 4         1.300887 -0.187757 -0.222523  4.286707 -57.906561 -27.961234
# ...            ...       ...       ...       ...        ...        ...
# 24374995 -0.797165 -0.407344 -0.111095 -4.135029 -96.765379 -83.078840
# 24374996 -0.931955 -0.544604  0.065159 -6.710098 -95.525230 -83.847600
# 24374997 -0.959418 -0.703134  0.274186 -7.480734 -94.221777 -84.194322
# 24374998 -0.977184 -0.704531  0.219923 -7.768990 -93.280180 -84.567775
# 24374999 -0.995484 -0.538634  0.135718 -8.564871 -92.980745 -85.093899
#
# [24375000 rows x 6 columns]

# %%
# 가속도
train['acc_t'] = (train['acc_x'] ** 2) + (train['acc_y'] ** 2) + (train['acc_z'] ** 2) ** (1/3)
test['acc_t'] = (test['acc_x'] ** 2) + (test['acc_y'] ** 2) + (test['acc_z'] ** 2) ** (1/3)

train['gy_t'] = (train['gy_x'] ** 2) + (train['gy_y'] ** 2) + (train['gy_z'] ** 2) ** (1/3)
test['gy_t'] = (test['gy_x'] ** 2) + (test['gy_y'] ** 2) + (test['gy_z'] ** 2) ** (1/3)

# Signal 극대화 (peak 캐치 유용)
train['acc_mag'] = (train['acc_x'] ** 2) + (train['acc_y'] ** 2) + (train['acc_z'] ** 2)
test['acc_mag'] = (test['acc_x'] ** 2) + (test['acc_y'] ** 2) + (test['acc_z'] ** 2)

train['gy_mag'] = (train['gy_x'] ** 2) + (train['gy_y'] ** 2) + (train['gy_z'] ** 2)
test['gy_mag'] = (test['gy_x'] ** 2) + (test['gy_y'] ** 2) + (test['gy_z'] ** 2)

# %%
# vector
train['acc_vec'] = np.sqrt((train['acc_x'] ** 2) +(train['acc_y'] ** 2)+(train['acc_z'] ** 2))
test['acc_vec'] = np.sqrt((test['acc_x'] ** 2) +(test['acc_y'] ** 2)+(test['acc_z'] ** 2))

train['gy_vec'] = np.sqrt((train['gy_x'] ** 2) +(train['gy_y'] ** 2)+(train['gy_z'] ** 2))
test['gy_vec'] = np.sqrt((test['gy_x'] ** 2) +(test['gy_y'] ** 2)+(test['gy_z'] ** 2))

# 자이로스코프 무게중심
train['gy_gravity'] = (train['gy_x']+train['gy_y']+train['gy_z'])/3
test['gy_gravity'] = (test['gy_x']+test['gy_y']+test['gy_z'])/3

# %%
# roll & pitch
train['roll'] = np.arctan(train['acc_y']/np.sqrt(train['acc_x'] ** 2 + train['acc_z'] ** 2))
test['roll'] = np.arctan(test['acc_y']/np.sqrt(test['acc_x'] ** 2 + test['acc_z'] ** 2))

train['pitch'] = np.arctan(train['acc_x']/np.sqrt(train['acc_y'] ** 2 + train['acc_z'] ** 2))
test['pitch'] = np.arctan(test['acc_x']/np.sqrt(test['acc_y'] ** 2 + test['acc_z'] ** 2))

train['math_roll'] = np.arctan(- train['acc_x']/np.sqrt(train['acc_y'] ** 2 + train['acc_z'] ** 2)) * (180/pi)
test['math_roll'] = np.arctan(- test['acc_x']/np.sqrt(test['acc_y'] ** 2 + test['acc_z'] ** 2)) * (180/pi)

train['math_pitch'] = np.arctan(train['acc_y']/np.sqrt(train['acc_x'] ** 2 + train['acc_z'] ** 2)) * (180/pi)
test['math_pitch'] = np.arctan(test['acc_y']/np.sqrt(test['acc_x'] ** 2 + test['acc_z'] ** 2)) * (180/pi)

train['gy_roll'] = np.arctan(train['gy_y']/np.sqrt(train['gy_x'] ** 2 + train['gy_z'] ** 2))
test['gy_roll'] = np.arctan(test['gy_y']/np.sqrt(test['gy_x'] ** 2 + test['gy_z'] ** 2))

train['gy_pitch'] = np.arctan(train['gy_x']/np.sqrt(train['gy_y'] ** 2 + train['gy_z'] ** 2))
test['gy_pitch'] = np.arctan(test['gy_x']/np.sqrt(test['gy_y'] ** 2 + test['gy_z'] ** 2))

train['gy_math_roll'] = np.arctan(- train['gy_x']/np.sqrt(train['gy_y'] ** 2 + train['gy_z'] ** 2)) * (180/pi)
test['gy_math_roll'] = np.arctan(- test['gy_x']/np.sqrt(test['gy_y'] ** 2 + test['gy_z'] ** 2)) * (180/pi)

train['gy_math_pitch'] = np.arctan(train['gy_y']/np.sqrt(train['gy_x'] ** 2 + train['gy_z'] ** 2)) * (180/pi)
test['gy_math_pitch'] = np.arctan(test['gy_y']/np.sqrt(test['gy_x'] ** 2 + test['gy_z'] ** 2)) * (180/pi)

print(train.shape)
train
# Out:
# (24375000, 21)
#              acc_x     acc_y     acc_z  ...  gy_pitch  gy_math_roll  gy_math_pitch
# 0         1.206087 -0.179371 -0.148447  ... -0.013443      0.770209     -43.957305
# 1         1.287696 -0.198974 -0.182444  ...  0.006532     -0.374246     -57.505519
# 2         1.304609 -0.195114 -0.253382  ... -0.071194      4.079137     -60.189701
# 3         1.293095 -0.230366 -0.215210  ...  0.045021     -2.579501     -62.764338
# 4         1.300887 -0.187757 -0.222523  ...  0.066565     -3.813876     -63.964038
# ...            ...       ...       ...  ...       ...           ...            ...
# 24374995 -0.797165 -0.407344 -0.111095  ... -0.032411      1.857007     -49.316910
# 24374996 -0.931955 -0.544604  0.065159  ... -0.052743      3.021958     -48.634155
# 24374997 -0.959418 -0.703134  0.274186  ... -0.059134      3.388101     -48.104839
# 24374998 -0.977184 -0.704531  0.219923  ... -0.061625      3.530877     -47.684732
# 24374999 -0.995484 -0.538634  0.135718  ... -0.067849      3.887440     -47.392098
#
# [24375000 rows x 21 columns]

# %%
# # Scaling 하기 전 Outlier 제거 작업
# def get_outlier(df, column, weight=1.5):
#   # target 값과 상관관계가 높은 열을 우선적으로 진행
#   quantile_25 = np.percentile(df[column].values, 25)
#   quantile_75 = np.percentile(df[column].values, 75)

#   IQR = quantile_75 - quantile_25
#   IQR_weight = IQR*weight
  
#   lowest = quantile_25 - IQR_weight
#   highest = quantile_75 + IQR_weight
  
#   outlier_idx = df[column][ (df[column] < lowest) | (df[column] > highest) ].index
#   return outlier_idx

# # 함수 사용해서 이상치 값 삭제
# name_features = train.columns.values.tolist()
# for i in name_features:
#     outlier_idx = get_outlier(df=train, column=i)
#     train.drop(outlier_idx, axis=0, inplace=True)
# train.shape

# %%
# Scaling 원하는 걸로 사용
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer

scaler = RobustScaler()
train = scaler.fit_transform(train)
test.drop(['id', 'time'], axis=1, inplace=True)
test = scaler.transform(test)
train
# Out:
# array([[ 1.93489817,  0.03657354, -0.31330862, ...,  0.05924213,
#         -0.05924213, -0.71658616],
#        [ 2.01969699,  0.00673528, -0.37289479, ...,  0.07768724,
#         -0.07768724, -0.94204715],
#        [ 2.0372705 ,  0.01260973, -0.49722803, ...,  0.0059123 ,
#         -0.0059123 , -0.98671563],
#        ...,
#        [-0.31522429, -0.76068882,  0.42743318, ...,  0.01704969,
#         -0.01704969, -0.78560684],
#        [-0.33368375, -0.76281458,  0.33232805, ...,  0.01474858,
#         -0.01474858, -0.77861568],
#        [-0.35269944, -0.51028997,  0.18474317, ...,  0.00900187,
#         -0.00900187, -0.77374585]])

# %%
import tensorflow as tf 
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Input
from keras.layers import TimeDistributed
from keras.layers import Activation, GlobalAveragePooling1D
from keras.layers import Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from keras.models import load_model
from keras.layers.merge import concatenate

# %%
len_features = train.shape[1] # feature 갯수
X = train.reshape(-1, 600, len_features)
X.shape
# Out:
# (40625, 600, 21)

# %%
y = to_categorical(y_train_total) 
y.shape
# Out:
# (40625, 61)

# %%
epochs, batch_size = 50, 64 # Ram 24GB 기준 256 이상 reset될 가능성 높음

# %%
test_X = test.reshape(-1, 600, len_features)
test_X.shape
# Out:
# (782, 600, 21)

# %%
class Models:
    # 각종 size 다양하게 custom해서 stacking 쌓아 올리기
    def define_model_0():
        model = Sequential()
        model.add(Conv1D(filters=32, kernel_size=9, padding='same', input_shape=(600, len_features)))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(Conv1D(filters=32, kernel_size=6, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.4))

        model.add(Conv1D(filters=32, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.5))

        model.add(GlobalAveragePooling1D())
        model.add(Dense(61, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_1():
        model = Sequential()
        model.add(Conv1D(filters=64, kernel_size=3, padding='same', input_shape=(600, len_features)))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(Conv1D(filters=64, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(Conv1D(filters=64, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(GlobalAveragePooling1D())
        model.add(Dense(61, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_2():
        model = Sequential()
        model.add(Conv1D(filters=32, kernel_size=3, padding='same', input_shape=(600, len_features)))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.5))

        model.add(Conv1D(filters=64, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.5))

        model.add(Conv1D(filters=64, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.5))

        model.add(GlobalAveragePooling1D())
        model.add(Dense(61, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_3():
        model = Sequential()
        model.add(Conv1D(filters=64, kernel_size=6, padding='same', input_shape=(600, len_features)))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(Conv1D(filters=64, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(Conv1D(filters=128, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(GlobalAveragePooling1D())
        model.add(Dense(61, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_4():
        input_layer = Input(600, len_features)

        model = Sequential()
        model.add(Conv1D(filters=64, kernel_size=6, padding='same', input_shape=(600, len_features)))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.5))

        model.add(Conv1D(filters=128, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.5))

        model.add(Conv1D(filters=128, kernel_size=3, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation(activation='relu'))
        model.add(Dropout(0.3))

        model.add(GlobalAveragePooling1D())
        model.add(Dense(61, activation='softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

# %%
# 위의 모델들 학습하면서 stacking
for i in range(5):
    model = getattr(Models, f'define_model_{i}')()
    checkpoint_path = "checkpoint/cp.ckpt"
    cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='loss', 
                                verbose=1, save_weights_only=True, 
                                save_best_only=True, mode='min')
    early_stopping = EarlyStopping(monitor='loss', patience=20, mode='min')
    model.fit(X, y, epochs=epochs, batch_size=batch_size, 
            validation_split=0.2, callbacks=[early_stopping, cp_callback])
    model.save(f'models/model_{i}.h5')
    tf.keras.backend.clear_session()
# Out:
# Epoch 1/100
# 508/508 [==============================] - 21s 10ms/step - loss: 2.6695 - accuracy: 0.4770 - val_loss: 2.5378 - val_accuracy: 0.4932
#
# Epoch 00001: loss improved from inf to 2.66953, saving model to checkpoint/cp.ckpt
# Epoch 2/100
# 508/508 [==============================] - 4s 9ms/step - loss: 2.3027 - accuracy: 0.5158 - val_loss: 2.4664 - val_accuracy: 0.5068
#
# Epoch 00002: loss improved from 2.66953 to 2.30271, saving model to checkpoint/cp.ckpt
# Epoch 3/100
# 508/508 [==============================] - 4s 9ms/step - loss: 2.1895 - accuracy: 0.5354 - val_loss: 2.4014 - val_accuracy: 0.5199
#
# Epoch 00003: loss improved from 2.30271 to 2.18951, saving model to checkpoint/cp.ckpt
# Epoch 4/100
# 508/508 [==============================] - 4s 9ms/step - loss: 2.1030 - accuracy: 0.5513 - val_loss: 2.3607 - val_accuracy: 0.5265
#
# Epoch 00004: loss improved from 2.18951 to 2.10300, saving model to checkpoint/cp.ckpt
# Epoch 5/100
# 508/508 [==============================] - 4s 9ms/step - loss: 2.0386 - accuracy: 0.5635 - val_loss: 2.3408 - val_accuracy: 0.5365
#
# Epoch 00005: loss improved from 2.10300 to 2.03857, saving model to checkpoint/cp.ckpt
# Epoch 6/100
# 508/508 [==============================] - 4s 9ms/step - loss: 1.9970 - accuracy: 0.5745 - val_loss: 2.3446 - val_accuracy: 0.5396
#
# Epoch 00006: loss improved from 2.03857 to 1.99698, saving model to checkpoint/cp.ckpt
# Epoch 7/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.9613 - accuracy: 0.5835 - val_loss: 2.3164 - val_accuracy: 0.5458
#
# Epoch 00007: loss improved from 1.99698 to 1.96134, saving model to checkpoint/cp.ckpt
# Epoch 8/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.9357 - accuracy: 0.5933 - val_loss: 2.3052 - val_accuracy: 0.5527
#
# Epoch 00008: loss improved from 1.96134 to 1.93568, saving model to checkpoint/cp.ckpt
# Epoch 9/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.9090 - accuracy: 0.6006 - val_loss: 2.3084 - val_accuracy: 0.5532
#
# Epoch 00009: loss improved from 1.93568 to 1.90896, saving model to checkpoint/cp.ckpt
# Epoch 10/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8897 - accuracy: 0.6072 - val_loss: 2.3029 - val_accuracy: 0.5537
#
# Epoch 00010: loss improved from 1.90896 to 1.88965, saving model to checkpoint/cp.ckpt
# Epoch 11/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8710 - accuracy: 0.6118 - val_loss: 2.2600 - val_accuracy: 0.5631
#
# Epoch 00011: loss improved from 1.88965 to 1.87098, saving model to checkpoint/cp.ckpt
# Epoch 12/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8530 - accuracy: 0.6168 - val_loss: 2.2705 - val_accuracy: 0.5578
#
# Epoch 00012: loss improved from 1.87098 to 1.85301, saving model to checkpoint/cp.ckpt
# Epoch 13/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8418 - accuracy: 0.6210 - val_loss: 2.2516 - val_accuracy: 0.5646
#
# Epoch 00013: loss improved from 1.85301 to 1.84183, saving model to checkpoint/cp.ckpt
# Epoch 14/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8288 - accuracy: 0.6261 - val_loss: 2.2792 - val_accuracy: 0.5543
#
# Epoch 00014: loss improved from 1.84183 to 1.82877, saving model to checkpoint/cp.ckpt
# Epoch 15/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8162 - accuracy: 0.6299 - val_loss: 2.2259 - val_accuracy: 0.5702
#
# Epoch 00015: loss improved from 1.82877 to 1.81616, saving model to checkpoint/cp.ckpt
# Epoch 16/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8085 - accuracy: 0.6318 - val_loss: 2.2327 - val_accuracy: 0.5703
#
# Epoch 00016: loss improved from 1.81616 to 1.80846, saving model to checkpoint/cp.ckpt
# Epoch 17/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.8005 - accuracy: 0.6348 - val_loss: 2.2099 - val_accuracy: 0.5721
#
# Epoch 00017: loss improved from 1.80846 to 1.80046, saving model to checkpoint/cp.ckpt
# Epoch 18/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7903 - accuracy: 0.6364 - val_loss: 2.2177 - val_accuracy: 0.5734
#
# Epoch 00018: loss improved from 1.80046 to 1.79034, saving model to checkpoint/cp.ckpt
# Epoch 19/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7847 - accuracy: 0.6371 - val_loss: 2.2032 - val_accuracy: 0.5760
#
# Epoch 00019: loss improved from 1.79034 to 1.78471, saving model to checkpoint/cp.ckpt
# Epoch 20/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7803 - accuracy: 0.6396 - val_loss: 2.2219 - val_accuracy: 0.5710
#
# Epoch 00020: loss improved from 1.78471 to 1.78031, saving model to checkpoint/cp.ckpt
# Epoch 21/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.7693 - accuracy: 0.6412 - val_loss: 2.2114 - val_accuracy: 0.5740
#
# Epoch 00021: loss improved from 1.78031 to 1.76933, saving model to checkpoint/cp.ckpt
# Epoch 22/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7642 - accuracy: 0.6450 - val_loss: 2.2184 - val_accuracy: 0.5745
#
# Epoch 00022: loss improved from 1.76933 to 1.76418, saving model to checkpoint/cp.ckpt
# Epoch 23/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7612 - accuracy: 0.6440 - val_loss: 2.2027 - val_accuracy: 0.5751
#
# Epoch 00023: loss improved from 1.76418 to 1.76119, saving model to checkpoint/cp.ckpt
# Epoch 24/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7574 - accuracy: 0.6454 - val_loss: 2.2130 - val_accuracy: 0.5764
#
# Epoch 00024: loss improved from 1.76119 to 1.75737, saving model to checkpoint/cp.ckpt
# Epoch 25/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7536 - accuracy: 0.6451 - val_loss: 2.1893 - val_accuracy: 0.5835
#
# Epoch 00025: loss improved from 1.75737 to 1.75364, saving model to checkpoint/cp.ckpt
# Epoch 26/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7473 - accuracy: 0.6462 - val_loss: 2.2047 - val_accuracy: 0.5748
#
# Epoch 00026: loss improved from 1.75364 to 1.74726, saving model to checkpoint/cp.ckpt
# Epoch 27/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7402 - accuracy: 0.6475 - val_loss: 2.2138 - val_accuracy: 0.5734
#
# Epoch 00027: loss improved from 1.74726 to 1.74017, saving model to checkpoint/cp.ckpt
# Epoch 28/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7382 - accuracy: 0.6483 - val_loss: 2.1923 - val_accuracy: 0.5754
#
# Epoch 00028: loss improved from 1.74017 to 1.73822, saving model to checkpoint/cp.ckpt
# Epoch 29/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7350 - accuracy: 0.6508 - val_loss: 2.1996 - val_accuracy: 0.5783
#
# Epoch 00029: loss improved from 1.73822 to 1.73502, saving model to checkpoint/cp.ckpt
# Epoch 30/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7274 - accuracy: 0.6531 - val_loss: 2.2065 - val_accuracy: 0.5758
#
# Epoch 00030: loss improved from 1.73502 to 1.72740, saving model to checkpoint/cp.ckpt
# Epoch 31/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7263 - accuracy: 0.6528 - val_loss: 2.2107 - val_accuracy: 0.5739
#
# Epoch 00031: loss improved from 1.72740 to 1.72635, saving model to checkpoint/cp.ckpt
# Epoch 32/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7233 - accuracy: 0.6531 - val_loss: 2.1886 - val_accuracy: 0.5825
#
# Epoch 00032: loss improved from 1.72635 to 1.72333, saving model to checkpoint/cp.ckpt
# Epoch 33/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7208 - accuracy: 0.6532 - val_loss: 2.2164 - val_accuracy: 0.5764
#
# Epoch 00033: loss improved from 1.72333 to 1.72083, saving model to checkpoint/cp.ckpt
# Epoch 34/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7171 - accuracy: 0.6541 - val_loss: 2.2041 - val_accuracy: 0.5764
#
# Epoch 00034: loss improved from 1.72083 to 1.71709, saving model to checkpoint/cp.ckpt
# Epoch 35/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7162 - accuracy: 0.6542 - val_loss: 2.2204 - val_accuracy: 0.5771
#
# Epoch 00035: loss improved from 1.71709 to 1.71617, saving model to checkpoint/cp.ckpt
# Epoch 36/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7151 - accuracy: 0.6562 - val_loss: 2.1845 - val_accuracy: 0.5838
#
# Epoch 00036: loss improved from 1.71617 to 1.71514, saving model to checkpoint/cp.ckpt
# Epoch 37/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7143 - accuracy: 0.6545 - val_loss: 2.1946 - val_accuracy: 0.5814
#
# Epoch 00037: loss improved from 1.71514 to 1.71426, saving model to checkpoint/cp.ckpt
# Epoch 38/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7086 - accuracy: 0.6569 - val_loss: 2.2004 - val_accuracy: 0.5820
#
# Epoch 00038: loss improved from 1.71426 to 1.70859, saving model to checkpoint/cp.ckpt
# Epoch 39/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7096 - accuracy: 0.6573 - val_loss: 2.2020 - val_accuracy: 0.5798
#
# Epoch 00039: loss did not improve from 1.70859
# Epoch 40/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7046 - accuracy: 0.6572 - val_loss: 2.1880 - val_accuracy: 0.5845
#
# Epoch 00040: loss improved from 1.70859 to 1.70458, saving model to checkpoint/cp.ckpt
# Epoch 41/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7024 - accuracy: 0.6585 - val_loss: 2.1668 - val_accuracy: 0.5921
#
# Epoch 00041: loss improved from 1.70458 to 1.70244, saving model to checkpoint/cp.ckpt
# Epoch 42/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7015 - accuracy: 0.6584 - val_loss: 2.1883 - val_accuracy: 0.5839
#
# Epoch 00042: loss improved from 1.70244 to 1.70149, saving model to checkpoint/cp.ckpt
# Epoch 43/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.7002 - accuracy: 0.6573 - val_loss: 2.1851 - val_accuracy: 0.5862
#
# Epoch 00043: loss improved from 1.70149 to 1.70021, saving model to checkpoint/cp.ckpt
# Epoch 44/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6975 - accuracy: 0.6591 - val_loss: 2.1789 - val_accuracy: 0.5826
#
# Epoch 00044: loss improved from 1.70021 to 1.69752, saving model to checkpoint/cp.ckpt
# Epoch 45/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6936 - accuracy: 0.6601 - val_loss: 2.1968 - val_accuracy: 0.5804
#
# Epoch 00045: loss improved from 1.69752 to 1.69362, saving model to checkpoint/cp.ckpt
# Epoch 46/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6910 - accuracy: 0.6603 - val_loss: 2.2025 - val_accuracy: 0.5796
#
# Epoch 00046: loss improved from 1.69362 to 1.69098, saving model to checkpoint/cp.ckpt
# Epoch 47/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6914 - accuracy: 0.6592 - val_loss: 2.1750 - val_accuracy: 0.5852
#
# Epoch 00047: loss did not improve from 1.69098
# Epoch 48/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6900 - accuracy: 0.6608 - val_loss: 2.1826 - val_accuracy: 0.5866
#
# Epoch 00048: loss improved from 1.69098 to 1.69002, saving model to checkpoint/cp.ckpt
# Epoch 49/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6876 - accuracy: 0.6618 - val_loss: 2.1957 - val_accuracy: 0.5840
#
# Epoch 00049: loss improved from 1.69002 to 1.68756, saving model to checkpoint/cp.ckpt
# Epoch 50/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6862 - accuracy: 0.6608 - val_loss: 2.1674 - val_accuracy: 0.5883
#
# Epoch 00050: loss improved from 1.68756 to 1.68616, saving model to checkpoint/cp.ckpt
# Epoch 51/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6853 - accuracy: 0.6613 - val_loss: 2.1782 - val_accuracy: 0.5871
#
# Epoch 00051: loss improved from 1.68616 to 1.68527, saving model to checkpoint/cp.ckpt
# Epoch 52/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6822 - accuracy: 0.6618 - val_loss: 2.1751 - val_accuracy: 0.5846
#
# Epoch 00052: loss improved from 1.68527 to 1.68216, saving model to checkpoint/cp.ckpt
# Epoch 53/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6843 - accuracy: 0.6618 - val_loss: 2.1870 - val_accuracy: 0.5815
#
# Epoch 00053: loss did not improve from 1.68216
# Epoch 54/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6784 - accuracy: 0.6625 - val_loss: 2.1781 - val_accuracy: 0.5846
#
# Epoch 00054: loss improved from 1.68216 to 1.67841, saving model to checkpoint/cp.ckpt
# Epoch 55/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6783 - accuracy: 0.6635 - val_loss: 2.1917 - val_accuracy: 0.5857
#
# Epoch 00055: loss improved from 1.67841 to 1.67828, saving model to checkpoint/cp.ckpt
# Epoch 56/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6751 - accuracy: 0.6649 - val_loss: 2.1966 - val_accuracy: 0.5815
#
# Epoch 00056: loss improved from 1.67828 to 1.67507, saving model to checkpoint/cp.ckpt
# Epoch 57/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6791 - accuracy: 0.6618 - val_loss: 2.1868 - val_accuracy: 0.5826
#
# Epoch 00057: loss did not improve from 1.67507
# Epoch 58/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6759 - accuracy: 0.6626 - val_loss: 2.1840 - val_accuracy: 0.5845
#
# Epoch 00058: loss did not improve from 1.67507
# Epoch 59/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6725 - accuracy: 0.6660 - val_loss: 2.2044 - val_accuracy: 0.5745
#
# Epoch 00059: loss improved from 1.67507 to 1.67253, saving model to checkpoint/cp.ckpt
# Epoch 60/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6702 - accuracy: 0.6653 - val_loss: 2.1826 - val_accuracy: 0.5855
#
# Epoch 00060: loss improved from 1.67253 to 1.67022, saving model to checkpoint/cp.ckpt
# Epoch 61/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6702 - accuracy: 0.6669 - val_loss: 2.2016 - val_accuracy: 0.5818
#
# Epoch 00061: loss improved from 1.67022 to 1.67016, saving model to checkpoint/cp.ckpt
# Epoch 62/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6673 - accuracy: 0.6659 - val_loss: 2.1940 - val_accuracy: 0.5847
#
# Epoch 00062: loss improved from 1.67016 to 1.66732, saving model to checkpoint/cp.ckpt
# Epoch 63/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6679 - accuracy: 0.6648 - val_loss: 2.2021 - val_accuracy: 0.5819
#
# Epoch 00063: loss did not improve from 1.66732
# Epoch 64/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6625 - accuracy: 0.6673 - val_loss: 2.1688 - val_accuracy: 0.5888
#
# Epoch 00064: loss improved from 1.66732 to 1.66248, saving model to checkpoint/cp.ckpt
# Epoch 65/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6650 - accuracy: 0.6648 - val_loss: 2.1698 - val_accuracy: 0.5856
#
# Epoch 00065: loss did not improve from 1.66248
# Epoch 66/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6659 - accuracy: 0.6650 - val_loss: 2.1647 - val_accuracy: 0.5854
#
# Epoch 00066: loss did not improve from 1.66248
# Epoch 67/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6607 - accuracy: 0.6661 - val_loss: 2.1904 - val_accuracy: 0.5851
#
# Epoch 00067: loss improved from 1.66248 to 1.66075, saving model to checkpoint/cp.ckpt
# Epoch 68/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6622 - accuracy: 0.6679 - val_loss: 2.1789 - val_accuracy: 0.5879
#
# Epoch 00068: loss did not improve from 1.66075
# Epoch 69/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6580 - accuracy: 0.6680 - val_loss: 2.1779 - val_accuracy: 0.5833
#
# Epoch 00069: loss improved from 1.66075 to 1.65796, saving model to checkpoint/cp.ckpt
# Epoch 70/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6592 - accuracy: 0.6669 - val_loss: 2.1765 - val_accuracy: 0.5872
#
# Epoch 00070: loss did not improve from 1.65796
# Epoch 71/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6571 - accuracy: 0.6680 - val_loss: 2.1724 - val_accuracy: 0.5883
#
# Epoch 00071: loss improved from 1.65796 to 1.65715, saving model to checkpoint/cp.ckpt
# Epoch 72/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6575 - accuracy: 0.6690 - val_loss: 2.1512 - val_accuracy: 0.5913
#
# Epoch 00072: loss did not improve from 1.65715
# Epoch 73/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6544 - accuracy: 0.6675 - val_loss: 2.1664 - val_accuracy: 0.5876
#
# Epoch 00073: loss improved from 1.65715 to 1.65438, saving model to checkpoint/cp.ckpt
# Epoch 74/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6539 - accuracy: 0.6684 - val_loss: 2.1710 - val_accuracy: 0.5887
#
# Epoch 00074: loss improved from 1.65438 to 1.65394, saving model to checkpoint/cp.ckpt
# Epoch 75/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6520 - accuracy: 0.6688 - val_loss: 2.1908 - val_accuracy: 0.5804
#
# Epoch 00075: loss improved from 1.65394 to 1.65200, saving model to checkpoint/cp.ckpt
# Epoch 76/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6542 - accuracy: 0.6694 - val_loss: 2.1790 - val_accuracy: 0.5840
#
# Epoch 00076: loss did not improve from 1.65200
# Epoch 77/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6507 - accuracy: 0.6678 - val_loss: 2.1714 - val_accuracy: 0.5856
#
# Epoch 00077: loss improved from 1.65200 to 1.65074, saving model to checkpoint/cp.ckpt
# Epoch 78/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6490 - accuracy: 0.6701 - val_loss: 2.1856 - val_accuracy: 0.5861
#
# Epoch 00078: loss improved from 1.65074 to 1.64900, saving model to checkpoint/cp.ckpt
# Epoch 79/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6462 - accuracy: 0.6696 - val_loss: 2.1741 - val_accuracy: 0.5888
#
# Epoch 00079: loss improved from 1.64900 to 1.64625, saving model to checkpoint/cp.ckpt
# Epoch 80/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6486 - accuracy: 0.6703 - val_loss: 2.1712 - val_accuracy: 0.5887
#
# Epoch 00080: loss did not improve from 1.64625
# Epoch 81/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6478 - accuracy: 0.6696 - val_loss: 2.1687 - val_accuracy: 0.5868
#
# Epoch 00081: loss did not improve from 1.64625
# Epoch 82/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6462 - accuracy: 0.6708 - val_loss: 2.1748 - val_accuracy: 0.5868
#
# Epoch 00082: loss improved from 1.64625 to 1.64621, saving model to checkpoint/cp.ckpt
# Epoch 83/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6461 - accuracy: 0.6699 - val_loss: 2.1815 - val_accuracy: 0.5878
#
# Epoch 00083: loss improved from 1.64621 to 1.64608, saving model to checkpoint/cp.ckpt
# Epoch 84/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6421 - accuracy: 0.6706 - val_loss: 2.1792 - val_accuracy: 0.5862
#
# Epoch 00084: loss improved from 1.64608 to 1.64205, saving model to checkpoint/cp.ckpt
# Epoch 85/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.6424 - accuracy: 0.6712 - val_loss: 2.1776 - val_accuracy: 0.5866
#
# Epoch 00085: loss did not improve from 1.64205
# Epoch 86/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6417 - accuracy: 0.6723 - val_loss: 2.1811 - val_accuracy: 0.5855
#
# Epoch 00086: loss improved from 1.64205 to 1.64172, saving model to checkpoint/cp.ckpt
# Epoch 87/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6426 - accuracy: 0.6714 - val_loss: 2.1682 - val_accuracy: 0.5906
#
# Epoch 00087: loss did not improve from 1.64172
# Epoch 88/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6426 - accuracy: 0.6710 - val_loss: 2.1800 - val_accuracy: 0.5877
#
# Epoch 00088: loss did not improve from 1.64172
# Epoch 89/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6411 - accuracy: 0.6713 - val_loss: 2.1957 - val_accuracy: 0.5854
#
# Epoch 00089: loss improved from 1.64172 to 1.64109, saving model to checkpoint/cp.ckpt
# Epoch 90/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6393 - accuracy: 0.6718 - val_loss: 2.1812 - val_accuracy: 0.5826
#
# Epoch 00090: loss improved from 1.64109 to 1.63927, saving model to checkpoint/cp.ckpt
# Epoch 91/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6356 - accuracy: 0.6738 - val_loss: 2.1729 - val_accuracy: 0.5876
#
# Epoch 00091: loss improved from 1.63927 to 1.63556, saving model to checkpoint/cp.ckpt
# Epoch 92/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6378 - accuracy: 0.6719 - val_loss: 2.1535 - val_accuracy: 0.5904
#
# Epoch 00092: loss did not improve from 1.63556
# Epoch 93/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6347 - accuracy: 0.6718 - val_loss: 2.1620 - val_accuracy: 0.5915
#
# Epoch 00093: loss improved from 1.63556 to 1.63473, saving model to checkpoint/cp.ckpt
# Epoch 94/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6362 - accuracy: 0.6709 - val_loss: 2.1656 - val_accuracy: 0.5899
#
# Epoch 00094: loss did not improve from 1.63473
# Epoch 95/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6328 - accuracy: 0.6736 - val_loss: 2.1808 - val_accuracy: 0.5856
#
# Epoch 00095: loss improved from 1.63473 to 1.63278, saving model to checkpoint/cp.ckpt
# Epoch 96/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6352 - accuracy: 0.6723 - val_loss: 2.1631 - val_accuracy: 0.5884
#
# Epoch 00096: loss did not improve from 1.63278
# Epoch 97/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.6324 - accuracy: 0.6726 - val_loss: 2.1657 - val_accuracy: 0.5884
#
# Epoch 00097: loss improved from 1.63278 to 1.63237, saving model to checkpoint/cp.ckpt
# Epoch 98/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6308 - accuracy: 0.6724 - val_loss: 2.1440 - val_accuracy: 0.5957
#
# Epoch 00098: loss improved from 1.63237 to 1.63076, saving model to checkpoint/cp.ckpt
# Epoch 99/100
# 508/508 [==============================] - 5s 9ms/step - loss: 1.6306 - accuracy: 0.6724 - val_loss: 2.1636 - val_accuracy: 0.5924
#
# Epoch 00099: loss improved from 1.63076 to 1.63057, saving model to checkpoint/cp.ckpt
# Epoch 100/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.6315 - accuracy: 0.6726 - val_loss: 2.1606 - val_accuracy: 0.5929
#
# Epoch 00100: loss did not improve from 1.63057
# Epoch 1/100
# 508/508 [==============================] - 8s 13ms/step - loss: 2.4664 - accuracy: 0.4981 - val_loss: 2.4505 - val_accuracy: 0.5079
#
# Epoch 00001: loss improved from inf to 2.46636, saving model to checkpoint/cp.ckpt
# Epoch 2/100
# 508/508 [==============================] - 6s 11ms/step - loss: 2.1547 - accuracy: 0.5391 - val_loss: 2.3653 - val_accuracy: 0.5239
#
# Epoch 00002: loss improved from 2.46636 to 2.15466, saving model to checkpoint/cp.ckpt
# Epoch 3/100
# 508/508 [==============================] - 6s 11ms/step - loss: 2.0499 - accuracy: 0.5626 - val_loss: 2.3270 - val_accuracy: 0.5318
#
# Epoch 00003: loss improved from 2.15466 to 2.04992, saving model to checkpoint/cp.ckpt
# Epoch 4/100
# 508/508 [==============================] - 6s 11ms/step - loss: 1.9815 - accuracy: 0.5805 - val_loss: 2.3202 - val_accuracy: 0.5386
#
# Epoch 00004: loss improved from 2.04992 to 1.98150, saving model to checkpoint/cp.ckpt
# Epoch 5/100
# 508/508 [==============================] - 6s 11ms/step - loss: 1.9293 - accuracy: 0.5966 - val_loss: 2.2885 - val_accuracy: 0.5471
#
# Epoch 00005: loss improved from 1.98150 to 1.92928, saving model to checkpoint/cp.ckpt
# Epoch 6/100
# 508/508 [==============================] - 6s 11ms/step - loss: 1.8875 - accuracy: 0.6085 - val_loss: 2.2408 - val_accuracy: 0.5583
#
# Epoch 00006: loss improved from 1.92928 to 1.88752, saving model to checkpoint/cp.ckpt
# Epoch 7/100
# 508/508 [==============================] - 6s 11ms/step - loss: 1.8554 - accuracy: 0.6179 - val_loss: 2.2384 - val_accuracy: 0.5666
#
# Epoch 00007: loss improved from 1.88752 to 1.85536, saving model to checkpoint/cp.ckpt
# Epoch 8/100
# 508/508 [==============================] - 6s 11ms/step - loss: 1.8267 - accuracy: 0.6251 - val_loss: 2.2343 - val_accuracy: 0.5694
#
# Epoch 00008: loss improved from 1.85536 to 1.82670, saving model to checkpoint/cp.ckpt
# Epoch 9/100
# 508/508 [==============================] - 6s 11ms/step - loss: 1.8075 - accuracy: 0.6325 - val_loss: 2.2431 - val_accuracy: 0.5700
#
# Epoch 00009: loss improved from 1.82670 to 1.80745, saving model to checkpoint/cp.ckpt
# Epoch 10/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.7855 - accuracy: 0.6374 - val_loss: 2.2122 - val_accuracy: 0.5719
#
# Epoch 00010: loss improved from 1.80745 to 1.78551, saving model to checkpoint/cp.ckpt
# Epoch 11/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.7675 - accuracy: 0.6425 - val_loss: 2.1857 - val_accuracy: 0.5822
#
# Epoch 00011: loss improved from 1.78551 to 1.76750, saving model to checkpoint/cp.ckpt
# Epoch 12/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.7538 - accuracy: 0.6467 - val_loss: 2.1944 - val_accuracy: 0.5798
#
# Epoch 00012: loss improved from 1.76750 to 1.75383, saving model to checkpoint/cp.ckpt
# Epoch 13/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.7390 - accuracy: 0.6495 - val_loss: 2.1636 - val_accuracy: 0.5879
#
# Epoch 00013: loss improved from 1.75383 to 1.73904, saving model to checkpoint/cp.ckpt
# Epoch 14/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.7284 - accuracy: 0.6538 - val_loss: 2.2053 - val_accuracy: 0.5823
#
# Epoch 00014: loss improved from 1.73904 to 1.72842, saving model to checkpoint/cp.ckpt
# Epoch 15/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.7171 - accuracy: 0.6555 - val_loss: 2.1991 - val_accuracy: 0.5796
#
# Epoch 00015: loss improved from 1.72842 to 1.71714, saving model to checkpoint/cp.ckpt
# Epoch 16/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.7097 - accuracy: 0.6558 - val_loss: 2.1951 - val_accuracy: 0.5780
#
# Epoch 00016: loss improved from 1.71714 to 1.70973, saving model to checkpoint/cp.ckpt
# Epoch 17/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6981 - accuracy: 0.6593 - val_loss: 2.2262 - val_accuracy: 0.5761
#
# Epoch 00017: loss improved from 1.70973 to 1.69809, saving model to checkpoint/cp.ckpt
# Epoch 18/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6940 - accuracy: 0.6600 - val_loss: 2.1858 - val_accuracy: 0.5820
#
# Epoch 00018: loss improved from 1.69809 to 1.69400, saving model to checkpoint/cp.ckpt
# Epoch 19/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6849 - accuracy: 0.6620 - val_loss: 2.2019 - val_accuracy: 0.5815
#
# Epoch 00019: loss improved from 1.69400 to 1.68495, saving model to checkpoint/cp.ckpt
# Epoch 20/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6740 - accuracy: 0.6642 - val_loss: 2.1740 - val_accuracy: 0.5860
#
# Epoch 00020: loss improved from 1.68495 to 1.67402, saving model to checkpoint/cp.ckpt
# Epoch 21/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6679 - accuracy: 0.6644 - val_loss: 2.2106 - val_accuracy: 0.5830
#
# Epoch 00021: loss improved from 1.67402 to 1.66792, saving model to checkpoint/cp.ckpt
# Epoch 22/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6624 - accuracy: 0.6674 - val_loss: 2.2018 - val_accuracy: 0.5851
#
# Epoch 00022: loss improved from 1.66792 to 1.66242, saving model to checkpoint/cp.ckpt
# Epoch 23/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6574 - accuracy: 0.6692 - val_loss: 2.2128 - val_accuracy: 0.5791
#
# Epoch 00023: loss improved from 1.66242 to 1.65742, saving model to checkpoint/cp.ckpt
# Epoch 24/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6504 - accuracy: 0.6675 - val_loss: 2.1723 - val_accuracy: 0.5894
#
# Epoch 00024: loss improved from 1.65742 to 1.65038, saving model to checkpoint/cp.ckpt
# Epoch 25/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6425 - accuracy: 0.6705 - val_loss: 2.1682 - val_accuracy: 0.5924
#
# Epoch 00025: loss improved from 1.65038 to 1.64249, saving model to checkpoint/cp.ckpt
# Epoch 26/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6345 - accuracy: 0.6722 - val_loss: 2.1975 - val_accuracy: 0.5887
#
# Epoch 00026: loss improved from 1.64249 to 1.63451, saving model to checkpoint/cp.ckpt
# Epoch 27/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6336 - accuracy: 0.6730 - val_loss: 2.1826 - val_accuracy: 0.5899
#
# Epoch 00027: loss improved from 1.63451 to 1.63358, saving model to checkpoint/cp.ckpt
# Epoch 28/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6288 - accuracy: 0.6741 - val_loss: 2.1969 - val_accuracy: 0.5897
#
# Epoch 00028: loss improved from 1.63358 to 1.62876, saving model to checkpoint/cp.ckpt
# Epoch 29/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6239 - accuracy: 0.6748 - val_loss: 2.2232 - val_accuracy: 0.5812
#
# Epoch 00029: loss improved from 1.62876 to 1.62386, saving model to checkpoint/cp.ckpt
# Epoch 30/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6223 - accuracy: 0.6738 - val_loss: 2.1630 - val_accuracy: 0.5988
#
# Epoch 00030: loss improved from 1.62386 to 1.62230, saving model to checkpoint/cp.ckpt
# Epoch 31/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6143 - accuracy: 0.6758 - val_loss: 2.1976 - val_accuracy: 0.5893
#
# Epoch 00031: loss improved from 1.62230 to 1.61426, saving model to checkpoint/cp.ckpt
# Epoch 32/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6086 - accuracy: 0.6778 - val_loss: 2.1817 - val_accuracy: 0.5913
#
# Epoch 00032: loss improved from 1.61426 to 1.60861, saving model to checkpoint/cp.ckpt
# Epoch 33/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6038 - accuracy: 0.6776 - val_loss: 2.1993 - val_accuracy: 0.5845
#
# Epoch 00033: loss improved from 1.60861 to 1.60381, saving model to checkpoint/cp.ckpt
# Epoch 34/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.6039 - accuracy: 0.6781 - val_loss: 2.1744 - val_accuracy: 0.5940
#
# Epoch 00034: loss did not improve from 1.60381
# Epoch 35/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5960 - accuracy: 0.6807 - val_loss: 2.2142 - val_accuracy: 0.5847
#
# Epoch 00035: loss improved from 1.60381 to 1.59596, saving model to checkpoint/cp.ckpt
# Epoch 36/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5964 - accuracy: 0.6798 - val_loss: 2.1707 - val_accuracy: 0.5921
#
# Epoch 00036: loss did not improve from 1.59596
# Epoch 37/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5912 - accuracy: 0.6806 - val_loss: 2.1709 - val_accuracy: 0.5964
#
# Epoch 00037: loss improved from 1.59596 to 1.59118, saving model to checkpoint/cp.ckpt
# Epoch 38/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5882 - accuracy: 0.6811 - val_loss: 2.1773 - val_accuracy: 0.5982
#
# Epoch 00038: loss improved from 1.59118 to 1.58819, saving model to checkpoint/cp.ckpt
# Epoch 39/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5851 - accuracy: 0.6824 - val_loss: 2.1822 - val_accuracy: 0.5927
#
# Epoch 00039: loss improved from 1.58819 to 1.58509, saving model to checkpoint/cp.ckpt
# Epoch 40/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5806 - accuracy: 0.6859 - val_loss: 2.1583 - val_accuracy: 0.5966
#
# Epoch 00040: loss improved from 1.58509 to 1.58064, saving model to checkpoint/cp.ckpt
# Epoch 41/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5761 - accuracy: 0.6821 - val_loss: 2.1705 - val_accuracy: 0.5983
#
# Epoch 00041: loss improved from 1.58064 to 1.57612, saving model to checkpoint/cp.ckpt
# Epoch 42/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5706 - accuracy: 0.6839 - val_loss: 2.1770 - val_accuracy: 0.5962
#
# Epoch 00042: loss improved from 1.57612 to 1.57064, saving model to checkpoint/cp.ckpt
# Epoch 43/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5723 - accuracy: 0.6854 - val_loss: 2.1824 - val_accuracy: 0.5897
#
# Epoch 00043: loss did not improve from 1.57064
# Epoch 44/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5673 - accuracy: 0.6847 - val_loss: 2.1865 - val_accuracy: 0.5962
#
# Epoch 00044: loss improved from 1.57064 to 1.56731, saving model to checkpoint/cp.ckpt
# Epoch 45/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5670 - accuracy: 0.6866 - val_loss: 2.1571 - val_accuracy: 0.6021
#
# Epoch 00045: loss improved from 1.56731 to 1.56699, saving model to checkpoint/cp.ckpt
# Epoch 46/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5589 - accuracy: 0.6872 - val_loss: 2.1484 - val_accuracy: 0.5995
#
# Epoch 00046: loss improved from 1.56699 to 1.55887, saving model to checkpoint/cp.ckpt
# Epoch 47/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5563 - accuracy: 0.6874 - val_loss: 2.1694 - val_accuracy: 0.5973
#
# Epoch 00047: loss improved from 1.55887 to 1.55626, saving model to checkpoint/cp.ckpt
# Epoch 48/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5579 - accuracy: 0.6889 - val_loss: 2.1692 - val_accuracy: 0.5972
#
# Epoch 00048: loss did not improve from 1.55626
# Epoch 49/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5508 - accuracy: 0.6868 - val_loss: 2.1857 - val_accuracy: 0.5948
#
# Epoch 00049: loss improved from 1.55626 to 1.55085, saving model to checkpoint/cp.ckpt
# Epoch 50/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5526 - accuracy: 0.6875 - val_loss: 2.1648 - val_accuracy: 0.6015
#
# Epoch 00050: loss did not improve from 1.55085
# Epoch 51/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5489 - accuracy: 0.6909 - val_loss: 2.1540 - val_accuracy: 0.6060
#
# Epoch 00051: loss improved from 1.55085 to 1.54892, saving model to checkpoint/cp.ckpt
# Epoch 52/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5456 - accuracy: 0.6894 - val_loss: 2.1818 - val_accuracy: 0.5968
#
# Epoch 00052: loss improved from 1.54892 to 1.54562, saving model to checkpoint/cp.ckpt
# Epoch 53/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5433 - accuracy: 0.6898 - val_loss: 2.1742 - val_accuracy: 0.5979
#
# Epoch 00053: loss improved from 1.54562 to 1.54325, saving model to checkpoint/cp.ckpt
# Epoch 54/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5388 - accuracy: 0.6923 - val_loss: 2.1730 - val_accuracy: 0.5941
#
# Epoch 00054: loss improved from 1.54325 to 1.53884, saving model to checkpoint/cp.ckpt
# Epoch 55/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5415 - accuracy: 0.6903 - val_loss: 2.1861 - val_accuracy: 0.5925
#
# Epoch 00055: loss did not improve from 1.53884
# Epoch 56/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5369 - accuracy: 0.6902 - val_loss: 2.1751 - val_accuracy: 0.6004
#
# Epoch 00056: loss improved from 1.53884 to 1.53686, saving model to checkpoint/cp.ckpt
# Epoch 57/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5369 - accuracy: 0.6897 - val_loss: 2.1981 - val_accuracy: 0.5945
#
# Epoch 00057: loss improved from 1.53686 to 1.53685, saving model to checkpoint/cp.ckpt
# Epoch 58/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5324 - accuracy: 0.6919 - val_loss: 2.1832 - val_accuracy: 0.5978
#
# Epoch 00058: loss improved from 1.53685 to 1.53237, saving model to checkpoint/cp.ckpt
# Epoch 59/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5323 - accuracy: 0.6933 - val_loss: 2.1888 - val_accuracy: 0.5938
#
# Epoch 00059: loss improved from 1.53237 to 1.53232, saving model to checkpoint/cp.ckpt
# Epoch 60/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5274 - accuracy: 0.6932 - val_loss: 2.1843 - val_accuracy: 0.5977
#
# Epoch 00060: loss improved from 1.53232 to 1.52736, saving model to checkpoint/cp.ckpt
# Epoch 61/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5271 - accuracy: 0.6937 - val_loss: 2.1634 - val_accuracy: 0.6031
#
# Epoch 00061: loss improved from 1.52736 to 1.52708, saving model to checkpoint/cp.ckpt
# Epoch 62/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5238 - accuracy: 0.6933 - val_loss: 2.1776 - val_accuracy: 0.5988
#
# Epoch 00062: loss improved from 1.52708 to 1.52376, saving model to checkpoint/cp.ckpt
# Epoch 63/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5230 - accuracy: 0.6945 - val_loss: 2.1842 - val_accuracy: 0.5986
#
# Epoch 00063: loss improved from 1.52376 to 1.52299, saving model to checkpoint/cp.ckpt
# Epoch 64/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5206 - accuracy: 0.6956 - val_loss: 2.1730 - val_accuracy: 0.6022
#
# Epoch 00064: loss improved from 1.52299 to 1.52060, saving model to checkpoint/cp.ckpt
# Epoch 65/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5151 - accuracy: 0.6941 - val_loss: 2.1952 - val_accuracy: 0.5900
#
# Epoch 00065: loss improved from 1.52060 to 1.51508, saving model to checkpoint/cp.ckpt
# Epoch 66/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5164 - accuracy: 0.6937 - val_loss: 2.1890 - val_accuracy: 0.5982
#
# Epoch 00066: loss did not improve from 1.51508
# Epoch 67/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5155 - accuracy: 0.6954 - val_loss: 2.1790 - val_accuracy: 0.6001
#
# Epoch 00067: loss did not improve from 1.51508
# Epoch 68/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5126 - accuracy: 0.6956 - val_loss: 2.1769 - val_accuracy: 0.5983
#
# Epoch 00068: loss improved from 1.51508 to 1.51258, saving model to checkpoint/cp.ckpt
# Epoch 69/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5063 - accuracy: 0.6977 - val_loss: 2.1805 - val_accuracy: 0.5970
#
# Epoch 00069: loss improved from 1.51258 to 1.50630, saving model to checkpoint/cp.ckpt
# Epoch 70/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5118 - accuracy: 0.6975 - val_loss: 2.1696 - val_accuracy: 0.5972
#
# Epoch 00070: loss did not improve from 1.50630
# Epoch 71/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5081 - accuracy: 0.6949 - val_loss: 2.1699 - val_accuracy: 0.6021
#
# Epoch 00071: loss did not improve from 1.50630
# Epoch 72/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5067 - accuracy: 0.6966 - val_loss: 2.1702 - val_accuracy: 0.6015
#
# Epoch 00072: loss did not improve from 1.50630
# Epoch 73/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5050 - accuracy: 0.6978 - val_loss: 2.1613 - val_accuracy: 0.6080
#
# Epoch 00073: loss improved from 1.50630 to 1.50502, saving model to checkpoint/cp.ckpt
# Epoch 74/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4985 - accuracy: 0.7003 - val_loss: 2.1886 - val_accuracy: 0.5951
#
# Epoch 00074: loss improved from 1.50502 to 1.49847, saving model to checkpoint/cp.ckpt
# Epoch 75/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.5000 - accuracy: 0.6972 - val_loss: 2.1666 - val_accuracy: 0.6031
#
# Epoch 00075: loss did not improve from 1.49847
# Epoch 76/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4982 - accuracy: 0.6991 - val_loss: 2.1573 - val_accuracy: 0.6066
#
# Epoch 00076: loss improved from 1.49847 to 1.49815, saving model to checkpoint/cp.ckpt
# Epoch 77/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4973 - accuracy: 0.6984 - val_loss: 2.1726 - val_accuracy: 0.6020
#
# Epoch 00077: loss improved from 1.49815 to 1.49730, saving model to checkpoint/cp.ckpt
# Epoch 78/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4931 - accuracy: 0.6990 - val_loss: 2.1957 - val_accuracy: 0.5925
#
# Epoch 00078: loss improved from 1.49730 to 1.49306, saving model to checkpoint/cp.ckpt
# Epoch 79/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4938 - accuracy: 0.7001 - val_loss: 2.1699 - val_accuracy: 0.6005
#
# Epoch 00079: loss did not improve from 1.49306
# Epoch 80/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4893 - accuracy: 0.7016 - val_loss: 2.1761 - val_accuracy: 0.6001
#
# Epoch 00080: loss improved from 1.49306 to 1.48927, saving model to checkpoint/cp.ckpt
# Epoch 81/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4897 - accuracy: 0.7001 - val_loss: 2.1646 - val_accuracy: 0.6038
#
# Epoch 00081: loss did not improve from 1.48927
# Epoch 82/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4924 - accuracy: 0.6998 - val_loss: 2.1747 - val_accuracy: 0.6009
#
# Epoch 00082: loss did not improve from 1.48927
# Epoch 83/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4878 - accuracy: 0.6997 - val_loss: 2.1619 - val_accuracy: 0.6042
#
# Epoch 00083: loss improved from 1.48927 to 1.48778, saving model to checkpoint/cp.ckpt
# Epoch 84/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4891 - accuracy: 0.6995 - val_loss: 2.1801 - val_accuracy: 0.6006
#
# Epoch 00084: loss did not improve from 1.48778
# Epoch 85/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4853 - accuracy: 0.7001 - val_loss: 2.1753 - val_accuracy: 0.5998
#
# Epoch 00085: loss improved from 1.48778 to 1.48527, saving model to checkpoint/cp.ckpt
# Epoch 86/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4822 - accuracy: 0.7008 - val_loss: 2.1823 - val_accuracy: 0.5998
#
# Epoch 00086: loss improved from 1.48527 to 1.48223, saving model to checkpoint/cp.ckpt
# Epoch 87/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4798 - accuracy: 0.7021 - val_loss: 2.1920 - val_accuracy: 0.5998
#
# Epoch 00087: loss improved from 1.48223 to 1.47984, saving model to checkpoint/cp.ckpt
# Epoch 88/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4819 - accuracy: 0.7022 - val_loss: 2.1789 - val_accuracy: 0.6043
#
# Epoch 00088: loss did not improve from 1.47984
# Epoch 89/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4842 - accuracy: 0.7017 - val_loss: 2.2064 - val_accuracy: 0.5959
#
# Epoch 00089: loss did not improve from 1.47984
# Epoch 90/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4777 - accuracy: 0.7026 - val_loss: 2.1790 - val_accuracy: 0.6006
#
# Epoch 00090: loss improved from 1.47984 to 1.47774, saving model to checkpoint/cp.ckpt
# Epoch 91/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4772 - accuracy: 0.7038 - val_loss: 2.1854 - val_accuracy: 0.6004
#
# Epoch 00091: loss improved from 1.47774 to 1.47715, saving model to checkpoint/cp.ckpt
# Epoch 92/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4790 - accuracy: 0.7039 - val_loss: 2.1750 - val_accuracy: 0.6010
#
# Epoch 00092: loss did not improve from 1.47715
# Epoch 93/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4774 - accuracy: 0.7032 - val_loss: 2.2089 - val_accuracy: 0.5970
#
# Epoch 00093: loss did not improve from 1.47715
# Epoch 94/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4727 - accuracy: 0.7038 - val_loss: 2.1762 - val_accuracy: 0.6034
#
# Epoch 00094: loss improved from 1.47715 to 1.47269, saving model to checkpoint/cp.ckpt
# Epoch 95/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4735 - accuracy: 0.7025 - val_loss: 2.2178 - val_accuracy: 0.5883
#
# Epoch 00095: loss did not improve from 1.47269
# Epoch 96/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4733 - accuracy: 0.7027 - val_loss: 2.1871 - val_accuracy: 0.6032
#
# Epoch 00096: loss did not improve from 1.47269
# Epoch 97/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4714 - accuracy: 0.7037 - val_loss: 2.2132 - val_accuracy: 0.5946
#
# Epoch 00097: loss improved from 1.47269 to 1.47141, saving model to checkpoint/cp.ckpt
# Epoch 98/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4702 - accuracy: 0.7050 - val_loss: 2.1972 - val_accuracy: 0.5985
#
# Epoch 00098: loss improved from 1.47141 to 1.47015, saving model to checkpoint/cp.ckpt
# Epoch 99/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4698 - accuracy: 0.7039 - val_loss: 2.2116 - val_accuracy: 0.5961
#
# Epoch 00099: loss improved from 1.47015 to 1.46983, saving model to checkpoint/cp.ckpt
# Epoch 100/100
# 508/508 [==============================] - 6s 12ms/step - loss: 1.4698 - accuracy: 0.7016 - val_loss: 2.2030 - val_accuracy: 0.5951
#
# Epoch 00100: loss improved from 1.46983 to 1.46976, saving model to checkpoint/cp.ckpt
# Epoch 1/100
# 508/508 [==============================] - 7s 11ms/step - loss: 2.5545 - accuracy: 0.4884 - val_loss: 2.4998 - val_accuracy: 0.4945
#
# Epoch 00001: loss improved from inf to 2.55448, saving model to checkpoint/cp.ckpt
# Epoch 2/100
# 508/508 [==============================] - 5s 10ms/step - loss: 2.2366 - accuracy: 0.5272 - val_loss: 2.4295 - val_accuracy: 0.5084
#
# Epoch 00002: loss improved from 2.55448 to 2.23658, saving model to checkpoint/cp.ckpt
# Epoch 3/100
# 508/508 [==============================] - 5s 10ms/step - loss: 2.1316 - accuracy: 0.5455 - val_loss: 2.3789 - val_accuracy: 0.5264
#
# Epoch 00003: loss improved from 2.23658 to 2.13160, saving model to checkpoint/cp.ckpt
# Epoch 4/100
# 508/508 [==============================] - 5s 10ms/step - loss: 2.0646 - accuracy: 0.5597 - val_loss: 2.3790 - val_accuracy: 0.5308
#
# Epoch 00004: loss improved from 2.13160 to 2.06457, saving model to checkpoint/cp.ckpt
# Epoch 5/100
# 508/508 [==============================] - 5s 10ms/step - loss: 2.0192 - accuracy: 0.5706 - val_loss: 2.3459 - val_accuracy: 0.5394
#
# Epoch 00005: loss improved from 2.06457 to 2.01918, saving model to checkpoint/cp.ckpt
# Epoch 6/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.9851 - accuracy: 0.5805 - val_loss: 2.3435 - val_accuracy: 0.5408
#
# Epoch 00006: loss improved from 2.01918 to 1.98513, saving model to checkpoint/cp.ckpt
# Epoch 7/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.9576 - accuracy: 0.5878 - val_loss: 2.3223 - val_accuracy: 0.5423
#
# Epoch 00007: loss improved from 1.98513 to 1.95761, saving model to checkpoint/cp.ckpt
# Epoch 8/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.9341 - accuracy: 0.5921 - val_loss: 2.3152 - val_accuracy: 0.5461
#
# Epoch 00008: loss improved from 1.95761 to 1.93411, saving model to checkpoint/cp.ckpt
# Epoch 9/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.9093 - accuracy: 0.6004 - val_loss: 2.3205 - val_accuracy: 0.5465
#
# Epoch 00009: loss improved from 1.93411 to 1.90930, saving model to checkpoint/cp.ckpt
# Epoch 10/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.8876 - accuracy: 0.6064 - val_loss: 2.2822 - val_accuracy: 0.5510
#
# Epoch 00010: loss improved from 1.90930 to 1.88765, saving model to checkpoint/cp.ckpt
# Epoch 11/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.8729 - accuracy: 0.6117 - val_loss: 2.3042 - val_accuracy: 0.5490
#
# Epoch 00011: loss improved from 1.88765 to 1.87293, saving model to checkpoint/cp.ckpt
# Epoch 12/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.8545 - accuracy: 0.6151 - val_loss: 2.2712 - val_accuracy: 0.5582
#
# Epoch 00012: loss improved from 1.87293 to 1.85453, saving model to checkpoint/cp.ckpt
# Epoch 13/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.8418 - accuracy: 0.6216 - val_loss: 2.2806 - val_accuracy: 0.5519
#
# Epoch 00013: loss improved from 1.85453 to 1.84176, saving model to checkpoint/cp.ckpt
# Epoch 14/100
# 508/508 [==============================] - 5s 10ms/step - loss: 1.8291 - accuracy: 0.6231 - val_loss: 2.2803 - val_accuracy: 0.5543
#
# ...
# Epoch 29/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5523 - accuracy: 0.6864 - val_loss: 2.1639 - val_accuracy: 0.5959
#
# Epoch 00029: loss improved from 1.55705 to 1.55228, saving model to checkpoint/cp.ckpt
# Epoch 30/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5458 - accuracy: 0.6880 - val_loss: 2.1844 - val_accuracy: 0.5877
#
# Epoch 00030: loss improved from 1.55228 to 1.54583, saving model to checkpoint/cp.ckpt
# Epoch 31/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5390 - accuracy: 0.6901 - val_loss: 2.1373 - val_accuracy: 0.5983
#
# Epoch 00031: loss improved from 1.54583 to 1.53904, saving model to checkpoint/cp.ckpt
# Epoch 32/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5370 - accuracy: 0.6894 - val_loss: 2.1738 - val_accuracy: 0.5899
#
# Epoch 00032: loss improved from 1.53904 to 1.53701, saving model to checkpoint/cp.ckpt
# Epoch 33/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5303 - accuracy: 0.6907 - val_loss: 2.1555 - val_accuracy: 0.5959
#
# Epoch 00033: loss improved from 1.53701 to 1.53032, saving model to checkpoint/cp.ckpt
# Epoch 34/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5294 - accuracy: 0.6905 - val_loss: 2.1801 - val_accuracy: 0.5909
#
# Epoch 00034: loss improved from 1.53032 to 1.52937, saving model to checkpoint/cp.ckpt
# Epoch 35/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5223 - accuracy: 0.6922 - val_loss: 2.2025 - val_accuracy: 0.5833
#
# Epoch 00035: loss improved from 1.52937 to 1.52226, saving model to checkpoint/cp.ckpt
# Epoch 36/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5199 - accuracy: 0.6930 - val_loss: 2.1928 - val_accuracy: 0.5888
#
# Epoch 00036: loss improved from 1.52226 to 1.51993, saving model to checkpoint/cp.ckpt
# Epoch 37/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5115 - accuracy: 0.6947 - val_loss: 2.1753 - val_accuracy: 0.5893
#
# Epoch 00037: loss improved from 1.51993 to 1.51153, saving model to checkpoint/cp.ckpt
# Epoch 38/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5088 - accuracy: 0.6962 - val_loss: 2.1857 - val_accuracy: 0.5942
#
# Epoch 00038: loss improved from 1.51153 to 1.50880, saving model to checkpoint/cp.ckpt
# Epoch 39/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5011 - accuracy: 0.6962 - val_loss: 2.1805 - val_accuracy: 0.5915
#
# Epoch 00039: loss improved from 1.50880 to 1.50114, saving model to checkpoint/cp.ckpt
# Epoch 40/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.5017 - accuracy: 0.6975 - val_loss: 2.1699 - val_accuracy: 0.5968
#
# Epoch 00040: loss did not improve from 1.50114
# Epoch 41/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4945 - accuracy: 0.6976 - val_loss: 2.1759 - val_accuracy: 0.5956
#
# Epoch 00041: loss improved from 1.50114 to 1.49451, saving model to checkpoint/cp.ckpt
# Epoch 42/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4904 - accuracy: 0.6991 - val_loss: 2.1930 - val_accuracy: 0.5942
#
# Epoch 00042: loss improved from 1.49451 to 1.49040, saving model to checkpoint/cp.ckpt
# Epoch 43/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4904 - accuracy: 0.6996 - val_loss: 2.2186 - val_accuracy: 0.5883
#
# Epoch 00043: loss did not improve from 1.49040
# Epoch 44/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4841 - accuracy: 0.7001 - val_loss: 2.1859 - val_accuracy: 0.5982
#
# Epoch 00044: loss improved from 1.49040 to 1.48413, saving model to checkpoint/cp.ckpt
# Epoch 45/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4808 - accuracy: 0.7004 - val_loss: 2.1689 - val_accuracy: 0.5979
#
# Epoch 00045: loss improved from 1.48413 to 1.48084, saving model to checkpoint/cp.ckpt
# Epoch 46/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4793 - accuracy: 0.7008 - val_loss: 2.1911 - val_accuracy: 0.5966
#
# Epoch 00046: loss improved from 1.48084 to 1.47933, saving model to checkpoint/cp.ckpt
# Epoch 47/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4784 - accuracy: 0.7017 - val_loss: 2.2400 - val_accuracy: 0.5824
#
# Epoch 00047: loss improved from 1.47933 to 1.47835, saving model to checkpoint/cp.ckpt
# Epoch 48/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4700 - accuracy: 0.7024 - val_loss: 2.1945 - val_accuracy: 0.5963
#
# Epoch 00048: loss improved from 1.47835 to 1.46996, saving model to checkpoint/cp.ckpt
# Epoch 49/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4695 - accuracy: 0.7018 - val_loss: 2.1986 - val_accuracy: 0.5941
#
# Epoch 00049: loss improved from 1.46996 to 1.46954, saving model to checkpoint/cp.ckpt
# Epoch 50/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4632 - accuracy: 0.7026 - val_loss: 2.1957 - val_accuracy: 0.5968
#
# Epoch 00050: loss improved from 1.46954 to 1.46320, saving model to checkpoint/cp.ckpt
# Epoch 51/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4610 - accuracy: 0.7049 - val_loss: 2.1984 - val_accuracy: 0.5934
#
# Epoch 00051: loss improved from 1.46320 to 1.46098, saving model to checkpoint/cp.ckpt
# Epoch 52/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4592 - accuracy: 0.7047 - val_loss: 2.1961 - val_accuracy: 0.5964
#
# Epoch 00052: loss improved from 1.46098 to 1.45921, saving model to checkpoint/cp.ckpt
# Epoch 53/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4553 - accuracy: 0.7048 - val_loss: 2.1964 - val_accuracy: 0.5951
#
# Epoch 00053: loss improved from 1.45921 to 1.45531, saving model to checkpoint/cp.ckpt
# Epoch 54/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4532 - accuracy: 0.7042 - val_loss: 2.1799 - val_accuracy: 0.5966
#
# Epoch 00054: loss improved from 1.45531 to 1.45317, saving model to checkpoint/cp.ckpt
# Epoch 55/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4499 - accuracy: 0.7044 - val_loss: 2.2145 - val_accuracy: 0.5883
#
# Epoch 00055: loss improved from 1.45317 to 1.44990, saving model to checkpoint/cp.ckpt
# Epoch 56/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4482 - accuracy: 0.7065 - val_loss: 2.1704 - val_accuracy: 0.6036
#
# Epoch 00056: loss improved from 1.44990 to 1.44818, saving model to checkpoint/cp.ckpt
# Epoch 57/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4431 - accuracy: 0.7058 - val_loss: 2.2408 - val_accuracy: 0.5799
#
# Epoch 00057: loss improved from 1.44818 to 1.44311, saving model to checkpoint/cp.ckpt
# Epoch 58/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4463 - accuracy: 0.7065 - val_loss: 2.2111 - val_accuracy: 0.5913
#
# Epoch 00058: loss did not improve from 1.44311
# Epoch 59/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4382 - accuracy: 0.7087 - val_loss: 2.2045 - val_accuracy: 0.5931
#
# Epoch 00059: loss improved from 1.44311 to 1.43824, saving model to checkpoint/cp.ckpt
# Epoch 60/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4368 - accuracy: 0.7092 - val_loss: 2.2014 - val_accuracy: 0.5958
#
# Epoch 00060: loss improved from 1.43824 to 1.43683, saving model to checkpoint/cp.ckpt
# Epoch 61/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4335 - accuracy: 0.7072 - val_loss: 2.2352 - val_accuracy: 0.5863
#
# Epoch 00061: loss improved from 1.43683 to 1.43350, saving model to checkpoint/cp.ckpt
# Epoch 62/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4273 - accuracy: 0.7092 - val_loss: 2.2252 - val_accuracy: 0.5929
#
# Epoch 00062: loss improved from 1.43350 to 1.42732, saving model to checkpoint/cp.ckpt
# Epoch 63/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4266 - accuracy: 0.7095 - val_loss: 2.2271 - val_accuracy: 0.5921
#
# Epoch 00063: loss improved from 1.42732 to 1.42664, saving model to checkpoint/cp.ckpt
# Epoch 64/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4310 - accuracy: 0.7082 - val_loss: 2.1932 - val_accuracy: 0.5991
#
# Epoch 00064: loss did not improve from 1.42664
# Epoch 65/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4219 - accuracy: 0.7102 - val_loss: 2.2225 - val_accuracy: 0.5870
#
# Epoch 00065: loss improved from 1.42664 to 1.42189, saving model to checkpoint/cp.ckpt
# Epoch 66/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4230 - accuracy: 0.7097 - val_loss: 2.1846 - val_accuracy: 0.6042
#
# Epoch 00066: loss did not improve from 1.42189
# Epoch 67/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4231 - accuracy: 0.7098 - val_loss: 2.1787 - val_accuracy: 0.5998
#
# Epoch 00067: loss did not improve from 1.42189
# Epoch 68/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4166 - accuracy: 0.7101 - val_loss: 2.2519 - val_accuracy: 0.5810
#
# Epoch 00068: loss improved from 1.42189 to 1.41662, saving model to checkpoint/cp.ckpt
# Epoch 69/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4190 - accuracy: 0.7109 - val_loss: 2.2223 - val_accuracy: 0.5918
#
# Epoch 00069: loss did not improve from 1.41662
# Epoch 70/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4089 - accuracy: 0.7139 - val_loss: 2.2355 - val_accuracy: 0.5850
#
# Epoch 00070: loss improved from 1.41662 to 1.40888, saving model to checkpoint/cp.ckpt
# Epoch 71/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4095 - accuracy: 0.7130 - val_loss: 2.2614 - val_accuracy: 0.5807
#
# Epoch 00071: loss did not improve from 1.40888
# Epoch 72/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4121 - accuracy: 0.7110 - val_loss: 2.2369 - val_accuracy: 0.5838
#
# Epoch 00072: loss did not improve from 1.40888
# Epoch 73/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4054 - accuracy: 0.7130 - val_loss: 2.2017 - val_accuracy: 0.5969
#
# Epoch 00073: loss improved from 1.40888 to 1.40536, saving model to checkpoint/cp.ckpt
# Epoch 74/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4035 - accuracy: 0.7124 - val_loss: 2.2369 - val_accuracy: 0.5823
#
# Epoch 00074: loss improved from 1.40536 to 1.40351, saving model to checkpoint/cp.ckpt
# Epoch 75/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4045 - accuracy: 0.7142 - val_loss: 2.2291 - val_accuracy: 0.5895
#
# Epoch 00075: loss did not improve from 1.40351
# Epoch 76/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.4038 - accuracy: 0.7127 - val_loss: 2.2244 - val_accuracy: 0.5938
#
# Epoch 00076: loss did not improve from 1.40351
# Epoch 77/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3979 - accuracy: 0.7134 - val_loss: 2.2359 - val_accuracy: 0.5895
#
# Epoch 00077: loss improved from 1.40351 to 1.39789, saving model to checkpoint/cp.ckpt
# Epoch 78/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3958 - accuracy: 0.7136 - val_loss: 2.2262 - val_accuracy: 0.5872
#
# Epoch 00078: loss improved from 1.39789 to 1.39578, saving model to checkpoint/cp.ckpt
# Epoch 79/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3958 - accuracy: 0.7142 - val_loss: 2.2434 - val_accuracy: 0.5841
#
# Epoch 00079: loss improved from 1.39578 to 1.39576, saving model to checkpoint/cp.ckpt
# Epoch 80/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3973 - accuracy: 0.7146 - val_loss: 2.2436 - val_accuracy: 0.5818
#
# Epoch 00080: loss did not improve from 1.39576
# Epoch 81/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3945 - accuracy: 0.7138 - val_loss: 2.2201 - val_accuracy: 0.5903
#
# Epoch 00081: loss improved from 1.39576 to 1.39449, saving model to checkpoint/cp.ckpt
# Epoch 82/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3952 - accuracy: 0.7134 - val_loss: 2.2239 - val_accuracy: 0.5902
#
# Epoch 00082: loss did not improve from 1.39449
# Epoch 83/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3897 - accuracy: 0.7171 - val_loss: 2.2630 - val_accuracy: 0.5824
#
# Epoch 00083: loss improved from 1.39449 to 1.38973, saving model to checkpoint/cp.ckpt
# Epoch 84/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3859 - accuracy: 0.7166 - val_loss: 2.2413 - val_accuracy: 0.5873
#
# Epoch 00084: loss improved from 1.38973 to 1.38589, saving model to checkpoint/cp.ckpt
# Epoch 85/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3857 - accuracy: 0.7165 - val_loss: 2.2351 - val_accuracy: 0.5886
#
# Epoch 00085: loss improved from 1.38589 to 1.38566, saving model to checkpoint/cp.ckpt
# Epoch 86/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3878 - accuracy: 0.7163 - val_loss: 2.2670 - val_accuracy: 0.5810
#
# Epoch 00086: loss did not improve from 1.38566
# Epoch 87/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3794 - accuracy: 0.7176 - val_loss: 2.2182 - val_accuracy: 0.5974
#
# Epoch 00087: loss improved from 1.38566 to 1.37937, saving model to checkpoint/cp.ckpt
# Epoch 88/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3835 - accuracy: 0.7174 - val_loss: 2.2085 - val_accuracy: 0.5999
#
# Epoch 00088: loss did not improve from 1.37937
# Epoch 89/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3746 - accuracy: 0.7177 - val_loss: 2.2417 - val_accuracy: 0.5874
#
# Epoch 00089: loss improved from 1.37937 to 1.37463, saving model to checkpoint/cp.ckpt
# Epoch 90/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3782 - accuracy: 0.7178 - val_loss: 2.2022 - val_accuracy: 0.5978
#
# Epoch 00090: loss did not improve from 1.37463
# Epoch 91/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3710 - accuracy: 0.7191 - val_loss: 2.3062 - val_accuracy: 0.5663
#
# Epoch 00091: loss improved from 1.37463 to 1.37105, saving model to checkpoint/cp.ckpt
# Epoch 92/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3729 - accuracy: 0.7178 - val_loss: 2.2189 - val_accuracy: 0.5975
#
# Epoch 00092: loss did not improve from 1.37105
# Epoch 93/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3730 - accuracy: 0.7192 - val_loss: 2.2882 - val_accuracy: 0.5734
#
# Epoch 00093: loss did not improve from 1.37105
# Epoch 94/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3709 - accuracy: 0.7181 - val_loss: 2.2712 - val_accuracy: 0.5799
#
# Epoch 00094: loss improved from 1.37105 to 1.37086, saving model to checkpoint/cp.ckpt
# Epoch 95/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3715 - accuracy: 0.7175 - val_loss: 2.2388 - val_accuracy: 0.5865
#
# Epoch 00095: loss did not improve from 1.37086
# Epoch 96/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3678 - accuracy: 0.7181 - val_loss: 2.2689 - val_accuracy: 0.5835
#
# Epoch 00096: loss improved from 1.37086 to 1.36780, saving model to checkpoint/cp.ckpt
# Epoch 97/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3690 - accuracy: 0.7193 - val_loss: 2.2365 - val_accuracy: 0.5902
#
# Epoch 00097: loss did not improve from 1.36780
# Epoch 98/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3658 - accuracy: 0.7199 - val_loss: 2.2554 - val_accuracy: 0.5826
#
# Epoch 00098: loss improved from 1.36780 to 1.36577, saving model to checkpoint/cp.ckpt
# Epoch 99/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3596 - accuracy: 0.7201 - val_loss: 2.2792 - val_accuracy: 0.5771
#
# Epoch 00099: loss improved from 1.36577 to 1.35961, saving model to checkpoint/cp.ckpt
# Epoch 100/100
# 508/508 [==============================] - 8s 16ms/step - loss: 1.3577 - accuracy: 0.7203 - val_loss: 2.2280 - val_accuracy: 0.5940
#
# Epoch 00100: loss improved from 1.35961 to 1.35770, saving model to checkpoint/cp.ckpt

# %%
# 저장한 모델 불러오기
for i in range(5):
    globals()[f'model{i}'] = load_model(f'models/model_{i}.h5')

# %%
model0._name = 'Client1'
model1._name = 'Client2'
model2._name = 'Client3'
model3._name = 'Client4'

# %%
inputs = Input(shape=(600, len_features))

merge = concatenate([model0(inputs), model1(inputs), model2(inputs), model3(inputs), model4(inputs)])
hidden = Dense(10, activation='relu')(merge)
output = Dense(61, activation='softmax')(hidden)

model = Model(inputs=inputs, outputs=output)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
checkpoint_path = "checkpoint/cp.ckpt"
cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_loss', patience=20, mode='min')
model.fit(X, y, epochs=epochs, batch_size=batch_size, validation_split=0.02, callbacks=[early_stopping, cp_callback])
# Out:
# Epoch 1/100
# 623/623 [==============================] - 31s 43ms/step - loss: 2.6270 - accuracy: 0.4936 - val_loss: 2.6620 - val_accuracy: 0.4859
#
# Epoch 00001: val_loss improved from inf to 2.66198, saving model to checkpoint/cp.ckpt
# Epoch 2/100
# 623/623 [==============================] - 26s 42ms/step - loss: 2.0311 - accuracy: 0.5765 - val_loss: 2.6934 - val_accuracy: 0.4723
#
# Epoch 00002: val_loss did not improve from 2.66198
# Epoch 3/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.8218 - accuracy: 0.6354 - val_loss: 2.7481 - val_accuracy: 0.4551
#
# Epoch 00003: val_loss did not improve from 2.66198
# Epoch 4/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.7073 - accuracy: 0.6624 - val_loss: 2.7611 - val_accuracy: 0.4588
#
# Epoch 00004: val_loss did not improve from 2.66198
# Epoch 5/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.6343 - accuracy: 0.6844 - val_loss: 2.8006 - val_accuracy: 0.4453
#
# Epoch 00005: val_loss did not improve from 2.66198
# Epoch 6/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.5873 - accuracy: 0.6941 - val_loss: 2.8067 - val_accuracy: 0.4490
#
# Epoch 00006: val_loss did not improve from 2.66198
# Epoch 7/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.5555 - accuracy: 0.6998 - val_loss: 2.8728 - val_accuracy: 0.4379
#
# Epoch 00007: val_loss did not improve from 2.66198
# Epoch 8/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.5304 - accuracy: 0.7085 - val_loss: 2.8940 - val_accuracy: 0.4231
#
# Epoch 00008: val_loss did not improve from 2.66198
# Epoch 9/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.5077 - accuracy: 0.7090 - val_loss: 2.9216 - val_accuracy: 0.4367
#
# Epoch 00009: val_loss did not improve from 2.66198
# Epoch 10/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4951 - accuracy: 0.7108 - val_loss: 2.9210 - val_accuracy: 0.4440
#
# Epoch 00010: val_loss did not improve from 2.66198
# Epoch 11/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4797 - accuracy: 0.7152 - val_loss: 2.9351 - val_accuracy: 0.4440
#
# Epoch 00011: val_loss did not improve from 2.66198
# Epoch 12/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4651 - accuracy: 0.7157 - val_loss: 2.9507 - val_accuracy: 0.4428
#
# Epoch 00012: val_loss did not improve from 2.66198
# Epoch 13/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4505 - accuracy: 0.7194 - val_loss: 2.9635 - val_accuracy: 0.4379
#
# Epoch 00013: val_loss did not improve from 2.66198
# Epoch 14/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4449 - accuracy: 0.7202 - val_loss: 2.9433 - val_accuracy: 0.4403
#
# Epoch 00014: val_loss did not improve from 2.66198
# Epoch 15/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4340 - accuracy: 0.7235 - val_loss: 2.9667 - val_accuracy: 0.4403
#
# Epoch 00015: val_loss did not improve from 2.66198
# Epoch 16/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4202 - accuracy: 0.7253 - val_loss: 2.9491 - val_accuracy: 0.4354
#
# Epoch 00016: val_loss did not improve from 2.66198
# Epoch 17/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4098 - accuracy: 0.7280 - val_loss: 2.9023 - val_accuracy: 0.4465
#
# Epoch 00017: val_loss did not improve from 2.66198
# Epoch 18/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.4012 - accuracy: 0.7315 - val_loss: 2.9831 - val_accuracy: 0.4367
#
# Epoch 00018: val_loss did not improve from 2.66198
# Epoch 19/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3945 - accuracy: 0.7322 - val_loss: 2.9987 - val_accuracy: 0.4317
#
# Epoch 00019: val_loss did not improve from 2.66198
# Epoch 20/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3902 - accuracy: 0.7327 - val_loss: 2.8994 - val_accuracy: 0.4502
#
# Epoch 00020: val_loss did not improve from 2.66198
# Epoch 21/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3754 - accuracy: 0.7351 - val_loss: 2.9535 - val_accuracy: 0.4342
#
# Epoch 00021: val_loss did not improve from 2.66198
# Epoch 22/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3713 - accuracy: 0.7349 - val_loss: 2.9098 - val_accuracy: 0.4514
#
# Epoch 00022: val_loss did not improve from 2.66198
# Epoch 23/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3633 - accuracy: 0.7375 - val_loss: 3.0052 - val_accuracy: 0.4268
#
# Epoch 00023: val_loss did not improve from 2.66198
# Epoch 24/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3605 - accuracy: 0.7372 - val_loss: 3.0080 - val_accuracy: 0.4219
#
# Epoch 00024: val_loss did not improve from 2.66198
# Epoch 25/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3514 - accuracy: 0.7387 - val_loss: 3.0072 - val_accuracy: 0.4403
#
# Epoch 00025: val_loss did not improve from 2.66198
# Epoch 26/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3471 - accuracy: 0.7406 - val_loss: 2.9748 - val_accuracy: 0.4391
#
# Epoch 00026: val_loss did not improve from 2.66198
# Epoch 27/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3461 - accuracy: 0.7408 - val_loss: 3.0325 - val_accuracy: 0.4453
#
# Epoch 00027: val_loss did not improve from 2.66198
# Epoch 28/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3426 - accuracy: 0.7404 - val_loss: 3.0458 - val_accuracy: 0.4379
#
# Epoch 00028: val_loss did not improve from 2.66198
# Epoch 29/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3356 - accuracy: 0.7421 - val_loss: 2.9755 - val_accuracy: 0.4428
#
# Epoch 00029: val_loss did not improve from 2.66198
# Epoch 30/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3292 - accuracy: 0.7439 - val_loss: 3.0400 - val_accuracy: 0.4416
#
# Epoch 00030: val_loss did not improve from 2.66198
# Epoch 31/100
# 623/623 [==============================] - 26s 42ms/step - loss: 1.3194 - accuracy: 0.7441 - val_loss: 3.0177 - val_accuracy: 0.4490
#
# Epoch 00031: val_loss did not improve from 2.66198

# %%
prediction = model.predict(test_X)
prediction.shape

# %%
submission

# %%
submission.iloc[:,1:]=prediction

# %%
submission

# %%
submission.to_csv('submission/just_cnn_stacked_5(jun).csv', index=False)
