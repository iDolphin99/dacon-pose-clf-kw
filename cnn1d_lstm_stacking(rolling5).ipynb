# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# %%
# 기본 directory 설정
import os
os.chdir('/content/drive/MyDrive/Monthly_Workout')

# %%
# 모듈 불러오기
import random
import pandas as pd
import numpy as np
from tqdm import tqdm
from math import pi

# %%
# 데이터 불러오기
path = './' # 기본 directory 경로에 추가 할 경로

train = pd.read_csv(path + 'train_features.csv')
train_labels = pd.read_csv(path + 'train_labels.csv')
test = pd.read_csv(path + 'test_features.csv')
submission = pd.read_csv(path + 'sample_submission.csv')

train
# Out:
#            id  time     acc_x     acc_y     acc_z       gy_x        gy_y  \
# 0           0     0  1.206087 -0.179371 -0.148447  -0.591608  -30.549010
# 1           0     1  1.287696 -0.198974 -0.182444   0.303100  -39.139103
# 2           0     2  1.304609 -0.195114 -0.253382  -3.617278  -44.122565
# 3           0     3  1.293095 -0.230366 -0.215210   2.712986  -53.597843
# 4           0     4  1.300887 -0.187757 -0.222523   4.286707  -57.906561
# ...       ...   ...       ...       ...       ...        ...         ...
# 1874995  3124   595 -0.712530 -0.658357  0.293707 -29.367857 -104.013664
# 1874996  3124   596 -0.683037 -0.658466  0.329223 -30.149089 -101.796809
# 1874997  3124   597 -0.664730 -0.666625  0.364114 -27.873095  -98.776072
# 1874998  3124   598 -0.630534 -0.682565  0.373696 -23.636550  -99.139495
# 1874999  3124   599 -0.578351 -0.700235  0.384390 -17.917626 -100.181873
#
#               gy_z
# 0       -31.676112
# 1       -24.927216
# 2       -25.019629
# 3       -27.454013
# 4       -27.961234
# ...            ...
# 1874995 -76.290437
# 1874996 -76.625087
# 1874997 -79.365125
# 1874998 -80.259478
# 1874999 -80.676229
#
# [1875000 rows x 8 columns]

# %%
act_list=train.iloc[:,2:].columns
acc_list=['acc_x','acc_y','acc_z']
gy_list=['gy_x','gy_y','gy_z']
act_list
# Out:
# Index(['acc_x', 'acc_y', 'acc_z', 'gy_x', 'gy_y', 'gy_z'], dtype='object')

# %%
# acc 데이터와 gy 데이터로 분할
def sensor_split(data):
    X_acc = []
    X_gy = []

    for i in tqdm(data['id'].unique()):
        temp_acc = np.array(data[data['id'] == i].loc[:,acc_list])
        temp_gy = np.array(data[data['id'] == i].loc[:,gy_list])
        X_acc.append(temp_acc)
        X_gy.append(temp_gy)
      
    X_acc = np.array(X_acc).reshape(-1,600,3)
    X_gy = np.array(X_gy).reshape(-1,600,3)

    return X_acc, X_gy

# %%
# 데이터 증강

def permutation(X, nPerm=4, minSegLength=10):
    X_new = np.zeros(X.shape)
    idx = np.random.permutation(nPerm)
    bWhile = True
    while bWhile == True:
        segs = np.zeros(nPerm+1, dtype=int)
        segs[1:-1] = np.sort(np.random.randint(minSegLength, X.shape[0]-minSegLength, nPerm-1))
        segs[-1] = X.shape[0]
        if np.min(segs[1:]-segs[0:-1]) > minSegLength:
            bWhile = False
    pp = 0
    for ii in range(nPerm):
        x_temp = X[segs[idx[ii]]:segs[idx[ii]+1],:]
        X_new[pp:pp+len(x_temp),:] = x_temp
        pp += len(x_temp)
    return (X_new)

def aug(data, uid, shift):
    shift_data = np.roll(data[uid], shift, axis=0)
    return shift_data

def rolling(data):
    aug_data=[]
    for i in range(data.shape[0]):
        temp=list((aug(data,i,int(random.random()*600))))
        aug_data.append(temp)
    return np.array(aug_data)

# %%
# 데이터 증강 (반복하고 싶은 만큼 조정)
def start_augmentation(train, train_labels):
    # acc, gy 데이터 분할
    X_train_mod=pd.merge(train,train_labels,how='left',on='id')
    X_train_acc, X_train_gy= sensor_split(X_train_mod)

    # 증강시키고 추가할 임시 데이터 복사본
    X_train_acc_temp = X_train_acc.copy()
    X_train_gy_temp = X_train_gy.copy()

    # label 데이터 변환
    y_train = train_labels['label']
    y_train_total = np.append(y_train, y_train, axis=0)

    rep = 5 # 5이상의 경우 reshape 과정에서 reset될 가능성 높음
    for i in range(rep):
        X_train_acc_roll = rolling(X_train_acc_temp)
        X_train_gy_roll = rolling(X_train_gy_temp)

        # 증강시킨 데이터 원래 데이터에 추가
        X_train_acc = np.append(X_train_acc, X_train_acc_roll, axis=0)
        X_train_gy = np.append(X_train_gy, X_train_gy_roll, axis=0)

        if i != (rep-1): # 마지막 한 번 제외
            y_train_total = np.append(y_train_total, y_train, axis=0)

    return X_train_acc, X_train_gy, y_train_total

# %%
X_train_acc, X_train_gy, y_train_total = start_augmentation(train, train_labels)

X_train_acc.shape, X_train_gy.shape, y_train_total.shape
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 3125/3125 [00:20<00:00, 155.70it/s]
# ((18750, 600, 3), (18750, 600, 3), (18750,))

# %%
# np array 형태를 dataframe 으로 변환
def np_to_df(X_train_acc, X_train_gy):
    acc = [e for sl in X_train_acc for e in sl]
    gy = [e for sl in X_train_gy for e in sl]

    df_report_acc = np.stack(acc, axis = 0)
    df_report_gy = np.stack(gy, axis = 0)

    df_acc = pd.DataFrame(df_report_acc, columns= ['acc_x', 'acc_y', 'acc_z']) 
    df_gy = pd.DataFrame(df_report_gy, columns= ['gy_x', 'gy_y', 'gy_z']) 

    # acc, gy 데이터프레임 병합
    df_aug_result = pd.concat([df_acc, df_gy], axis = 1)
    
    return df_aug_result

# %%
train = np_to_df(X_train_acc, X_train_gy)
train
# Out:
#              acc_x     acc_y     acc_z       gy_x       gy_y       gy_z
# 0         1.206087 -0.179371 -0.148447  -0.591608 -30.549010 -31.676112
# 1         1.287696 -0.198974 -0.182444   0.303100 -39.139103 -24.927216
# 2         1.304609 -0.195114 -0.253382  -3.617278 -44.122565 -25.019629
# 3         1.293095 -0.230366 -0.215210   2.712986 -53.597843 -27.454013
# 4         1.300887 -0.187757 -0.222523   4.286707 -57.906561 -27.961234
# ...            ...       ...       ...        ...        ...        ...
# 11249995 -0.992952 -0.321013 -0.090105  18.091944  79.130873  63.858367
# 11249996 -0.979069 -0.240940 -0.089751  16.734111  80.703429  61.247504
# 11249997 -0.948902 -0.197942 -0.110383  16.194187  80.104061  59.666932
# 11249998 -0.944806 -0.314007 -0.122991  26.457620  80.460091  57.722090
# 11249999 -0.976672 -0.466292 -0.133375  26.790743  84.888956  53.714246
#
# [11250000 rows x 6 columns]

# %%
# 가속도
train['acc_t'] = (train['acc_x'] ** 2) + (train['acc_y'] ** 2) + (train['acc_z'] ** 2) ** (1/3)
test['acc_t'] = (test['acc_x'] ** 2) + (test['acc_y'] ** 2) + (test['acc_z'] ** 2) ** (1/3)

train['gy_t'] = (train['gy_x'] ** 2) + (train['gy_y'] ** 2) + (train['gy_z'] ** 2) ** (1/3)
test['gy_t'] = (test['gy_x'] ** 2) + (test['gy_y'] ** 2) + (test['gy_z'] ** 2) ** (1/3)

# Signal 극대화 (peak 캐치 유용)
train['acc_mag'] = (train['acc_x'] ** 2) + (train['acc_y'] ** 2) + (train['acc_z'] ** 2)
test['acc_mag'] = (test['acc_x'] ** 2) + (test['acc_y'] ** 2) + (test['acc_z'] ** 2)

train['gy_mag'] = (train['gy_x'] ** 2) + (train['gy_y'] ** 2) + (train['gy_z'] ** 2)
test['gy_mag'] = (test['gy_x'] ** 2) + (test['gy_y'] ** 2) + (test['gy_z'] ** 2)

# %%
# vector
train['acc_vec'] = np.sqrt((train['acc_x'] ** 2) +(train['acc_y'] ** 2)+(train['acc_z'] ** 2))
test['acc_vec'] = np.sqrt((test['acc_x'] ** 2) +(test['acc_y'] ** 2)+(test['acc_z'] ** 2))

train['gy_vec'] = np.sqrt((train['gy_x'] ** 2) +(train['gy_y'] ** 2)+(train['gy_z'] ** 2))
test['gy_vec'] = np.sqrt((test['gy_x'] ** 2) +(test['gy_y'] ** 2)+(test['gy_z'] ** 2))

# 자이로스코프 무게중심
train['gy_gravity'] = (train['gy_x']+train['gy_y']+train['gy_z'])/3
test['gy_gravity'] = (test['gy_x']+test['gy_y']+test['gy_z'])/3

# %%
# roll & pitch
train['roll'] = np.arctan(train['acc_y']/np.sqrt(train['acc_x'] ** 2 + train['acc_z'] ** 2))
test['roll'] = np.arctan(test['acc_y']/np.sqrt(test['acc_x'] ** 2 + test['acc_z'] ** 2))

train['pitch'] = np.arctan(train['acc_x']/np.sqrt(train['acc_y'] ** 2 + train['acc_z'] ** 2))
test['pitch'] = np.arctan(test['acc_x']/np.sqrt(test['acc_y'] ** 2 + test['acc_z'] ** 2))

train['math_roll'] = np.arctan(- train['acc_x']/np.sqrt(train['acc_y'] ** 2 + train['acc_z'] ** 2)) * (180/pi)
test['math_roll'] = np.arctan(- test['acc_x']/np.sqrt(test['acc_y'] ** 2 + test['acc_z'] ** 2)) * (180/pi)

train['math_pitch'] = np.arctan(train['acc_y']/np.sqrt(train['acc_x'] ** 2 + train['acc_z'] ** 2)) * (180/pi)
test['math_pitch'] = np.arctan(test['acc_y']/np.sqrt(test['acc_x'] ** 2 + test['acc_z'] ** 2)) * (180/pi)

train['gy_roll'] = np.arctan(train['gy_y']/np.sqrt(train['gy_x'] ** 2 + train['gy_z'] ** 2))
test['gy_roll'] = np.arctan(test['gy_y']/np.sqrt(test['gy_x'] ** 2 + test['gy_z'] ** 2))

train['gy_pitch'] = np.arctan(train['gy_x']/np.sqrt(train['gy_y'] ** 2 + train['gy_z'] ** 2))
test['gy_pitch'] = np.arctan(test['gy_x']/np.sqrt(test['gy_y'] ** 2 + test['gy_z'] ** 2))

train['gy_math_roll'] = np.arctan(- train['gy_x']/np.sqrt(train['gy_y'] ** 2 + train['gy_z'] ** 2)) * (180/pi)
test['gy_math_roll'] = np.arctan(- test['gy_x']/np.sqrt(test['gy_y'] ** 2 + test['gy_z'] ** 2)) * (180/pi)

train['gy_math_pitch'] = np.arctan(train['gy_y']/np.sqrt(train['gy_x'] ** 2 + train['gy_z'] ** 2)) * (180/pi)
test['gy_math_pitch'] = np.arctan(test['gy_y']/np.sqrt(test['gy_x'] ** 2 + test['gy_z'] ** 2)) * (180/pi)

print(train.shape)
train
# Out:
# (11250000, 21)
#              acc_x     acc_y     acc_z       gy_x       gy_y       gy_z  \
# 0         1.206087 -0.179371 -0.148447  -0.591608 -30.549010 -31.676112
# 1         1.287696 -0.198974 -0.182444   0.303100 -39.139103 -24.927216
# 2         1.304609 -0.195114 -0.253382  -3.617278 -44.122565 -25.019629
# 3         1.293095 -0.230366 -0.215210   2.712986 -53.597843 -27.454013
# 4         1.300887 -0.187757 -0.222523   4.286707 -57.906561 -27.961234
# ...            ...       ...       ...        ...        ...        ...
# 11249995 -0.992952 -0.321013 -0.090105  18.091944  79.130873  63.858367
# 11249996 -0.979069 -0.240940 -0.089751  16.734111  80.703429  61.247504
# 11249997 -0.948902 -0.197942 -0.110383  16.194187  80.104061  59.666932
# 11249998 -0.944806 -0.314007 -0.122991  26.457620  80.460091  57.722090
# 11249999 -0.976672 -0.466292 -0.133375  26.790743  84.888956  53.714246
#
#              acc_t         gy_t   acc_mag        gy_mag  ...      gy_vec  \
# 0         1.767177   943.603223  1.508855   1936.968046  ...   44.010999
# 1         2.019429  1540.494535  1.731038   2153.327355  ...   46.403958
# 2         2.140496  1968.439749  1.804277   2585.867212  ...   50.851423
# 3         2.084285  2889.189647  1.771478   3633.811839  ...   60.281107
# 4         2.094771  3380.757973  1.777076   4153.376248  ...   64.446693
# ...            ...          ...       ...           ...  ...         ...
# 11249995  1.289989  6604.989949  1.097122  10666.904631  ...  103.280708
# 11249996  1.217087  6808.611865  1.024683  10544.330665  ...  102.685591
# 11249997  1.169706  6694.181743  0.951781  10239.055139  ...  101.188216
# 11249998  1.238573  7188.767624  1.006386  10505.671508  ...  102.497178
# 11249999  1.432360  7938.114949  1.189104  10809.098974  ...  103.966817
#
#           gy_gravity      roll     pitch  math_roll  math_pitch   gy_roll  \
# 0         -20.938910 -0.146550  1.380095 -79.073624   -8.396683 -0.767200
# 1         -21.254406 -0.151814  1.364146 -78.159835   -8.698302 -1.003661
# 2         -24.253157 -0.145773  1.330405 -76.226605   -8.352177 -1.050508
# 3         -26.112956 -0.173958  1.331665 -76.298763   -9.967037 -1.095444
# 4         -27.193696 -0.141316  1.350615 -77.384519   -8.096783 -1.116383
# ...              ...       ...       ...        ...         ...       ...
# 11249995   53.693728 -0.311487 -1.246841  71.438699  -17.846914  0.872864
# 11249996   52.895015 -0.240327 -1.313985  75.285820  -13.769703  0.904195
# 11249997   51.988394 -0.204312 -1.336345  76.566941  -11.706243  0.913479
# 11249998   54.879934 -0.318360 -1.227957  70.356740  -18.240658  0.902693
# 11249999   55.131315 -0.441847 -1.109892  63.592117  -25.315974  0.955323
#
#           gy_pitch  gy_math_roll  gy_math_pitch
# 0        -0.013443      0.770209     -43.957305
# 1         0.006532     -0.374246     -57.505519
# 2        -0.071194      4.079137     -60.189701
# 3         0.045021     -2.579501     -62.764338
# 4         0.066565     -3.813876     -63.964038
# ...            ...           ...            ...
# 11249995  0.176081    -10.088699      50.011446
# 11249996  0.163695     -9.379012      51.806541
# 11249997  0.160731     -9.209232      52.338501
# 11249998  0.261086    -14.959145      51.720503
# 11249999  0.260626    -14.932773      54.735998
#
# [11250000 rows x 21 columns]

# %%
# Scaling 원하는 걸로 사용
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
train = scaler.fit_transform(train)
test.drop(['id', 'time'], axis=1, inplace=True)
test = scaler.transform(test)
train
# Out:
# array([[ 1.93489817,  0.03657354, -0.31330862, ...,  0.05924213,
#         -0.05924213, -0.71658616],
#        [ 2.01969699,  0.00673528, -0.37289479, ...,  0.07768724,
#         -0.07768724, -0.94204715],
#        [ 2.0372705 ,  0.01260973, -0.49722803, ...,  0.0059123 ,
#         -0.0059123 , -0.98671563],
#        ...,
#        [-0.30429759,  0.0083059 , -0.24659414, ...,  0.22008025,
#         -0.22008025,  0.88590903],
#        [-0.30004125, -0.16836605, -0.26869281, ...,  0.31275131,
#         -0.31275131,  0.87562469],
#        [-0.33315173, -0.40017154, -0.28689203, ...,  0.31232627,
#         -0.31232627,  0.92580668]])

# %%
import tensorflow as tf 
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Input
from keras.layers import TimeDistributed
from keras.layers import Activation, GlobalAveragePooling1D
from keras.layers import Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from keras.models import load_model
from keras.layers.merge import concatenate

# %%
len_features = train.shape[1] # feature 갯수
X = train.reshape(-1, 600, len_features)
X.shape
# Out:
# (18750, 600, 21)

# %%
y = to_categorical(y_train_total)
y.shape
# Out:
# (18750, 61)

# %%
epochs, batch_size = 100, 64 # Ram 24GB 기준 256 이상 reset될 가능성 높음

# %%
test_X = test.reshape(-1, 600, len_features)
test_X.shape
# Out:
# (782, 600, 21)

# %%
pd.DataFrame(train).to_csv('model(1)_train.csv')

# %%
pd.DataFrame(y_train_total).to_csv('model(1)y_train_total.csv')
pd.DataFrame(test).to_csv('model(1)_test.csv')

# %%
#epochs, batch_size = 30, 64
n_features, n_outputs = X.shape[2], y.shape[1]
# reshape data into time steps of sub-sequences
n_steps, n_length = 6, 100
X = X.reshape((X.shape[0], n_steps, n_length, n_features))
test_X = test_X.reshape((test_X.shape[0], n_steps, n_length, n_features))

# %%
class Models:
    # 각종 사이즈는 다양하게 적용하여 stacking 쌓아 올리기
    def define_model_0():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_1():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_2():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu')))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_3():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.3))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_4():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

# %%
# 위의 모델들 학습하면서 stacking
for i in range(5):
    model = getattr(Models, f'define_model_{i}')()
    checkpoint_path = "checkpoint/cp.ckpt"
    
    cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', 
                                verbose=1, save_weights_only=True, 
                                save_best_only=True, mode='min')
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min', verbose=1)
    
    model.fit(X, y, epochs=epochs, batch_size=batch_size, 
            validation_split=0.2, callbacks=[early_stopping, cp_callback])
    model.save(f'models/211008(1)_model_{i}.h5')
    tf.keras.backend.clear_session()
# Out:
# Epoch 1/100
# 235/235 [==============================] - 50s 184ms/step - loss: 2.4053 - accuracy: 0.5014 - val_loss: 1.8790 - val_accuracy: 0.5651
#
# Epoch 00001: val_loss improved from inf to 1.87897, saving model to checkpoint\cp.ckpt
# Epoch 2/100
# 235/235 [==============================] - 40s 171ms/step - loss: 1.7853 - accuracy: 0.5519 - val_loss: 1.4718 - val_accuracy: 0.6192
#
# Epoch 00002: val_loss improved from 1.87897 to 1.47184, saving model to checkpoint\cp.ckpt
# Epoch 3/100
# 235/235 [==============================] - 40s 169ms/step - loss: 1.5130 - accuracy: 0.5959 - val_loss: 1.2222 - val_accuracy: 0.6691
#
# Epoch 00003: val_loss improved from 1.47184 to 1.22217, saving model to checkpoint\cp.ckpt
# Epoch 4/100
# 235/235 [==============================] - 39s 168ms/step - loss: 1.3352 - accuracy: 0.6310 - val_loss: 1.0489 - val_accuracy: 0.7075
#
# Epoch 00004: val_loss improved from 1.22217 to 1.04888, saving model to checkpoint\cp.ckpt
# Epoch 5/100
# 235/235 [==============================] - 40s 169ms/step - loss: 1.2177 - accuracy: 0.6532 - val_loss: 0.9752 - val_accuracy: 0.7125
#
# Epoch 00005: val_loss improved from 1.04888 to 0.97517, saving model to checkpoint\cp.ckpt
# Epoch 6/100
# 235/235 [==============================] - 39s 168ms/step - loss: 1.1229 - accuracy: 0.6743 - val_loss: 0.8752 - val_accuracy: 0.7437
#
# Epoch 00006: val_loss improved from 0.97517 to 0.87522, saving model to checkpoint\cp.ckpt
# Epoch 7/100
# 235/235 [==============================] - 40s 170ms/step - loss: 1.0663 - accuracy: 0.6875 - val_loss: 0.8476 - val_accuracy: 0.7533
#
# Epoch 00007: val_loss improved from 0.87522 to 0.84764, saving model to checkpoint\cp.ckpt
# Epoch 8/100
# 235/235 [==============================] - 39s 168ms/step - loss: 1.0014 - accuracy: 0.7009 - val_loss: 0.7962 - val_accuracy: 0.7576
#
# Epoch 00008: val_loss improved from 0.84764 to 0.79615, saving model to checkpoint\cp.ckpt
# Epoch 9/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.9825 - accuracy: 0.7047 - val_loss: 0.7318 - val_accuracy: 0.7744
#
# Epoch 00009: val_loss improved from 0.79615 to 0.73176, saving model to checkpoint\cp.ckpt
# Epoch 10/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.9344 - accuracy: 0.7191 - val_loss: 0.7383 - val_accuracy: 0.7755
#
# Epoch 00010: val_loss did not improve from 0.73176
# Epoch 11/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.8946 - accuracy: 0.7299 - val_loss: 0.6712 - val_accuracy: 0.7912
#
# Epoch 00011: val_loss improved from 0.73176 to 0.67121, saving model to checkpoint\cp.ckpt
# Epoch 12/100
# 235/235 [==============================] - 40s 172ms/step - loss: 0.8704 - accuracy: 0.7350 - val_loss: 0.6549 - val_accuracy: 0.7861
#
# Epoch 00012: val_loss improved from 0.67121 to 0.65493, saving model to checkpoint\cp.ckpt
# Epoch 13/100
# 235/235 [==============================] - 39s 168ms/step - loss: 0.8460 - accuracy: 0.7434 - val_loss: 0.6101 - val_accuracy: 0.8029
#
# Epoch 00013: val_loss improved from 0.65493 to 0.61009, saving model to checkpoint\cp.ckpt
# Epoch 14/100
# 235/235 [==============================] - 39s 167ms/step - loss: 0.8073 - accuracy: 0.7518 - val_loss: 0.6088 - val_accuracy: 0.8085
#
# Epoch 00014: val_loss improved from 0.61009 to 0.60881, saving model to checkpoint\cp.ckpt
# Epoch 15/100
# 235/235 [==============================] - 40s 168ms/step - loss: 0.7970 - accuracy: 0.7551 - val_loss: 0.5731 - val_accuracy: 0.8197
#
# Epoch 00015: val_loss improved from 0.60881 to 0.57314, saving model to checkpoint\cp.ckpt
# Epoch 16/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.7746 - accuracy: 0.7617 - val_loss: 0.5830 - val_accuracy: 0.8141
#
# Epoch 00016: val_loss did not improve from 0.57314
# Epoch 17/100
# 235/235 [==============================] - 39s 167ms/step - loss: 0.7326 - accuracy: 0.7685 - val_loss: 0.5690 - val_accuracy: 0.8155
#
# Epoch 00017: val_loss improved from 0.57314 to 0.56904, saving model to checkpoint\cp.ckpt
# Epoch 18/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.7322 - accuracy: 0.7695 - val_loss: 0.5645 - val_accuracy: 0.8192
#
# Epoch 00018: val_loss improved from 0.56904 to 0.56452, saving model to checkpoint\cp.ckpt
# Epoch 19/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.7166 - accuracy: 0.7740 - val_loss: 0.5376 - val_accuracy: 0.8285
#
# Epoch 00019: val_loss improved from 0.56452 to 0.53756, saving model to checkpoint\cp.ckpt
# Epoch 20/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.6864 - accuracy: 0.7791 - val_loss: 0.5119 - val_accuracy: 0.8285
#
# Epoch 00020: val_loss improved from 0.53756 to 0.51195, saving model to checkpoint\cp.ckpt
# Epoch 21/100
# 235/235 [==============================] - 40s 168ms/step - loss: 0.6711 - accuracy: 0.7859 - val_loss: 0.4704 - val_accuracy: 0.8485
#
# Epoch 00021: val_loss improved from 0.51195 to 0.47041, saving model to checkpoint\cp.ckpt
# Epoch 22/100
# 235/235 [==============================] - 39s 168ms/step - loss: 0.6685 - accuracy: 0.7879 - val_loss: 0.5144 - val_accuracy: 0.8347
#
# Epoch 00022: val_loss did not improve from 0.47041
# Epoch 23/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.6443 - accuracy: 0.7951 - val_loss: 0.4659 - val_accuracy: 0.8467
#
# Epoch 00023: val_loss improved from 0.47041 to 0.46594, saving model to checkpoint\cp.ckpt
# Epoch 24/100
# 235/235 [==============================] - 41s 173ms/step - loss: 0.6375 - accuracy: 0.7950 - val_loss: 0.4781 - val_accuracy: 0.8427
#
# Epoch 00024: val_loss did not improve from 0.46594
# Epoch 25/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.6124 - accuracy: 0.8005 - val_loss: 0.4284 - val_accuracy: 0.8544
#
# Epoch 00025: val_loss improved from 0.46594 to 0.42837, saving model to checkpoint\cp.ckpt
# Epoch 26/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.6169 - accuracy: 0.7991 - val_loss: 0.4852 - val_accuracy: 0.8368
#
# Epoch 00026: val_loss did not improve from 0.42837
# Epoch 27/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.5916 - accuracy: 0.8079 - val_loss: 0.4563 - val_accuracy: 0.8584
#
# Epoch 00027: val_loss did not improve from 0.42837
# Epoch 28/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.5750 - accuracy: 0.8127 - val_loss: 0.4545 - val_accuracy: 0.8568
#
# Epoch 00028: val_loss did not improve from 0.42837
# Epoch 29/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.5795 - accuracy: 0.8151 - val_loss: 0.4524 - val_accuracy: 0.8451
#
# Epoch 00029: val_loss did not improve from 0.42837
# Epoch 30/100
# 235/235 [==============================] - 39s 168ms/step - loss: 0.5665 - accuracy: 0.8137 - val_loss: 0.4275 - val_accuracy: 0.8565
#
# Epoch 00030: val_loss improved from 0.42837 to 0.42751, saving model to checkpoint\cp.ckpt
# Epoch 31/100
# 235/235 [==============================] - 39s 168ms/step - loss: 0.5468 - accuracy: 0.8219 - val_loss: 0.3765 - val_accuracy: 0.8701
#
# Epoch 00031: val_loss improved from 0.42751 to 0.37647, saving model to checkpoint\cp.ckpt
# Epoch 32/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.5306 - accuracy: 0.8290 - val_loss: 0.3721 - val_accuracy: 0.8701
#
# Epoch 00032: val_loss improved from 0.37647 to 0.37206, saving model to checkpoint\cp.ckpt
# Epoch 33/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.5383 - accuracy: 0.8219 - val_loss: 0.3941 - val_accuracy: 0.8640
#
# Epoch 00033: val_loss did not improve from 0.37206
# Epoch 34/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.5196 - accuracy: 0.8297 - val_loss: 0.3982 - val_accuracy: 0.8685
#
# Epoch 00034: val_loss did not improve from 0.37206
# Epoch 35/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.5081 - accuracy: 0.8309 - val_loss: 0.3541 - val_accuracy: 0.8773
#
# Epoch 00035: val_loss improved from 0.37206 to 0.35412, saving model to checkpoint\cp.ckpt
# Epoch 36/100
# 235/235 [==============================] - 40s 171ms/step - loss: 0.5027 - accuracy: 0.8308 - val_loss: 0.3771 - val_accuracy: 0.8821
#
# Epoch 00036: val_loss did not improve from 0.35412
# Epoch 37/100
# 235/235 [==============================] - 40s 171ms/step - loss: 0.4273 - accuracy: 0.8565 - val_loss: 0.2935 - val_accuracy: 0.9085
#
# Epoch 00046: val_loss improved from 0.30400 to 0.29350, saving model to checkpoint\cp.ckpt
# Epoch 47/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.4201 - accuracy: 0.8565 - val_loss: 0.3309 - val_accuracy: 0.8944
#
# Epoch 00047: val_loss did not improve from 0.29350
# Epoch 48/100
# 235/235 [==============================] - 40s 168ms/step - loss: 0.4228 - accuracy: 0.8546 - val_loss: 0.3192 - val_accuracy: 0.8920
#
# Epoch 00048: val_loss did not improve from 0.29350
# Epoch 49/100
# 235/235 [==============================] - 39s 167ms/step - loss: 0.4136 - accuracy: 0.8565 - val_loss: 0.3400 - val_accuracy: 0.8899
#
# Epoch 00049: val_loss did not improve from 0.29350
# Epoch 50/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.4145 - accuracy: 0.8608 - val_loss: 0.2690 - val_accuracy: 0.9096
#
# Epoch 00050: val_loss improved from 0.29350 to 0.26895, saving model to checkpoint\cp.ckpt
# Epoch 51/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.4006 - accuracy: 0.8631 - val_loss: 0.2866 - val_accuracy: 0.8939
#
# Epoch 00051: val_loss did not improve from 0.26895
# Epoch 52/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.4127 - accuracy: 0.8611 - val_loss: 0.3048 - val_accuracy: 0.8960
#
# Epoch 00052: val_loss did not improve from 0.26895
# Epoch 53/100
# 235/235 [==============================] - 40s 171ms/step - loss: 0.3895 - accuracy: 0.8704 - val_loss: 0.3007 - val_accuracy: 0.9032
#
# Epoch 00055: val_loss did not improve from 0.26468
# Epoch 56/100
# 235/235 [==============================] - 40s 170ms/step - loss: 0.3894 - accuracy: 0.8661 - val_loss: 0.2836 - val_accuracy: 0.9056
#
# Epoch 00056: val_loss did not improve from 0.26468
# Epoch 57/100
# 235/235 [==============================] - 40s 172ms/step - loss: 0.3618 - accuracy: 0.8705 - val_loss: 0.2609 - val_accuracy: 0.9133
#
# Epoch 00057: val_loss improved from 0.26468 to 0.26092, saving model to checkpoint\cp.ckpt
# Epoch 58/100
# 235/235 [==============================] - 39s 167ms/step - loss: 0.3804 - accuracy: 0.8701 - val_loss: 0.2879 - val_accuracy: 0.9037
#
# Epoch 00058: val_loss did not improve from 0.26092
# Epoch 59/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.3762 - accuracy: 0.8751 - val_loss: 0.2457 - val_accuracy: 0.9131
#
# Epoch 00059: val_loss improved from 0.26092 to 0.24566, saving model to checkpoint\cp.ckpt
# Epoch 60/100
# 235/235 [==============================] - 39s 168ms/step - loss: 0.3599 - accuracy: 0.8741 - val_loss: 0.2602 - val_accuracy: 0.9117
#
# Epoch 00060: val_loss did not improve from 0.24566
# Epoch 61/100
# 235/235 [==============================] - 41s 173ms/step - loss: 0.3644 - accuracy: 0.8755 - val_loss: 0.2495 - val_accuracy: 0.9205
#
# Epoch 00061: val_loss did not improve from 0.24566
# Epoch 62/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.3621 - accuracy: 0.8757 - val_loss: 0.2387 - val_accuracy: 0.9147
#
# Epoch 00062: val_loss improved from 0.24566 to 0.23865, saving model to checkpoint\cp.ckpt
# Epoch 63/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.3553 - accuracy: 0.8793 - val_loss: 0.2320 - val_accuracy: 0.9245
#
# Epoch 00063: val_loss improved from 0.23865 to 0.23202, saving model to checkpoint\cp.ckpt
# Epoch 64/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.3486 - accuracy: 0.8819 - val_loss: 0.2450 - val_accuracy: 0.9149
#
# Epoch 00064: val_loss did not improve from 0.23202
# Epoch 65/100
# 235/235 [==============================] - 40s 169ms/step - loss: 0.3502 - accuracy: 0.8818 - val_loss: 0.2705 - val_accuracy: 0.9109
#
# Epoch 00065: val_loss did not improve from 0.23202
# Epoch 66/100
# 235/235 [==============================] - 39s 168ms/step - loss: 0.3424 - accuracy: 0.8824 - val_loss: 0.2504 - val_accuracy: 0.9224
#
# Epoch 00066: val_loss did not improve from 0.23202
# Epoch 67/100
# 235/235 [==============================] - 34s 127ms/step - loss: 2.3510 - accuracy: 0.5088 - val_loss: 1.6883 - val_accuracy: 0.5683
#
# Epoch 00001: val_loss improved from inf to 1.68827, saving model to checkpoint\cp.ckpt
# Epoch 2/100
# 235/235 [==============================] - 28s 119ms/step - loss: 1.5614 - accuracy: 0.5892 - val_loss: 1.2519 - val_accuracy: 0.6560
#
# Epoch 00002: val_loss improved from 1.68827 to 1.25190, saving model to checkpoint\cp.ckpt
# Epoch 3/100
# 235/235 [==============================] - 28s 119ms/step - loss: 1.2959 - accuracy: 0.6374 - val_loss: 1.0376 - val_accuracy: 0.6971
#
# Epoch 00003: val_loss improved from 1.25190 to 1.03764, saving model to checkpoint\cp.ckpt
# Epoch 4/100
# 235/235 [==============================] - 28s 121ms/step - loss: 1.1309 - accuracy: 0.6767 - val_loss: 0.9084 - val_accuracy: 0.7331
#
# Epoch 00004: val_loss improved from 1.03764 to 0.90835, saving model to checkpoint\cp.ckpt
# Epoch 5/100
# 235/235 [==============================] - 29s 122ms/step - loss: 1.0476 - accuracy: 0.6962 - val_loss: 0.8164 - val_accuracy: 0.7549
#
# Epoch 00005: val_loss improved from 0.90835 to 0.81643, saving model to checkpoint\cp.ckpt
# Epoch 6/100
# 235/235 [==============================] - 29s 123ms/step - loss: 0.5594 - accuracy: 0.8233 - val_loss: 0.4304 - val_accuracy: 0.8571
#
# Epoch 00019: val_loss did not improve from 0.42448
# Epoch 20/100
# 235/235 [==============================] - 29s 121ms/step - loss: 0.5375 - accuracy: 0.8274 - val_loss: 0.4261 - val_accuracy: 0.8619
#
# Epoch 00020: val_loss did not improve from 0.42448
# Epoch 21/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.5203 - accuracy: 0.8349 - val_loss: 0.3940 - val_accuracy: 0.8701
#
# Epoch 00021: val_loss improved from 0.42448 to 0.39397, saving model to checkpoint\cp.ckpt
# Epoch 22/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.5113 - accuracy: 0.8382 - val_loss: 0.3753 - val_accuracy: 0.8840
#
# Epoch 00022: val_loss improved from 0.39397 to 0.37534, saving model to checkpoint\cp.ckpt
# Epoch 23/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.4942 - accuracy: 0.8403 - val_loss: 0.3616 - val_accuracy: 0.8819
#
# Epoch 00023: val_loss improved from 0.37534 to 0.36162, saving model to checkpoint\cp.ckpt
# Epoch 24/100
# 235/235 [==============================] - 29s 123ms/step - loss: 0.4788 - accuracy: 0.8455 - val_loss: 0.3443 - val_accuracy: 0.8923
#
# Epoch 00024: val_loss improved from 0.36162 to 0.34425, saving model to checkpoint\cp.ckpt
# Epoch 25/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.4827 - accuracy: 0.8443 - val_loss: 0.3363 - val_accuracy: 0.8891
#
# Epoch 00025: val_loss improved from 0.34425 to 0.33630, saving model to checkpoint\cp.ckpt
# Epoch 26/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.4489 - accuracy: 0.8550 - val_loss: 0.3343 - val_accuracy: 0.8933
#
# Epoch 00026: val_loss improved from 0.33630 to 0.33426, saving model to checkpoint\cp.ckpt
# Epoch 27/100
# 235/235 [==============================] - 28s 119ms/step - loss: 0.4398 - accuracy: 0.8567 - val_loss: 0.3155 - val_accuracy: 0.8963
#
# Epoch 00027: val_loss improved from 0.33426 to 0.31551, saving model to checkpoint\cp.ckpt
# Epoch 28/100
# 235/235 [==============================] - 29s 123ms/step - loss: 0.4267 - accuracy: 0.8583 - val_loss: 0.3178 - val_accuracy: 0.8912
#
# Epoch 00028: val_loss did not improve from 0.31551
# Epoch 29/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.4147 - accuracy: 0.8635 - val_loss: 0.2993 - val_accuracy: 0.9059
#
# Epoch 00029: val_loss improved from 0.31551 to 0.29928, saving model to checkpoint\cp.ckpt
# Epoch 30/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.4201 - accuracy: 0.8609 - val_loss: 0.3188 - val_accuracy: 0.8960
#
# Epoch 00030: val_loss did not improve from 0.29928
# Epoch 31/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.4069 - accuracy: 0.8663 - val_loss: 0.2812 - val_accuracy: 0.9035
#
# Epoch 00031: val_loss improved from 0.29928 to 0.28120, saving model to checkpoint\cp.ckpt
# Epoch 32/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.3806 - accuracy: 0.8723 - val_loss: 0.2816 - val_accuracy: 0.9043
#
# Epoch 00032: val_loss did not improve from 0.28120
# Epoch 33/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.3740 - accuracy: 0.8756 - val_loss: 0.2886 - val_accuracy: 0.9019
#
# Epoch 00033: val_loss did not improve from 0.28120
# Epoch 34/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.3711 - accuracy: 0.8755 - val_loss: 0.2951 - val_accuracy: 0.9067
#
# Epoch 00034: val_loss did not improve from 0.28120
# Epoch 35/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.3671 - accuracy: 0.8761 - val_loss: 0.2693 - val_accuracy: 0.9083
#
# Epoch 00035: val_loss improved from 0.28120 to 0.26933, saving model to checkpoint\cp.ckpt
# Epoch 36/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.3658 - accuracy: 0.8764 - val_loss: 0.2623 - val_accuracy: 0.9104
#
# Epoch 00036: val_loss improved from 0.26933 to 0.26230, saving model to checkpoint\cp.ckpt
# Epoch 37/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.3566 - accuracy: 0.8797 - val_loss: 0.2487 - val_accuracy: 0.9155
#
# Epoch 00037: val_loss improved from 0.26230 to 0.24869, saving model to checkpoint\cp.ckpt
# Epoch 38/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.3477 - accuracy: 0.8826 - val_loss: 0.2556 - val_accuracy: 0.9147
#
# Epoch 00038: val_loss did not improve from 0.24869
# Epoch 39/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.3410 - accuracy: 0.8875 - val_loss: 0.2417 - val_accuracy: 0.9155
#
# Epoch 00039: val_loss improved from 0.24869 to 0.24168, saving model to checkpoint\cp.ckpt
# Epoch 40/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.3318 - accuracy: 0.8891 - val_loss: 0.2787 - val_accuracy: 0.9056
#
# Epoch 00040: val_loss did not improve from 0.24168
# Epoch 41/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.3341 - accuracy: 0.8909 - val_loss: 0.2366 - val_accuracy: 0.9208
#
# Epoch 00041: val_loss improved from 0.24168 to 0.23659, saving model to checkpoint\cp.ckpt
# Epoch 42/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.3138 - accuracy: 0.8904 - val_loss: 0.2465 - val_accuracy: 0.9157
#
# Epoch 00042: val_loss did not improve from 0.23659
# Epoch 43/100
# 235/235 [==============================] - 30s 129ms/step - loss: 0.3249 - accuracy: 0.8924 - val_loss: 0.2196 - val_accuracy: 0.9272
#
# Epoch 00043: val_loss improved from 0.23659 to 0.21963, saving model to checkpoint\cp.ckpt
# Epoch 44/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.3086 - accuracy: 0.8947 - val_loss: 0.2261 - val_accuracy: 0.9251
#
# Epoch 00044: val_loss did not improve from 0.21963
# Epoch 45/100
# 235/235 [==============================] - 30s 126ms/step - loss: 0.3080 - accuracy: 0.8960 - val_loss: 0.2291 - val_accuracy: 0.9197
#
# Epoch 00045: val_loss did not improve from 0.21963
# Epoch 46/100
# 235/235 [==============================] - 30s 126ms/step - loss: 0.3025 - accuracy: 0.8987 - val_loss: 0.2182 - val_accuracy: 0.9253
#
# Epoch 00046: val_loss improved from 0.21963 to 0.21819, saving model to checkpoint\cp.ckpt
# Epoch 47/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.2948 - accuracy: 0.9012 - val_loss: 0.2111 - val_accuracy: 0.9288
#
# Epoch 00047: val_loss improved from 0.21819 to 0.21109, saving model to checkpoint\cp.ckpt
# Epoch 48/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.2762 - accuracy: 0.9051 - val_loss: 0.2029 - val_accuracy: 0.9349
#
# Epoch 00048: val_loss improved from 0.21109 to 0.20285, saving model to checkpoint\cp.ckpt
# Epoch 49/100
# 235/235 [==============================] - 32s 135ms/step - loss: 0.2911 - accuracy: 0.9014 - val_loss: 0.2102 - val_accuracy: 0.9232
#
# Epoch 00049: val_loss did not improve from 0.20285
# Epoch 50/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.2830 - accuracy: 0.9075 - val_loss: 0.1873 - val_accuracy: 0.9349
#
# Epoch 00050: val_loss improved from 0.20285 to 0.18730, saving model to checkpoint\cp.ckpt
# Epoch 51/100
# 235/235 [==============================] - 30s 127ms/step - loss: 0.2800 - accuracy: 0.9071 - val_loss: 0.2052 - val_accuracy: 0.9296
#
# Epoch 00051: val_loss did not improve from 0.18730
# Epoch 52/100
# 235/235 [==============================] - 30s 127ms/step - loss: 0.2674 - accuracy: 0.9104 - val_loss: 0.2167 - val_accuracy: 0.9277
#
# Epoch 00052: val_loss did not improve from 0.18730
# Epoch 53/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.2819 - accuracy: 0.9051 - val_loss: 0.2140 - val_accuracy: 0.9269
#
# Epoch 00053: val_loss did not improve from 0.18730
# Epoch 54/100
# 235/235 [==============================] - 30s 126ms/step - loss: 0.2631 - accuracy: 0.9074 - val_loss: 0.1913 - val_accuracy: 0.9403
#
# Epoch 00054: val_loss did not improve from 0.18730
# Epoch 55/100
# 235/235 [==============================] - 31s 132ms/step - loss: 0.2465 - accuracy: 0.9142 - val_loss: 0.2044 - val_accuracy: 0.9285
#
# Epoch 00055: val_loss did not improve from 0.18730
# Epoch 00055: early stopping
# Epoch 1/100
# 235/235 [==============================] - 24s 81ms/step - loss: 2.5096 - accuracy: 0.4864 - val_loss: 1.9410 - val_accuracy: 0.5419
#
# Epoch 00001: val_loss improved from inf to 1.94097, saving model to checkpoint\cp.ckpt
# Epoch 2/100
# 235/235 [==============================] - 17s 73ms/step - loss: 1.8374 - accuracy: 0.5485 - val_loss: 1.5087 - val_accuracy: 0.6115
#
# Epoch 00002: val_loss improved from 1.94097 to 1.50866, saving model to checkpoint\cp.ckpt
# Epoch 3/100
# 235/235 [==============================] - 17s 74ms/step - loss: 1.5832 - accuracy: 0.5872 - val_loss: 1.3416 - val_accuracy: 0.6515
#
# Epoch 00003: val_loss improved from 1.50866 to 1.34156, saving model to checkpoint\cp.ckpt
# Epoch 4/100
# 235/235 [==============================] - 17s 72ms/step - loss: 1.4315 - accuracy: 0.6145 - val_loss: 1.1613 - val_accuracy: 0.6877
#
# Epoch 00004: val_loss improved from 1.34156 to 1.16129, saving model to checkpoint\cp.ckpt
# Epoch 5/100
# 235/235 [==============================] - 17s 73ms/step - loss: 1.3276 - accuracy: 0.6322 - val_loss: 1.0547 - val_accuracy: 0.7128
#
# Epoch 00005: val_loss improved from 1.16129 to 1.05470, saving model to checkpoint\cp.ckpt
# Epoch 6/100
# 235/235 [==============================] - 18s 77ms/step - loss: 1.2355 - accuracy: 0.6543 - val_loss: 0.9640 - val_accuracy: 0.7277
#
# Epoch 00006: val_loss improved from 1.05470 to 0.96400, saving model to checkpoint\cp.ckpt
# Epoch 7/100
# 235/235 [==============================] - 17s 74ms/step - loss: 1.1635 - accuracy: 0.6639 - val_loss: 0.9186 - val_accuracy: 0.7296
#
# Epoch 00007: val_loss improved from 0.96400 to 0.91856, saving model to checkpoint\cp.ckpt
# Epoch 8/100
# 235/235 [==============================] - 17s 74ms/step - loss: 1.1256 - accuracy: 0.6751 - val_loss: 0.8710 - val_accuracy: 0.7459
#
# Epoch 00008: val_loss improved from 0.91856 to 0.87097, saving model to checkpoint\cp.ckpt
# Epoch 9/100
# 235/235 [==============================] - 17s 73ms/step - loss: 1.0781 - accuracy: 0.6887 - val_loss: 0.8519 - val_accuracy: 0.7459
#
# Epoch 00009: val_loss improved from 0.87097 to 0.85188, saving model to checkpoint\cp.ckpt
# Epoch 10/100
# 235/235 [==============================] - 17s 73ms/step - loss: 1.0489 - accuracy: 0.6906 - val_loss: 0.8190 - val_accuracy: 0.7544
#
# Epoch 00010: val_loss improved from 0.85188 to 0.81904, saving model to checkpoint\cp.ckpt
# Epoch 11/100
# 235/235 [==============================] - 18s 76ms/step - loss: 1.0264 - accuracy: 0.6951 - val_loss: 0.7733 - val_accuracy: 0.7613
#
# Epoch 00011: val_loss improved from 0.81904 to 0.77329, saving model to checkpoint\cp.ckpt
# Epoch 12/100
# 235/235 [==============================] - 18s 78ms/step - loss: 0.9923 - accuracy: 0.7037 - val_loss: 0.7812 - val_accuracy: 0.7659
#
# Epoch 00012: val_loss did not improve from 0.77329
# Epoch 13/100
# 235/235 [==============================] - 18s 77ms/step - loss: 0.9541 - accuracy: 0.7144 - val_loss: 0.7372 - val_accuracy: 0.7717
#
# Epoch 00013: val_loss improved from 0.77329 to 0.73719, saving model to checkpoint\cp.ckpt
# Epoch 14/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.9351 - accuracy: 0.7163 - val_loss: 0.7052 - val_accuracy: 0.7835
#
# Epoch 00014: val_loss improved from 0.73719 to 0.70519, saving model to checkpoint\cp.ckpt
# Epoch 15/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.9182 - accuracy: 0.7220 - val_loss: 0.6769 - val_accuracy: 0.7864
#
# Epoch 00015: val_loss improved from 0.70519 to 0.67691, saving model to checkpoint\cp.ckpt
# Epoch 16/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.8976 - accuracy: 0.7268 - val_loss: 0.6923 - val_accuracy: 0.7885
#
# Epoch 00016: val_loss did not improve from 0.67691
# Epoch 17/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.8732 - accuracy: 0.7321 - val_loss: 0.6497 - val_accuracy: 0.7944
#
# Epoch 00017: val_loss improved from 0.67691 to 0.64974, saving model to checkpoint\cp.ckpt
# Epoch 18/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.8435 - accuracy: 0.7388 - val_loss: 0.6192 - val_accuracy: 0.8093
#
# Epoch 00018: val_loss improved from 0.64974 to 0.61917, saving model to checkpoint\cp.ckpt
# Epoch 19/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.8338 - accuracy: 0.7434 - val_loss: 0.6124 - val_accuracy: 0.8048
#
# Epoch 00019: val_loss improved from 0.61917 to 0.61241, saving model to checkpoint\cp.ckpt
# Epoch 20/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.8126 - accuracy: 0.7492 - val_loss: 0.5981 - val_accuracy: 0.8077
#
# Epoch 00020: val_loss improved from 0.61241 to 0.59808, saving model to checkpoint\cp.ckpt
# Epoch 21/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.7970 - accuracy: 0.7518 - val_loss: 0.5837 - val_accuracy: 0.8120
#
# Epoch 00021: val_loss improved from 0.59808 to 0.58365, saving model to checkpoint\cp.ckpt
# Epoch 22/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.7841 - accuracy: 0.7520 - val_loss: 0.5719 - val_accuracy: 0.8136
#
# Epoch 00022: val_loss improved from 0.58365 to 0.57194, saving model to checkpoint\cp.ckpt
# Epoch 23/100
# 235/235 [==============================] - 18s 77ms/step - loss: 0.7645 - accuracy: 0.7622 - val_loss: 0.5520 - val_accuracy: 0.8240
#
# Epoch 00023: val_loss improved from 0.57194 to 0.55205, saving model to checkpoint\cp.ckpt
# Epoch 24/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.7562 - accuracy: 0.7625 - val_loss: 0.5465 - val_accuracy: 0.8203
#
# Epoch 00024: val_loss improved from 0.55205 to 0.54652, saving model to checkpoint\cp.ckpt
# Epoch 25/100
# 235/235 [==============================] - 20s 84ms/step - loss: 0.7495 - accuracy: 0.7638 - val_loss: 0.5313 - val_accuracy: 0.8219
#
# Epoch 00025: val_loss improved from 0.54652 to 0.53135, saving model to checkpoint\cp.ckpt
# Epoch 26/100
# 235/235 [==============================] - 16s 68ms/step - loss: 0.7233 - accuracy: 0.7747 - val_loss: 0.5269 - val_accuracy: 0.8248
#
# Epoch 00026: val_loss improved from 0.53135 to 0.52690, saving model to checkpoint\cp.ckpt
# Epoch 27/100
# 235/235 [==============================] - 17s 74ms/step - loss: 0.7218 - accuracy: 0.7727 - val_loss: 0.5176 - val_accuracy: 0.8301
#
# Epoch 00027: val_loss improved from 0.52690 to 0.51764, saving model to checkpoint\cp.ckpt
# Epoch 28/100
# 235/235 [==============================] - 17s 73ms/step - loss: 0.7153 - accuracy: 0.7701 - val_loss: 0.5252 - val_accuracy: 0.8325
#
# Epoch 00028: val_loss did not improve from 0.51764
# Epoch 29/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.7033 - accuracy: 0.7773 - val_loss: 0.5154 - val_accuracy: 0.8341
#
# Epoch 00029: val_loss improved from 0.51764 to 0.51536, saving model to checkpoint\cp.ckpt
# Epoch 30/100
# 235/235 [==============================] - 17s 73ms/step - loss: 0.6952 - accuracy: 0.7803 - val_loss: 0.4937 - val_accuracy: 0.8368
#
# Epoch 00030: val_loss improved from 0.51536 to 0.49370, saving model to checkpoint\cp.ckpt
# Epoch 31/100
# 235/235 [==============================] - 17s 74ms/step - loss: 0.6791 - accuracy: 0.7810 - val_loss: 0.5096 - val_accuracy: 0.8312
#
# Epoch 00031: val_loss did not improve from 0.49370
# Epoch 32/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.6646 - accuracy: 0.7901 - val_loss: 0.4741 - val_accuracy: 0.8445
#
# Epoch 00032: val_loss improved from 0.49370 to 0.47415, saving model to checkpoint\cp.ckpt
# Epoch 33/100
# 235/235 [==============================] - 18s 77ms/step - loss: 0.6586 - accuracy: 0.7857 - val_loss: 0.4910 - val_accuracy: 0.8387
#
# Epoch 00033: val_loss did not improve from 0.47415
# Epoch 34/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.6560 - accuracy: 0.7909 - val_loss: 0.4637 - val_accuracy: 0.8456
#
# Epoch 00034: val_loss improved from 0.47415 to 0.46368, saving model to checkpoint\cp.ckpt
# Epoch 35/100
# 235/235 [==============================] - 18s 78ms/step - loss: 0.6490 - accuracy: 0.7928 - val_loss: 0.4454 - val_accuracy: 0.8557
#
# Epoch 00035: val_loss improved from 0.46368 to 0.44540, saving model to checkpoint\cp.ckpt
# Epoch 36/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.6422 - accuracy: 0.7954 - val_loss: 0.4708 - val_accuracy: 0.8384
#
# Epoch 00036: val_loss did not improve from 0.44540
# Epoch 37/100
# 235/235 [==============================] - 18s 78ms/step - loss: 0.6344 - accuracy: 0.7943 - val_loss: 0.4412 - val_accuracy: 0.8515
#
# Epoch 00037: val_loss improved from 0.44540 to 0.44115, saving model to checkpoint\cp.ckpt
# Epoch 38/100
# 235/235 [==============================] - 17s 74ms/step - loss: 0.6243 - accuracy: 0.7970 - val_loss: 0.4296 - val_accuracy: 0.8555
#
# Epoch 00038: val_loss improved from 0.44115 to 0.42955, saving model to checkpoint\cp.ckpt
# Epoch 39/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.6123 - accuracy: 0.8029 - val_loss: 0.4333 - val_accuracy: 0.8568
#
# Epoch 00039: val_loss did not improve from 0.42955
# Epoch 40/100
# 235/235 [==============================] - 17s 74ms/step - loss: 0.6163 - accuracy: 0.8020 - val_loss: 0.4216 - val_accuracy: 0.8603
#
# Epoch 00040: val_loss improved from 0.42955 to 0.42165, saving model to checkpoint\cp.ckpt
# Epoch 41/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.6138 - accuracy: 0.7995 - val_loss: 0.4341 - val_accuracy: 0.8547
#
# Epoch 00041: val_loss did not improve from 0.42165
# Epoch 42/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5976 - accuracy: 0.8064 - val_loss: 0.4036 - val_accuracy: 0.8693
#
# Epoch 00042: val_loss improved from 0.42165 to 0.40357, saving model to checkpoint\cp.ckpt
# Epoch 43/100
# 235/235 [==============================] - 18s 78ms/step - loss: 0.6007 - accuracy: 0.8068 - val_loss: 0.3987 - val_accuracy: 0.8667
#
# Epoch 00043: val_loss improved from 0.40357 to 0.39867, saving model to checkpoint\cp.ckpt
# Epoch 44/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.5885 - accuracy: 0.8077 - val_loss: 0.3934 - val_accuracy: 0.8685
#
# Epoch 00044: val_loss improved from 0.39867 to 0.39343, saving model to checkpoint\cp.ckpt
# Epoch 45/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5853 - accuracy: 0.8085 - val_loss: 0.4011 - val_accuracy: 0.8696
#
# Epoch 00045: val_loss did not improve from 0.39343
# Epoch 46/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5782 - accuracy: 0.8119 - val_loss: 0.3882 - val_accuracy: 0.8704
#
# Epoch 00046: val_loss improved from 0.39343 to 0.38817, saving model to checkpoint\cp.ckpt
# Epoch 47/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.5780 - accuracy: 0.8121 - val_loss: 0.4026 - val_accuracy: 0.8693
#
# Epoch 00047: val_loss did not improve from 0.38817
# Epoch 48/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.5707 - accuracy: 0.8125 - val_loss: 0.3921 - val_accuracy: 0.8685
#
# Epoch 00048: val_loss did not improve from 0.38817
# Epoch 49/100
# 235/235 [==============================] - 18s 79ms/step - loss: 0.5572 - accuracy: 0.8195 - val_loss: 0.3989 - val_accuracy: 0.8648
#
# Epoch 00049: val_loss did not improve from 0.38817
# Epoch 50/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.5456 - accuracy: 0.8213 - val_loss: 0.3639 - val_accuracy: 0.8829
#
# Epoch 00050: val_loss improved from 0.38817 to 0.36388, saving model to checkpoint\cp.ckpt
# Epoch 51/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.5514 - accuracy: 0.8210 - val_loss: 0.3957 - val_accuracy: 0.8717
#
# Epoch 00051: val_loss did not improve from 0.36388
# Epoch 52/100
# 235/235 [==============================] - 18s 77ms/step - loss: 0.5463 - accuracy: 0.8213 - val_loss: 0.3751 - val_accuracy: 0.8816
#
# Epoch 00052: val_loss did not improve from 0.36388
# Epoch 53/100
# 235/235 [==============================] - 17s 74ms/step - loss: 0.5422 - accuracy: 0.8231 - val_loss: 0.3722 - val_accuracy: 0.8741
#
# Epoch 00053: val_loss did not improve from 0.36388
# Epoch 54/100
# 235/235 [==============================] - 19s 79ms/step - loss: 0.5307 - accuracy: 0.8249 - val_loss: 0.3459 - val_accuracy: 0.8856
#
# Epoch 00054: val_loss improved from 0.36388 to 0.34593, saving model to checkpoint\cp.ckpt
# Epoch 55/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.5230 - accuracy: 0.8303 - val_loss: 0.3527 - val_accuracy: 0.8779
#
# Epoch 00055: val_loss did not improve from 0.34593
# Epoch 56/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5299 - accuracy: 0.8249 - val_loss: 0.3635 - val_accuracy: 0.8827
#
# Epoch 00056: val_loss did not improve from 0.34593
# Epoch 57/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5076 - accuracy: 0.8324 - val_loss: 0.3392 - val_accuracy: 0.8853
#
# Epoch 00057: val_loss improved from 0.34593 to 0.33924, saving model to checkpoint\cp.ckpt
# Epoch 58/100
# 235/235 [==============================] - 18s 78ms/step - loss: 0.5078 - accuracy: 0.8291 - val_loss: 0.3328 - val_accuracy: 0.8888
#
# Epoch 00058: val_loss improved from 0.33924 to 0.33280, saving model to checkpoint\cp.ckpt
# Epoch 59/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5193 - accuracy: 0.8253 - val_loss: 0.3330 - val_accuracy: 0.8851
#
# Epoch 00059: val_loss did not improve from 0.33280
# Epoch 60/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.5111 - accuracy: 0.8313 - val_loss: 0.3311 - val_accuracy: 0.8845
#
# Epoch 00060: val_loss improved from 0.33280 to 0.33110, saving model to checkpoint\cp.ckpt
# Epoch 61/100
# 235/235 [==============================] - 17s 73ms/step - loss: 0.4995 - accuracy: 0.8357 - val_loss: 0.3546 - val_accuracy: 0.8837
#
# Epoch 00061: val_loss did not improve from 0.33110
# Epoch 62/100
# 235/235 [==============================] - 17s 74ms/step - loss: 0.5093 - accuracy: 0.8312 - val_loss: 0.3553 - val_accuracy: 0.8811
#
# Epoch 00062: val_loss did not improve from 0.33110
# Epoch 63/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.4997 - accuracy: 0.8355 - val_loss: 0.3307 - val_accuracy: 0.8867
#
# Epoch 00063: val_loss improved from 0.33110 to 0.33065, saving model to checkpoint\cp.ckpt
# Epoch 64/100
# 235/235 [==============================] - 19s 80ms/step - loss: 0.4898 - accuracy: 0.8349 - val_loss: 0.3370 - val_accuracy: 0.8877
#
# Epoch 00064: val_loss did not improve from 0.33065
# Epoch 65/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.4974 - accuracy: 0.8337 - val_loss: 0.3328 - val_accuracy: 0.8893
#
# Epoch 00065: val_loss did not improve from 0.33065
# Epoch 66/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5017 - accuracy: 0.8324 - val_loss: 0.3302 - val_accuracy: 0.8925
#
# Epoch 00066: val_loss improved from 0.33065 to 0.33025, saving model to checkpoint\cp.ckpt
# Epoch 67/100
# 235/235 [==============================] - 18s 77ms/step - loss: 0.4718 - accuracy: 0.8418 - val_loss: 0.3374 - val_accuracy: 0.8944
#
# Epoch 00067: val_loss did not improve from 0.33025
# Epoch 68/100
# 235/235 [==============================] - 14s 61ms/step - loss: 0.4772 - accuracy: 0.8393 - val_loss: 0.3235 - val_accuracy: 0.8931
#
# Epoch 00068: val_loss improved from 0.33025 to 0.32348, saving model to checkpoint\cp.ckpt
# Epoch 69/100
# 235/235 [==============================] - 10s 43ms/step - loss: 0.4771 - accuracy: 0.8390 - val_loss: 0.3174 - val_accuracy: 0.8907
#
# Epoch 00069: val_loss improved from 0.32348 to 0.31743, saving model to checkpoint\cp.ckpt
# Epoch 70/100
# 235/235 [==============================] - 10s 43ms/step - loss: 0.4747 - accuracy: 0.8423 - val_loss: 0.3244 - val_accuracy: 0.8907
#
# Epoch 00070: val_loss did not improve from 0.31743
# Epoch 71/100
# 235/235 [==============================] - 10s 44ms/step - loss: 0.4759 - accuracy: 0.8437 - val_loss: 0.3146 - val_accuracy: 0.8941
#
# Epoch 00071: val_loss improved from 0.31743 to 0.31462, saving model to checkpoint\cp.ckpt
# Epoch 72/100
# 235/235 [==============================] - 11s 47ms/step - loss: 0.4668 - accuracy: 0.8422 - val_loss: 0.3180 - val_accuracy: 0.8960
#
# Epoch 00072: val_loss did not improve from 0.31462
# Epoch 73/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4574 - accuracy: 0.8500 - val_loss: 0.3081 - val_accuracy: 0.8971
#
# Epoch 00073: val_loss improved from 0.31462 to 0.30811, saving model to checkpoint\cp.ckpt
# Epoch 74/100
# 235/235 [==============================] - 19s 80ms/step - loss: 0.4674 - accuracy: 0.8457 - val_loss: 0.2989 - val_accuracy: 0.8984
#
# Epoch 00074: val_loss improved from 0.30811 to 0.29891, saving model to checkpoint\cp.ckpt
# Epoch 75/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.4478 - accuracy: 0.8498 - val_loss: 0.2912 - val_accuracy: 0.9067
#
# Epoch 00075: val_loss improved from 0.29891 to 0.29121, saving model to checkpoint\cp.ckpt
# Epoch 76/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4580 - accuracy: 0.8444 - val_loss: 0.3008 - val_accuracy: 0.8984
#
# Epoch 00076: val_loss did not improve from 0.29121
# Epoch 77/100
# 235/235 [==============================] - 17s 73ms/step - loss: 0.4534 - accuracy: 0.8466 - val_loss: 0.3085 - val_accuracy: 0.8933
#
# Epoch 00077: val_loss did not improve from 0.29121
# Epoch 78/100
# 235/235 [==============================] - 17s 74ms/step - loss: 0.4454 - accuracy: 0.8501 - val_loss: 0.2831 - val_accuracy: 0.9064
#
# Epoch 00078: val_loss improved from 0.29121 to 0.28314, saving model to checkpoint\cp.ckpt
# Epoch 79/100
# 235/235 [==============================] - 18s 76ms/step - loss: 0.4442 - accuracy: 0.8513 - val_loss: 0.3068 - val_accuracy: 0.8960
#
# Epoch 00079: val_loss did not improve from 0.28314
# Epoch 80/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4451 - accuracy: 0.8479 - val_loss: 0.3169 - val_accuracy: 0.8973
#
# Epoch 00080: val_loss did not improve from 0.28314
# Epoch 81/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4435 - accuracy: 0.8491 - val_loss: 0.3164 - val_accuracy: 0.8952
#
# Epoch 00081: val_loss did not improve from 0.28314
# Epoch 82/100
# 235/235 [==============================] - 18s 79ms/step - loss: 0.4329 - accuracy: 0.8541 - val_loss: 0.2793 - val_accuracy: 0.9067
#
# Epoch 00082: val_loss improved from 0.28314 to 0.27929, saving model to checkpoint\cp.ckpt
# Epoch 83/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4368 - accuracy: 0.8559 - val_loss: 0.2964 - val_accuracy: 0.9037
#
# Epoch 00083: val_loss did not improve from 0.27929
# Epoch 84/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4164 - accuracy: 0.8581 - val_loss: 0.2970 - val_accuracy: 0.9043
#
# Epoch 00084: val_loss did not improve from 0.27929
# Epoch 85/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4238 - accuracy: 0.8562 - val_loss: 0.2844 - val_accuracy: 0.9045
#
# Epoch 00085: val_loss did not improve from 0.27929
# Epoch 86/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4306 - accuracy: 0.8561 - val_loss: 0.3114 - val_accuracy: 0.9005
#
# Epoch 00086: val_loss did not improve from 0.27929
# Epoch 87/100
# 235/235 [==============================] - 18s 75ms/step - loss: 0.4243 - accuracy: 0.8578 - val_loss: 0.2935 - val_accuracy: 0.9037
#
# Epoch 00087: val_loss did not improve from 0.27929
# Epoch 00087: early stopping

# %%
# 저장한 모델 불러오기
for i in range(5): # 모델 갯수
    globals()[f'model{i}'] = load_model(f'models/211008(1)_model_{i}.h5')

# %%
model0._name = 'Client0'
model1._name = 'Client1'
model2._name = 'Client2'
model3._name = 'Client3'
model4._name = 'Client4'

# %%
inputs = Input(shape=(n_steps, n_length, n_features))

merge = concatenate([model0(inputs), model1(inputs), model2(inputs), model3(inputs), model4(inputs)])
hidden = Dense(10, activation='relu')(merge)
output = Dense(61, activation='softmax')(hidden)
model = tf.keras.models.Model(inputs=inputs, outputs=output)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

stfold = StratifiedKFold(n_splits=3, shuffle=True)
idx_iter = 0 
skf_accuracy=[]

for train_idx, valid_idx in stfold.split(X, y_train_total) : 
    Y_train, Y_valid = tf.gather(y, train_idx), tf.gather(y, valid_idx)
    X_train, X_valid = tf.gather(X, train_idx), tf.gather(X, valid_idx)

    checkpoint_path = "checkpoint/cp1.ckpt"
    cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

    early_stopping = EarlyStopping(monitor='loss', patience=4, mode='min')
    model.fit(X_train, Y_train, epochs=30, batch_size=batch_size, validation_split=0.02, callbacks=[early_stopping, cp_callback])
    pred = model.predict(X_valid)

    # 반복 시 마다 정확도 측정 -> 수정해야함; 
    idx_iter += 1 
    y_pred = (pred > 0.5) 
    accuracy = np.round(accuracy_score(Y_valid, y_pred), 4)
    train_size = X_train.shape[0]
    test_size = X_valid.shape[0]

    print("\n##### 교차 검증: {}, 정확도: {}  #####" .format(idx_iter, accuracy))
    print('학습 레이블 데이터 분포:\n ', Y_train.shape[0])
    print('검증 레이블 데이터 분포:\n ', Y_valid.shape[0], '\n\n')
# Out:
# Epoch 1/30
# 192/192 [==============================] - 126s 657ms/step - loss: 0.9316 - accuracy: 0.7839 - val_loss: 0.6883 - val_accuracy: 0.8680
#
# Epoch 00001: val_loss improved from inf to 0.68828, saving model to checkpoint\cp1.ckpt
# Epoch 2/30
# 192/192 [==============================] - 89s 466ms/step - loss: 0.6962 - accuracy: 0.8424 - val_loss: 0.5076 - val_accuracy: 0.8640
#
# Epoch 00002: val_loss improved from 0.68828 to 0.50759, saving model to checkpoint\cp1.ckpt
# Epoch 3/30
# 192/192 [==============================] - 93s 487ms/step - loss: 0.5644 - accuracy: 0.8598 - val_loss: 0.4300 - val_accuracy: 0.8840
#
# Epoch 00003: val_loss improved from 0.50759 to 0.43004, saving model to checkpoint\cp1.ckpt
# Epoch 4/30
# 192/192 [==============================] - 99s 517ms/step - loss: 0.4726 - accuracy: 0.8774 - val_loss: 0.3764 - val_accuracy: 0.8880
#
# Epoch 00004: val_loss improved from 0.43004 to 0.37642, saving model to checkpoint\cp1.ckpt
# Epoch 5/30
# 192/192 [==============================] - 53s 273ms/step - loss: 0.4198 - accuracy: 0.8830 - val_loss: 0.3226 - val_accuracy: 0.9040
#
# Epoch 00005: val_loss improved from 0.37642 to 0.32259, saving model to checkpoint\cp1.ckpt
# Epoch 6/30
# 192/192 [==============================] - 51s 266ms/step - loss: 0.3759 - accuracy: 0.8923 - val_loss: 0.3200 - val_accuracy: 0.9200
#
# Epoch 00006: val_loss improved from 0.32259 to 0.31998, saving model to checkpoint\cp1.ckpt
# Epoch 7/30
# 192/192 [==============================] - 52s 273ms/step - loss: 0.3611 - accuracy: 0.8910 - val_loss: 0.2959 - val_accuracy: 0.9160
#
# Epoch 00007: val_loss improved from 0.31998 to 0.29588, saving model to checkpoint\cp1.ckpt
# Epoch 8/30
# 192/192 [==============================] - 52s 271ms/step - loss: 0.3438 - accuracy: 0.8950 - val_loss: 0.3012 - val_accuracy: 0.9120
#
# Epoch 00008: val_loss did not improve from 0.29588
# Epoch 9/30
# 192/192 [==============================] - 52s 272ms/step - loss: 0.3186 - accuracy: 0.9020 - val_loss: 0.2734 - val_accuracy: 0.9160
#
# Epoch 00009: val_loss improved from 0.29588 to 0.27344, saving model to checkpoint\cp1.ckpt
# Epoch 10/30
# 192/192 [==============================] - 85s 445ms/step - loss: 0.2950 - accuracy: 0.9038 - val_loss: 0.2309 - val_accuracy: 0.9120
#
# Epoch 00010: val_loss improved from 0.27344 to 0.23091, saving model to checkpoint\cp1.ckpt
# Epoch 11/30
# 192/192 [==============================] - 94s 489ms/step - loss: 0.2821 - accuracy: 0.9089 - val_loss: 0.2623 - val_accuracy: 0.9120
#
# Epoch 00011: val_loss did not improve from 0.23091
# Epoch 12/30
# 192/192 [==============================] - 92s 477ms/step - loss: 0.2698 - accuracy: 0.9115 - val_loss: 0.2649 - val_accuracy: 0.9040
#
# Epoch 00012: val_loss did not improve from 0.23091
# Epoch 13/30
# 192/192 [==============================] - 93s 486ms/step - loss: 0.2923 - accuracy: 0.9058 - val_loss: 0.3161 - val_accuracy: 0.9000
#
# Epoch 00013: val_loss did not improve from 0.23091
# Epoch 14/30
# 192/192 [==============================] - 90s 467ms/step - loss: 0.2635 - accuracy: 0.9143 - val_loss: 0.2759 - val_accuracy: 0.9160
#
# Epoch 00014: val_loss did not improve from 0.23091
# Epoch 15/30
# 192/192 [==============================] - 93s 483ms/step - loss: 0.2507 - accuracy: 0.9158 - val_loss: 0.2207 - val_accuracy: 0.9200
#
# Epoch 00015: val_loss improved from 0.23091 to 0.22071, saving model to checkpoint\cp1.ckpt
# Epoch 16/30
# 192/192 [==============================] - 92s 479ms/step - loss: 0.2717 - accuracy: 0.9112 - val_loss: 0.2071 - val_accuracy: 0.9240
#
# Epoch 00016: val_loss improved from 0.22071 to 0.20712, saving model to checkpoint\cp1.ckpt
# Epoch 17/30
# 192/192 [==============================] - 93s 482ms/step - loss: 0.2901 - accuracy: 0.9048 - val_loss: 0.2016 - val_accuracy: 0.9280
#
# Epoch 00017: val_loss improved from 0.20712 to 0.20159, saving model to checkpoint\cp1.ckpt
# Epoch 18/30
# 192/192 [==============================] - 92s 478ms/step - loss: 0.2493 - accuracy: 0.9158 - val_loss: 0.2061 - val_accuracy: 0.9240
#
# Epoch 00018: val_loss did not improve from 0.20159
# Epoch 19/30
# 192/192 [==============================] - 91s 475ms/step - loss: 0.2370 - accuracy: 0.9201 - val_loss: 0.2481 - val_accuracy: 0.9120
#
# Epoch 00019: val_loss did not improve from 0.20159
# Epoch 20/30
# 192/192 [==============================] - 91s 475ms/step - loss: 0.2152 - accuracy: 0.9264 - val_loss: 0.2119 - val_accuracy: 0.9360
#
# Epoch 00020: val_loss did not improve from 0.20159
# Epoch 21/30
# 192/192 [==============================] - 91s 475ms/step - loss: 0.2127 - accuracy: 0.9293 - val_loss: 0.2453 - val_accuracy: 0.9280
#
# Epoch 00021: val_loss did not improve from 0.20159
# Epoch 22/30
# 192/192 [==============================] - 92s 480ms/step - loss: 0.2310 - accuracy: 0.9227 - val_loss: 0.2741 - val_accuracy: 0.9240
#
# Epoch 00022: val_loss did not improve from 0.20159
# Epoch 23/30
# 192/192 [==============================] - 93s 485ms/step - loss: 0.2277 - accuracy: 0.9214 - val_loss: 0.2189 - val_accuracy: 0.9200
#
# Epoch 00023: val_loss did not improve from 0.20159
# Epoch 24/30
# 192/192 [==============================] - 95s 492ms/step - loss: 0.2074 - accuracy: 0.9280 - val_loss: 0.2058 - val_accuracy: 0.9280
#
# Epoch 00024: val_loss did not improve from 0.20159
# Epoch 25/30
# 192/192 [==============================] - 93s 482ms/step - loss: 0.1988 - accuracy: 0.9321 - val_loss: 0.2079 - val_accuracy: 0.9160
#
# Epoch 00025: val_loss did not improve from 0.20159
# Epoch 26/30
# 192/192 [==============================] - 95s 494ms/step - loss: 0.1906 - accuracy: 0.9353 - val_loss: 0.2376 - val_accuracy: 0.9120
#
# Epoch 00026: val_loss did not improve from 0.20159
# Epoch 27/30
# 192/192 [==============================] - 100s 520ms/step - loss: 0.2283 - accuracy: 0.9222 - val_loss: 0.2122 - val_accuracy: 0.9240
#
# Epoch 00027: val_loss did not improve from 0.20159
# Epoch 28/30
# 192/192 [==============================] - 96s 498ms/step - loss: 0.1863 - accuracy: 0.9354 - val_loss: 0.2002 - val_accuracy: 0.9280
#
# Epoch 00028: val_loss improved from 0.20159 to 0.20018, saving model to checkpoint\cp1.ckpt
# Epoch 29/30
# 192/192 [==============================] - 94s 492ms/step - loss: 0.1692 - accuracy: 0.9409 - val_loss: 0.1654 - val_accuracy: 0.9440
#
# Epoch 00029: val_loss improved from 0.20018 to 0.16540, saving model to checkpoint\cp1.ckpt
# Epoch 30/30
# 192/192 [==============================] - 92s 481ms/step - loss: 0.1820 - accuracy: 0.9365 - val_loss: 0.1811 - val_accuracy: 0.9200
#
# Epoch 00030: val_loss did not improve from 0.16540
#
# ##### 교차 검증: 1, 정확도: 0.9256  #####
# 학습 레이블 데이터 분포:
#   12500
# 검증 레이블 데이터 분포:
#   6250
#
#
# Epoch 1/30
# 192/192 [==============================] - 87s 452ms/step - loss: 0.2634 - accuracy: 0.9119 - val_loss: 0.1927 - val_accuracy: 0.9320
#
# Epoch 00001: val_loss improved from inf to 0.19269, saving model to checkpoint\cp1.ckpt
# Epoch 2/30
# 192/192 [==============================] - 93s 487ms/step - loss: 0.2316 - accuracy: 0.9243 - val_loss: 0.1638 - val_accuracy: 0.9160
#
# Epoch 00002: val_loss improved from 0.19269 to 0.16379, saving model to checkpoint\cp1.ckpt
# Epoch 3/30
# 192/192 [==============================] - 97s 503ms/step - loss: 0.2166 - accuracy: 0.9246 - val_loss: 0.2524 - val_accuracy: 0.9080
#
# Epoch 00003: val_loss did not improve from 0.16379
# Epoch 4/30
# 192/192 [==============================] - 97s 505ms/step - loss: 0.1911 - accuracy: 0.9364 - val_loss: 0.1571 - val_accuracy: 0.9280
#
# Epoch 00004: val_loss improved from 0.16379 to 0.15711, saving model to checkpoint\cp1.ckpt
# Epoch 5/30
#  25/192 [==>...........................] - ETA: 1:27 - loss: 0.1742 - accuracy: 0.9394

# %%
prediction = model.predict(test_X)
prediction.shape

# %%
submission

# %%
submission.iloc[:,1:]=prediction

# %%
submission.to_csv('cnn_LSTM_stacked5_fold3(jy_last).csv', index=False)

# %%
submission

# %%
sub = pd.read_csv('test_c_l.csv')

# %%
def result_pred(sub1, sub2) :
    subpre1 = []
    subpre2 = []
    corcount = 0
    
    for i in range(len(sub1)) :
        subpre1.append(sub1.iloc[i,1:].idxmax())
        subpre2.append(sub2.iloc[i,1:].idxmax())

    subpre1 = pd.DataFrame(subpre1, columns = ['label'])
    subpre1.head()
    
    subpre2 = pd.DataFrame(subpre2, columns = ['label'])
    subpre2.head()
    
    print("파일 1 운동중 라벨 수 :", len(subpre1[subpre1['label'] != '26']), "\n파일 2 운동중 라벨 수 :", len(subpre2[subpre2['label'] != '26']))
    for i in range(len(subpre1)) :
        if (subpre1['label'][i] == subpre2['label'][i]) : 
            corcount += 1
    print("예측 결과 일치 개수 :", corcount)
    
    return subpre1

# %%
sub1 = pd.read_csv('cnn_LSTM_last(jun).csv')
sub2 = pd.read_csv('cnn_LSTM_stacked5_fold3(jy_epoch10_batch256).csv')

subpre1 = result_pred(sub1, sub2)
subpre1

# %%
y ==

# %%
subpre1.to_csv('subpre1.csv')

# %%
sub1 = pd.read_csv('cnn_LSTM_stacked(jun).csv')
sub2 = pd.read_csv('cnn_LSTM_stacked5_fold3(jy_last).csv')

subpre1 = result_pred(sub1, sub2)
subpre1.head(15)

# %%
sub1 = pd.read_csv(path+'baseline_aug_1.csv')
subpre3 = []

for i in range(len(sub1)) :
    subpre3.append(sub1.iloc[i,1:].idxmax())

subpre3 = pd.DataFrame(subpre3, columns = ['label'])
subpre3.head()

# %%
len(subpre3[subpre3['label'] != '26']) # 1.8747789247

# %%
sub1 = pd.read_csv(path+'baseline_aug(npTodf).csv')
subpre3 = []

for i in range(len(sub1)) :
    subpre3.append(sub1.iloc[i,1:].idxmax())

subpre3 = pd.DataFrame(subpre3, columns = ['label'])

len(subpre3[subpre3['label'] != '26']) # 168

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

stfold = StratifiedKFold(n_splits=3, shuffle=True)
idx_iter = 0 
skf_accuracy=[]
epochs = 10
batch_size = 256

for train_idx, valid_idx in stfold.split(X, y_train_total) : 
    Y_train, Y_valid = tf.gather(y, train_idx), tf.gather(y, valid_idx)
    X_train, X_valid = tf.gather(X, train_idx), tf.gather(X, valid_idx)

    checkpoint_path = "checkpoint/cp.ckpt"
    cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

    early_stopping = EarlyStopping(monitor='loss', patience=5, mode='min')
    model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, validation_split=0.02, callbacks=[early_stopping, cp_callback])
    pred = model.predict(X_valid)

    # 반복 시 마다 정확도 측정 -> 수정해야함; 
    idx_iter += 1 
    y_pred = (pred > 0.5) 
    accuracy = np.round(accuracy_score(Y_valid, y_pred), 4)
    train_size = X_train.shape[0]
    test_size = X_valid.shape[0]

    print("\n##### 교차 검증: {}, 정확도: {}  #####" .format(idx_iter, accuracy))
    print('학습 레이블 데이터 분포:\n ', Y_train.shape[0])
    print('검증 레이블 데이터 분포:\n ', Y_valid.shape[0], '\n\n')
