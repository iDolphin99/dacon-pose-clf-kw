# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# %%
# 기본 directory 설정
import os
os.chdir('/content/drive/MyDrive/Monthly_Workout')

# %%
# 모듈 불러오기
import random
import pandas as pd
import numpy as np
from tqdm import tqdm
from math import pi

# %%
# 데이터 불러오기
path = './' # 기본 directory 경로에 추가 할 경로

train = pd.read_csv(path + 'train_features.csv')
train_labels = pd.read_csv(path + 'train_labels.csv')
test = pd.read_csv(path + 'test_features.csv')
submission = pd.read_csv(path + 'sample_submission.csv')

train
# Out:
#            id  time     acc_x     acc_y     acc_z       gy_x        gy_y  \
# 0           0     0  1.206087 -0.179371 -0.148447  -0.591608  -30.549010
# 1           0     1  1.287696 -0.198974 -0.182444   0.303100  -39.139103
# 2           0     2  1.304609 -0.195114 -0.253382  -3.617278  -44.122565
# 3           0     3  1.293095 -0.230366 -0.215210   2.712986  -53.597843
# 4           0     4  1.300887 -0.187757 -0.222523   4.286707  -57.906561
# ...       ...   ...       ...       ...       ...        ...         ...
# 1874995  3124   595 -0.712530 -0.658357  0.293707 -29.367857 -104.013664
# 1874996  3124   596 -0.683037 -0.658466  0.329223 -30.149089 -101.796809
# 1874997  3124   597 -0.664730 -0.666625  0.364114 -27.873095  -98.776072
# 1874998  3124   598 -0.630534 -0.682565  0.373696 -23.636550  -99.139495
# 1874999  3124   599 -0.578351 -0.700235  0.384390 -17.917626 -100.181873
#
#               gy_z
# 0       -31.676112
# 1       -24.927216
# 2       -25.019629
# 3       -27.454013
# 4       -27.961234
# ...            ...
# 1874995 -76.290437
# 1874996 -76.625087
# 1874997 -79.365125
# 1874998 -80.259478
# 1874999 -80.676229
#
# [1875000 rows x 8 columns]

# %%
act_list=train.iloc[:,2:].columns
acc_list=['acc_x','acc_y','acc_z']
gy_list=['gy_x','gy_y','gy_z']
act_list
# Out:
# Index(['acc_x', 'acc_y', 'acc_z', 'gy_x', 'gy_y', 'gy_z'], dtype='object')

# %%
# acc 데이터와 gy 데이터로 분할
def sensor_split(data):
    X_acc = []
    X_gy = []

    for i in tqdm(data['id'].unique()):
        temp_acc = np.array(data[data['id'] == i].loc[:,acc_list])
        temp_gy = np.array(data[data['id'] == i].loc[:,gy_list])
        X_acc.append(temp_acc)
        X_gy.append(temp_gy)
      
    X_acc = np.array(X_acc).reshape(-1,600,3)
    X_gy = np.array(X_gy).reshape(-1,600,3)

    return X_acc, X_gy

# %%
# 데이터 증강

def aug(data, uid, shift):
    shift_data = np.roll(data[uid], shift, axis=0)
    return shift_data

def rolling(data):
    aug_data=[]
    for i in range(data.shape[0]):
        temp=list((aug(data,i,int(random.random()*600))))
        aug_data.append(temp)
    return np.array(aug_data)

# %%
# 데이터 증강 (반복하고 싶은 만큼 조정)
def start_augmentation(train, train_labels):
    # acc, gy 데이터 분할
    X_train_mod=pd.merge(train,train_labels,how='left',on='id')
    X_train_acc, X_train_gy= sensor_split(X_train_mod)

    # 증강시키고 추가할 임시 데이터 복사본
    X_train_acc_temp = X_train_acc.copy()
    X_train_gy_temp = X_train_gy.copy()

    # label 데이터 변환
    y_train = train_labels['label']
    y_train_total = np.append(y_train, y_train, axis=0)

    rep = 5 # 5이상의 경우 reshape 과정에서 reset될 가능성 높음
    for i in range(rep):
        X_train_acc_roll = rolling(X_train_acc_temp)
        X_train_gy_roll = rolling(X_train_gy_temp)

        # 증강시킨 데이터 원래 데이터에 추가
        X_train_acc = np.append(X_train_acc, X_train_acc_roll, axis=0)
        X_train_gy = np.append(X_train_gy, X_train_gy_roll, axis=0)

        if i != (rep-1): # 마지막 한 번 제외
            y_train_total = np.append(y_train_total, y_train, axis=0)

    return X_train_acc, X_train_gy, y_train_total

# %%
X_train_acc, X_train_gy, y_train_total = start_augmentation(train, train_labels)

X_train_acc.shape, X_train_gy.shape, y_train_total.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3125/3125 [00:40<00:00, 77.40it/s]
# ((18750, 600, 3), (18750, 600, 3), (18750,))

# %%
# np array 형태를 dataframe 으로 변환
def np_to_df(X_train_acc, X_train_gy):
    acc = [e for sl in X_train_acc for e in sl]
    gy = [e for sl in X_train_gy for e in sl]

    df_report_acc = np.stack(acc, axis = 0)
    df_report_gy = np.stack(gy, axis = 0)

    df_acc = pd.DataFrame(df_report_acc, columns= ['acc_x', 'acc_y', 'acc_z']) 
    df_gy = pd.DataFrame(df_report_gy, columns= ['gy_x', 'gy_y', 'gy_z']) 

    # acc, gy 데이터프레임 병합
    df_aug_result = pd.concat([df_acc, df_gy], axis = 1)
    
    return df_aug_result

# %%
train = np_to_df(X_train_acc, X_train_gy)
train
# Out:
#              acc_x     acc_y     acc_z      gy_x       gy_y       gy_z
# 0         1.206087 -0.179371 -0.148447 -0.591608 -30.549010 -31.676112
# 1         1.287696 -0.198974 -0.182444  0.303100 -39.139103 -24.927216
# 2         1.304609 -0.195114 -0.253382 -3.617278 -44.122565 -25.019629
# 3         1.293095 -0.230366 -0.215210  2.712986 -53.597843 -27.454013
# 4         1.300887 -0.187757 -0.222523  4.286707 -57.906561 -27.961234
# ...            ...       ...       ...       ...        ...        ...
# 11249995 -0.584944 -0.655879  0.427890  6.081671  77.737712  55.006650
# 11249996 -0.616364 -0.660179  0.435595  8.814869  79.429573  55.866462
# 11249997 -0.618149 -0.684883  0.436353  7.457219  78.437228  54.712492
# 11249998 -0.632275 -0.691995  0.392237  5.109621  75.604057  54.834697
# 11249999 -0.672990 -0.658979  0.320705  1.809531  75.278959  53.267941
#
# [11250000 rows x 6 columns]

# %%
# 가속도
train['acc_t'] = (train['acc_x'] ** 2) + (train['acc_y'] ** 2) + (train['acc_z'] ** 2) ** (1/3)
test['acc_t'] = (test['acc_x'] ** 2) + (test['acc_y'] ** 2) + (test['acc_z'] ** 2) ** (1/3)

train['gy_t'] = (train['gy_x'] ** 2) + (train['gy_y'] ** 2) + (train['gy_z'] ** 2) ** (1/3)
test['gy_t'] = (test['gy_x'] ** 2) + (test['gy_y'] ** 2) + (test['gy_z'] ** 2) ** (1/3)

# Signal 극대화 (peak 캐치 유용)
train['acc_mag'] = (train['acc_x'] ** 2) + (train['acc_y'] ** 2) + (train['acc_z'] ** 2)
test['acc_mag'] = (test['acc_x'] ** 2) + (test['acc_y'] ** 2) + (test['acc_z'] ** 2)

train['gy_mag'] = (train['gy_x'] ** 2) + (train['gy_y'] ** 2) + (train['gy_z'] ** 2)
test['gy_mag'] = (test['gy_x'] ** 2) + (test['gy_y'] ** 2) + (test['gy_z'] ** 2)

# %%
# vector
train['acc_vec'] = np.sqrt((train['acc_x'] ** 2) +(train['acc_y'] ** 2)+(train['acc_z'] ** 2))
test['acc_vec'] = np.sqrt((test['acc_x'] ** 2) +(test['acc_y'] ** 2)+(test['acc_z'] ** 2))

train['gy_vec'] = np.sqrt((train['gy_x'] ** 2) +(train['gy_y'] ** 2)+(train['gy_z'] ** 2))
test['gy_vec'] = np.sqrt((test['gy_x'] ** 2) +(test['gy_y'] ** 2)+(test['gy_z'] ** 2))

# 자이로스코프 무게중심
train['gy_gravity'] = (train['gy_x']+train['gy_y']+train['gy_z'])/3
test['gy_gravity'] = (test['gy_x']+test['gy_y']+test['gy_z'])/3

# %%
# roll & pitch
train['roll'] = np.arctan(train['acc_y']/np.sqrt(train['acc_x'] ** 2 + train['acc_z'] ** 2))
test['roll'] = np.arctan(test['acc_y']/np.sqrt(test['acc_x'] ** 2 + test['acc_z'] ** 2))

train['pitch'] = np.arctan(train['acc_x']/np.sqrt(train['acc_y'] ** 2 + train['acc_z'] ** 2))
test['pitch'] = np.arctan(test['acc_x']/np.sqrt(test['acc_y'] ** 2 + test['acc_z'] ** 2))

train['math_roll'] = np.arctan(- train['acc_x']/np.sqrt(train['acc_y'] ** 2 + train['acc_z'] ** 2)) * (180/pi)
test['math_roll'] = np.arctan(- test['acc_x']/np.sqrt(test['acc_y'] ** 2 + test['acc_z'] ** 2)) * (180/pi)

train['math_pitch'] = np.arctan(train['acc_y']/np.sqrt(train['acc_x'] ** 2 + train['acc_z'] ** 2)) * (180/pi)
test['math_pitch'] = np.arctan(test['acc_y']/np.sqrt(test['acc_x'] ** 2 + test['acc_z'] ** 2)) * (180/pi)

train['gy_roll'] = np.arctan(train['gy_y']/np.sqrt(train['gy_x'] ** 2 + train['gy_z'] ** 2))
test['gy_roll'] = np.arctan(test['gy_y']/np.sqrt(test['gy_x'] ** 2 + test['gy_z'] ** 2))

train['gy_pitch'] = np.arctan(train['gy_x']/np.sqrt(train['gy_y'] ** 2 + train['gy_z'] ** 2))
test['gy_pitch'] = np.arctan(test['gy_x']/np.sqrt(test['gy_y'] ** 2 + test['gy_z'] ** 2))

train['gy_math_roll'] = np.arctan(- train['gy_x']/np.sqrt(train['gy_y'] ** 2 + train['gy_z'] ** 2)) * (180/pi)
test['gy_math_roll'] = np.arctan(- test['gy_x']/np.sqrt(test['gy_y'] ** 2 + test['gy_z'] ** 2)) * (180/pi)

train['gy_math_pitch'] = np.arctan(train['gy_y']/np.sqrt(train['gy_x'] ** 2 + train['gy_z'] ** 2)) * (180/pi)
test['gy_math_pitch'] = np.arctan(test['gy_y']/np.sqrt(test['gy_x'] ** 2 + test['gy_z'] ** 2)) * (180/pi)

print(train.shape)
train
# Out:
# (11250000, 21)
#              acc_x     acc_y     acc_z      gy_x       gy_y       gy_z  \
# 0         1.206087 -0.179371 -0.148447 -0.591608 -30.549010 -31.676112
# 1         1.287696 -0.198974 -0.182444  0.303100 -39.139103 -24.927216
# 2         1.304609 -0.195114 -0.253382 -3.617278 -44.122565 -25.019629
# 3         1.293095 -0.230366 -0.215210  2.712986 -53.597843 -27.454013
# 4         1.300887 -0.187757 -0.222523  4.286707 -57.906561 -27.961234
# ...            ...       ...       ...       ...        ...        ...
# 11249995 -0.584944 -0.655879  0.427890  6.081671  77.737712  55.006650
# 11249996 -0.616364 -0.660179  0.435595  8.814869  79.429573  55.866462
# 11249997 -0.618149 -0.684883  0.436353  7.457219  78.437228  54.712492
# 11249998 -0.632275 -0.691995  0.392237  5.109621  75.604057  54.834697
# 11249999 -0.672990 -0.658979  0.320705  1.809531  75.278959  53.267941
#
#              acc_t         gy_t   acc_mag       gy_mag  ...     gy_vec  \
# 0         1.767177   943.603223  1.508855  1936.968046  ...  44.010999
# 1         2.019429  1540.494535  1.731038  2153.327355  ...  46.403958
# 2         2.140496  1968.439749  1.804277  2585.867212  ...  50.851423
# 3         2.084285  2889.189647  1.771478  3633.811839  ...  60.281107
# 4         2.094771  3380.757973  1.777076  4153.376248  ...  64.446693
# ...            ...          ...       ...          ...  ...        ...
# 11249995  1.340172  6094.602162  0.955427  9105.870146  ...  95.424683
# 11249996  1.390371  6401.372914  1.005483  9507.820602  ...  97.508054
# 11249997  1.426470  6222.420839  1.041577  9201.465611  ...  95.924270
# 11249998  1.414466  5756.515091  1.032479  8748.925654  ...  93.535692
# 11249999  1.355699  5684.353297  0.990021  8507.669607  ...  92.237029
#
#           gy_gravity      roll     pitch  math_roll  math_pitch   gy_roll  \
# 0         -20.938910 -0.146550  1.380095 -79.073624   -8.396683 -0.767200
# 1         -21.254406 -0.151814  1.364146 -78.159835   -8.698302 -1.003661
# 2         -24.253157 -0.145773  1.330405 -76.226605   -8.352177 -1.050508
# 3         -26.112956 -0.173958  1.331665 -76.298763   -9.967037 -1.095444
# 4         -27.193696 -0.141316  1.350615 -77.384519   -8.096783 -1.116383
# ...              ...       ...       ...        ...         ...       ...
# 11249995   46.275344 -0.735562 -0.641544  36.757770  -42.144596  0.952125
# 11249996   48.036968 -0.718659 -0.661982  37.928762  -41.176144  0.952031
# 11249997   46.868980 -0.735658 -0.650627  37.278184  -42.150073  0.957403
# 11249998   45.182792 -0.749161 -0.671614  38.480650  -42.923737  0.941244
# 11249999   43.452144 -0.723873 -0.742828  42.560900  -41.474894  0.954711
#
#           gy_pitch  gy_math_roll  gy_math_pitch
# 0        -0.013443      0.770209     -43.957305
# 1         0.006532     -0.374246     -57.505519
# 2        -0.071194      4.079137     -60.189701
# 3         0.045021     -2.579501     -62.764338
# 4         0.066565     -3.813876     -63.964038
# ...            ...           ...            ...
# 11249995  0.063776     -3.654090      54.552763
# 11249996  0.090525     -5.186703      54.547336
# 11249997  0.077819     -4.458712      54.855164
# 11249998  0.054655     -3.131484      53.929291
# 11249999  0.019620     -1.124116      54.700916
#
# [11250000 rows x 21 columns]

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
train = scaler.fit_transform(train)
test.drop(['id', 'time'], axis=1, inplace=True)
test = scaler.transform(test)
train
# Out:
# array([[ 1.93489817,  0.03657354, -0.31330862, ...,  0.05924213,
#         -0.05924213, -0.71658616],
#        [ 2.01969699,  0.00673528, -0.37289479, ...,  0.07768724,
#         -0.07768724, -0.94204715],
#        [ 2.0372705 ,  0.01260973, -0.49722803, ...,  0.0059123 ,
#         -0.0059123 , -0.98671563],
#        ...,
#        [ 0.03938067, -0.73290797,  0.71166123, ...,  0.14351637,
#         -0.14351637,  0.92778977],
#        [ 0.0247026 , -0.74373387,  0.63434016, ...,  0.12212551,
#         -0.12212551,  0.91238197],
#        [-0.01760412, -0.69347699,  0.5089667 , ...,  0.08977286,
#         -0.08977286,  0.92522288]])

# %%
tr = pd.DataFrame(train)
te = pd.DataFrame(test)
la = pd.DataFrame(y_train_total)

tr.to_csv('last_train.csv', index=False)
te.to_csv('last_test.csv', index=False)
la.to_csv('last_label.csv', index=False)

# %%
import tensorflow as tf 
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Input
from keras.layers import TimeDistributed
from keras.layers import Activation, GlobalAveragePooling1D
from keras.layers import Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from keras.models import load_model
from keras.layers.merge import concatenate

# %%
len_features = train.shape[1] # feature 갯수
X = train.reshape(-1, 600, len_features)
X.shape
# Out:
# (18750, 600, 21)

# %%
y = to_categorical(y_train_total)
y.shape
# Out:
# (18750, 61)

# %%
epochs, batch_size = 100, 64 # Ram 24GB 기준 256 이상 reset될 가능성 높음

# %%
test_X = test.reshape(-1, 600, len_features)
test_X.shape
# Out:
# (782, 600, 21)

# %%
#epochs, batch_size = 30, 64
n_features, n_outputs = X.shape[2], y.shape[1]
# reshape data into time steps of sub-sequences
n_steps, n_length = 6, 100
X = X.reshape((X.shape[0], n_steps, n_length, n_features))
test_X = test_X.reshape((test_X.shape[0], n_steps, n_length, n_features))

# %%
class Models:
    # 각종 사이즈는 다양하게 적용하여 stacking 쌓아 올리기
    def define_model_0():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Conv1D(filters=16, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_1():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=6, activation='relu')))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_2():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_3():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.3))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_4():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

# %%
class Models:
    # 각종 사이즈는 다양하게 적용하여 stacking 쌓아 올리기
    def define_model_0():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_1():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_2():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=6, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_3():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=6, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.3))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

    def define_model_4():
        model = Sequential()
        model.add(TimeDistributed(Conv1D(filters=32, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_features)))
        model.add(TimeDistributed(Dropout(0.5)))
        model.add(TimeDistributed(GlobalAveragePooling1D()))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(32))
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(n_outputs, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model

# %%
# 위의 모델들 학습하면서 stacking
for i in range(5):
    model = getattr(Models, f'define_model_{i}')()
    checkpoint_path = "checkpoint/cp.ckpt"
    
    cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', 
                                verbose=1, save_weights_only=True, 
                                save_best_only=True, mode='min')
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min', verbose=1)
    
    model.fit(X, y, epochs=epochs, batch_size=batch_size, 
            validation_split=0.2, callbacks=[early_stopping, cp_callback])
    model.save(f'models/211008(3)_model_{i}.h5')
    tf.keras.backend.clear_session()
# Out:
# Epoch 1/100
# 235/235 [==============================] - 38s 125ms/step - loss: 2.5855 - accuracy: 0.4866 - val_loss: 2.0794 - val_accuracy: 0.5360
#
# Epoch 00001: val_loss improved from inf to 2.07944, saving model to checkpoint\cp.ckpt
# Epoch 2/100
# 235/235 [==============================] - 27s 114ms/step - loss: 1.9268 - accuracy: 0.5351 - val_loss: 1.6558 - val_accuracy: 0.5595
#
# Epoch 00002: val_loss improved from 2.07944 to 1.65583, saving model to checkpoint\cp.ckpt
# Epoch 3/100
# 235/235 [==============================] - 26s 109ms/step - loss: 1.6865 - accuracy: 0.5642 - val_loss: 1.4237 - val_accuracy: 0.6131
#
# Epoch 00003: val_loss improved from 1.65583 to 1.42366, saving model to checkpoint\cp.ckpt
# Epoch 4/100
# 235/235 [==============================] - 27s 115ms/step - loss: 1.5126 - accuracy: 0.5945 - val_loss: 1.2555 - val_accuracy: 0.6549
#
# Epoch 00004: val_loss improved from 1.42366 to 1.25552, saving model to checkpoint\cp.ckpt
# Epoch 5/100
# 235/235 [==============================] - 26s 111ms/step - loss: 1.4147 - accuracy: 0.6124 - val_loss: 1.1491 - val_accuracy: 0.6733
#
# Epoch 00005: val_loss improved from 1.25552 to 1.14911, saving model to checkpoint\cp.ckpt
# Epoch 6/100
# 235/235 [==============================] - 26s 111ms/step - loss: 1.3330 - accuracy: 0.6266 - val_loss: 1.0645 - val_accuracy: 0.6947
#
# Epoch 00006: val_loss improved from 1.14911 to 1.06449, saving model to checkpoint\cp.ckpt
# Epoch 7/100
# 235/235 [==============================] - 26s 111ms/step - loss: 1.2659 - accuracy: 0.6368 - val_loss: 1.0107 - val_accuracy: 0.6984
#
# Epoch 00007: val_loss improved from 1.06449 to 1.01070, saving model to checkpoint\cp.ckpt
# Epoch 8/100
# 235/235 [==============================] - 26s 111ms/step - loss: 1.2171 - accuracy: 0.6521 - val_loss: 0.9882 - val_accuracy: 0.7056
#
# Epoch 00008: val_loss improved from 1.01070 to 0.98824, saving model to checkpoint\cp.ckpt
# Epoch 9/100
# 235/235 [==============================] - 26s 112ms/step - loss: 1.1680 - accuracy: 0.6591 - val_loss: 0.9237 - val_accuracy: 0.7189
#
# Epoch 00009: val_loss improved from 0.98824 to 0.92366, saving model to checkpoint\cp.ckpt
# Epoch 10/100
# 235/235 [==============================] - 26s 111ms/step - loss: 1.1337 - accuracy: 0.6701 - val_loss: 0.8766 - val_accuracy: 0.7328
#
# Epoch 00010: val_loss improved from 0.92366 to 0.87658, saving model to checkpoint\cp.ckpt
# Epoch 11/100
# 235/235 [==============================] - 26s 112ms/step - loss: 1.1012 - accuracy: 0.6752 - val_loss: 0.8550 - val_accuracy: 0.7389
#
# Epoch 00011: val_loss improved from 0.87658 to 0.85500, saving model to checkpoint\cp.ckpt
# Epoch 12/100
# 235/235 [==============================] - 26s 110ms/step - loss: 1.0730 - accuracy: 0.6827 - val_loss: 0.8610 - val_accuracy: 0.7424
#
# Epoch 00012: val_loss did not improve from 0.85500
# Epoch 13/100
# 235/235 [==============================] - 27s 114ms/step - loss: 1.0474 - accuracy: 0.6855 - val_loss: 0.7900 - val_accuracy: 0.7563
#
# Epoch 00013: val_loss improved from 0.85500 to 0.79004, saving model to checkpoint\cp.ckpt
# Epoch 14/100
# 235/235 [==============================] - 25s 107ms/step - loss: 1.0096 - accuracy: 0.6969 - val_loss: 0.7462 - val_accuracy: 0.7661
#
# Epoch 00014: val_loss improved from 0.79004 to 0.74620, saving model to checkpoint\cp.ckpt
# Epoch 15/100
# 235/235 [==============================] - 25s 106ms/step - loss: 0.9873 - accuracy: 0.7024 - val_loss: 0.7661 - val_accuracy: 0.7619
#
# Epoch 00015: val_loss did not improve from 0.74620
# Epoch 16/100
# 235/235 [==============================] - 25s 107ms/step - loss: 0.9604 - accuracy: 0.7091 - val_loss: 0.7214 - val_accuracy: 0.7773
#
# Epoch 00016: val_loss improved from 0.74620 to 0.72135, saving model to checkpoint\cp.ckpt
# Epoch 17/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.9358 - accuracy: 0.7119 - val_loss: 0.7021 - val_accuracy: 0.7725
#
# Epoch 00017: val_loss improved from 0.72135 to 0.70207, saving model to checkpoint\cp.ckpt
# Epoch 18/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.9133 - accuracy: 0.7165 - val_loss: 0.6779 - val_accuracy: 0.7787
#
# Epoch 00018: val_loss improved from 0.70207 to 0.67789, saving model to checkpoint\cp.ckpt
# Epoch 19/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.9056 - accuracy: 0.7250 - val_loss: 0.6673 - val_accuracy: 0.7859
#
# Epoch 00019: val_loss improved from 0.67789 to 0.66726, saving model to checkpoint\cp.ckpt
# Epoch 20/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.8689 - accuracy: 0.7321 - val_loss: 0.6562 - val_accuracy: 0.7864
#
# Epoch 00020: val_loss improved from 0.66726 to 0.65619, saving model to checkpoint\cp.ckpt
# Epoch 21/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.8661 - accuracy: 0.7327 - val_loss: 0.6430 - val_accuracy: 0.7989
#
# Epoch 00021: val_loss improved from 0.65619 to 0.64297, saving model to checkpoint\cp.ckpt
# Epoch 22/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.8541 - accuracy: 0.7319 - val_loss: 0.6214 - val_accuracy: 0.7933
#
# Epoch 00022: val_loss improved from 0.64297 to 0.62144, saving model to checkpoint\cp.ckpt
# Epoch 23/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.8385 - accuracy: 0.7370 - val_loss: 0.6134 - val_accuracy: 0.8053
#
# Epoch 00023: val_loss improved from 0.62144 to 0.61343, saving model to checkpoint\cp.ckpt
# Epoch 24/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.8119 - accuracy: 0.7483 - val_loss: 0.6081 - val_accuracy: 0.8056
#
# Epoch 00024: val_loss improved from 0.61343 to 0.60810, saving model to checkpoint\cp.ckpt
# Epoch 25/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.8070 - accuracy: 0.7484 - val_loss: 0.5834 - val_accuracy: 0.8080
#
# Epoch 00025: val_loss improved from 0.60810 to 0.58340, saving model to checkpoint\cp.ckpt
# Epoch 26/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.7907 - accuracy: 0.7547 - val_loss: 0.5611 - val_accuracy: 0.8133
#
# Epoch 00026: val_loss improved from 0.58340 to 0.56115, saving model to checkpoint\cp.ckpt
# Epoch 27/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.7659 - accuracy: 0.7614 - val_loss: 0.5776 - val_accuracy: 0.8053
#
# Epoch 00027: val_loss did not improve from 0.56115
# Epoch 28/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.7640 - accuracy: 0.7612 - val_loss: 0.5480 - val_accuracy: 0.8187
#
# Epoch 00028: val_loss improved from 0.56115 to 0.54803, saving model to checkpoint\cp.ckpt
# Epoch 29/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.7567 - accuracy: 0.7602 - val_loss: 0.5505 - val_accuracy: 0.8147
#
# Epoch 00029: val_loss did not improve from 0.54803
# Epoch 30/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.7459 - accuracy: 0.7639 - val_loss: 0.5576 - val_accuracy: 0.8115
#
# Epoch 00030: val_loss did not improve from 0.54803
# Epoch 31/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.7380 - accuracy: 0.7674 - val_loss: 0.5222 - val_accuracy: 0.8261
#
# Epoch 00031: val_loss improved from 0.54803 to 0.52217, saving model to checkpoint\cp.ckpt
# Epoch 32/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.7294 - accuracy: 0.7715 - val_loss: 0.5233 - val_accuracy: 0.8283
#
# Epoch 00032: val_loss did not improve from 0.52217
# Epoch 33/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.7172 - accuracy: 0.7722 - val_loss: 0.5121 - val_accuracy: 0.8304
#
# Epoch 00033: val_loss improved from 0.52217 to 0.51211, saving model to checkpoint\cp.ckpt
# Epoch 34/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.7070 - accuracy: 0.7765 - val_loss: 0.5169 - val_accuracy: 0.8179
#
# Epoch 00034: val_loss did not improve from 0.51211
# Epoch 35/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6948 - accuracy: 0.7788 - val_loss: 0.4957 - val_accuracy: 0.8285
#
# Epoch 00035: val_loss improved from 0.51211 to 0.49572, saving model to checkpoint\cp.ckpt
# Epoch 36/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6833 - accuracy: 0.7789 - val_loss: 0.4862 - val_accuracy: 0.8357
# Epoch 00036: val_loss improved from 0.49572 to 0.48623, saving model to checkpoint\cp.ckpt
# Epoch 37/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.6812 - accuracy: 0.7815 - val_loss: 0.4801 - val_accuracy: 0.8299
#
# Epoch 00037: val_loss improved from 0.48623 to 0.48006, saving model to checkpoint\cp.ckpt
# Epoch 38/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.6809 - accuracy: 0.7793 - val_loss: 0.4959 - val_accuracy: 0.8331
#
# Epoch 00038: val_loss did not improve from 0.48006
# Epoch 39/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6710 - accuracy: 0.7836 - val_loss: 0.4995 - val_accuracy: 0.8283
#
# Epoch 00039: val_loss did not improve from 0.48006
# Epoch 40/100
# 235/235 [==============================] - 25s 109ms/step - loss: 0.6558 - accuracy: 0.7886 - val_loss: 0.4608 - val_accuracy: 0.8448
#
# Epoch 00040: val_loss improved from 0.48006 to 0.46079, saving model to checkpoint\cp.ckpt
# Epoch 41/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6696 - accuracy: 0.7874 - val_loss: 0.4514 - val_accuracy: 0.8421
#
# Epoch 00041: val_loss improved from 0.46079 to 0.45144, saving model to checkpoint\cp.ckpt
# Epoch 42/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.6449 - accuracy: 0.7909 - val_loss: 0.4624 - val_accuracy: 0.8405
#
# Epoch 00042: val_loss did not improve from 0.45144
# Epoch 43/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6359 - accuracy: 0.7953 - val_loss: 0.4468 - val_accuracy: 0.8451
#
# Epoch 00043: val_loss improved from 0.45144 to 0.44684, saving model to checkpoint\cp.ckpt
# Epoch 44/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6381 - accuracy: 0.7926 - val_loss: 0.4486 - val_accuracy: 0.8472
#
# Epoch 00044: val_loss did not improve from 0.44684
# Epoch 45/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.6245 - accuracy: 0.7985 - val_loss: 0.4405 - val_accuracy: 0.8523
#
# Epoch 00045: val_loss improved from 0.44684 to 0.44053, saving model to checkpoint\cp.ckpt
# Epoch 46/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.6206 - accuracy: 0.7967 - val_loss: 0.4886 - val_accuracy: 0.8304
#
# Epoch 00046: val_loss did not improve from 0.44053
# Epoch 47/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6202 - accuracy: 0.7999 - val_loss: 0.4382 - val_accuracy: 0.8472
#
# Epoch 00047: val_loss improved from 0.44053 to 0.43816, saving model to checkpoint\cp.ckpt
# Epoch 48/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.6177 - accuracy: 0.8011 - val_loss: 0.4329 - val_accuracy: 0.8493
#
# Epoch 00048: val_loss improved from 0.43816 to 0.43288, saving model to checkpoint\cp.ckpt
# Epoch 49/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.6032 - accuracy: 0.8045 - val_loss: 0.4217 - val_accuracy: 0.8509
#
# Epoch 00049: val_loss improved from 0.43288 to 0.42172, saving model to checkpoint\cp.ckpt
# Epoch 50/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.5916 - accuracy: 0.8065 - val_loss: 0.4008 - val_accuracy: 0.8597
#
# Epoch 00050: val_loss improved from 0.42172 to 0.40081, saving model to checkpoint\cp.ckpt
# Epoch 51/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.5972 - accuracy: 0.8063 - val_loss: 0.4428 - val_accuracy: 0.8459
#
# Epoch 00051: val_loss did not improve from 0.40081
# Epoch 52/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.5892 - accuracy: 0.8091 - val_loss: 0.4087 - val_accuracy: 0.8597
#
# Epoch 00052: val_loss did not improve from 0.40081
# Epoch 53/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.5797 - accuracy: 0.8117 - val_loss: 0.3939 - val_accuracy: 0.8571
#
# Epoch 00053: val_loss improved from 0.40081 to 0.39385, saving model to checkpoint\cp.ckpt
# Epoch 54/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.5778 - accuracy: 0.8150 - val_loss: 0.4096 - val_accuracy: 0.8573
#
# Epoch 00054: val_loss did not improve from 0.39385
# Epoch 55/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.5823 - accuracy: 0.8088 - val_loss: 0.3978 - val_accuracy: 0.8603
#
# Epoch 00055: val_loss did not improve from 0.39385
# Epoch 56/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.5677 - accuracy: 0.8163 - val_loss: 0.3923 - val_accuracy: 0.8600
#
# Epoch 00056: val_loss improved from 0.39385 to 0.39230, saving model to checkpoint\cp.ckpt
# Epoch 57/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.5701 - accuracy: 0.8117 - val_loss: 0.4124 - val_accuracy: 0.8584
#
# Epoch 00057: val_loss did not improve from 0.39230
# Epoch 58/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.5660 - accuracy: 0.8157 - val_loss: 0.4030 - val_accuracy: 0.8592
#
# Epoch 00058: val_loss did not improve from 0.39230
# Epoch 59/100
# 235/235 [==============================] - 27s 116ms/step - loss: 0.5510 - accuracy: 0.8164 - val_loss: 0.3987 - val_accuracy: 0.8643
#
# Epoch 00059: val_loss did not improve from 0.39230
# Epoch 60/100
# 235/235 [==============================] - 27s 116ms/step - loss: 0.5430 - accuracy: 0.8226 - val_loss: 0.3804 - val_accuracy: 0.8621
#
# Epoch 00060: val_loss improved from 0.39230 to 0.38040, saving model to checkpoint\cp.ckpt
# Epoch 61/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.5693 - accuracy: 0.8167 - val_loss: 0.4302 - val_accuracy: 0.8477
#
# Epoch 00061: val_loss did not improve from 0.38040
# Epoch 62/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.5441 - accuracy: 0.8216 - val_loss: 0.3787 - val_accuracy: 0.8645
#
# Epoch 00062: val_loss improved from 0.38040 to 0.37872, saving model to checkpoint\cp.ckpt
# Epoch 63/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.5407 - accuracy: 0.8203 - val_loss: 0.3757 - val_accuracy: 0.8680
#
# Epoch 00063: val_loss improved from 0.37872 to 0.37575, saving model to checkpoint\cp.ckpt
# Epoch 64/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.5256 - accuracy: 0.8263 - val_loss: 0.3658 - val_accuracy: 0.8704
#
# Epoch 00064: val_loss improved from 0.37575 to 0.36579, saving model to checkpoint\cp.ckpt
# Epoch 65/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.5228 - accuracy: 0.8293 - val_loss: 0.3577 - val_accuracy: 0.8725
#
# Epoch 00065: val_loss improved from 0.36579 to 0.35771, saving model to checkpoint\cp.ckpt
# Epoch 66/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.5372 - accuracy: 0.8241 - val_loss: 0.3779 - val_accuracy: 0.8709
#
# Epoch 00066: val_loss did not improve from 0.35771
# Epoch 67/100
# 235/235 [==============================] - 25s 108ms/step - loss: 0.5358 - accuracy: 0.8244 - val_loss: 0.3786 - val_accuracy: 0.8656
#
# Epoch 00067: val_loss did not improve from 0.35771
# Epoch 68/100
# 235/235 [==============================] - 26s 113ms/step - loss: 0.5213 - accuracy: 0.8271 - val_loss: 0.3683 - val_accuracy: 0.8707
#
# Epoch 00068: val_loss did not improve from 0.35771
# Epoch 69/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.5137 - accuracy: 0.8315 - val_loss: 0.3606 - val_accuracy: 0.8768
#
# Epoch 00069: val_loss did not improve from 0.35771
# Epoch 70/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.5189 - accuracy: 0.8301 - val_loss: 0.3456 - val_accuracy: 0.8851
#
# Epoch 00070: val_loss improved from 0.35771 to 0.34560, saving model to checkpoint\cp.ckpt
# Epoch 71/100
# 235/235 [==============================] - 25s 108ms/step - loss: 0.5247 - accuracy: 0.8280 - val_loss: 0.3552 - val_accuracy: 0.8715
#
# Epoch 00071: val_loss did not improve from 0.34560
# Epoch 72/100
# 235/235 [==============================] - 26s 110ms/step - loss: 0.5048 - accuracy: 0.8367 - val_loss: 0.3408 - val_accuracy: 0.8811
#
# Epoch 00072: val_loss improved from 0.34560 to 0.34076, saving model to checkpoint\cp.ckpt
# Epoch 73/100
# 235/235 [==============================] - 26s 109ms/step - loss: 0.5060 - accuracy: 0.8321 - val_loss: 0.3661 - val_accuracy: 0.8760
#
# Epoch 00073: val_loss did not improve from 0.34076
# Epoch 74/100
# 235/235 [==============================] - 24s 101ms/step - loss: 0.5158 - accuracy: 0.8327 - val_loss: 0.3536 - val_accuracy: 0.8757
#
# Epoch 00074: val_loss did not improve from 0.34076
# Epoch 75/100
# 235/235 [==============================] - 20s 86ms/step - loss: 0.4990 - accuracy: 0.8336 - val_loss: 0.3410 - val_accuracy: 0.8792
#
# Epoch 00075: val_loss did not improve from 0.34076
# Epoch 76/100
# 235/235 [==============================] - 23s 99ms/step - loss: 0.5001 - accuracy: 0.8326 - val_loss: 0.3547 - val_accuracy: 0.8763
#
# Epoch 00076: val_loss did not improve from 0.34076
# Epoch 77/100
# 235/235 [==============================] - 25s 106ms/step - loss: 0.4820 - accuracy: 0.8387 - val_loss: 0.3644 - val_accuracy: 0.8792
#
# Epoch 00077: val_loss did not improve from 0.34076
# Epoch 00077: early stopping
# Epoch 1/100
# 235/235 [==============================] - 65s 247ms/step - loss: 2.5731 - accuracy: 0.4839 - val_loss: 1.9655 - val_accuracy: 0.5280
#
# Epoch 00001: val_loss improved from inf to 1.96552, saving model to checkpoint\cp.ckpt
# Epoch 2/100
# 235/235 [==============================] - 53s 226ms/step - loss: 1.8675 - accuracy: 0.5436 - val_loss: 1.5670 - val_accuracy: 0.5936
#
# Epoch 00002: val_loss improved from 1.96552 to 1.56703, saving model to checkpoint\cp.ckpt
# Epoch 3/100
# 235/235 [==============================] - 53s 227ms/step - loss: 1.5914 - accuracy: 0.5791 - val_loss: 1.3094 - val_accuracy: 0.6352
#
# Epoch 00003: val_loss improved from 1.56703 to 1.30939, saving model to checkpoint\cp.ckpt
# Epoch 4/100
# 235/235 [==============================] - 56s 239ms/step - loss: 1.4242 - accuracy: 0.6077 - val_loss: 1.1607 - val_accuracy: 0.6683
#
# Epoch 00004: val_loss improved from 1.30939 to 1.16068, saving model to checkpoint\cp.ckpt
# Epoch 5/100
# 235/235 [==============================] - 54s 231ms/step - loss: 1.3074 - accuracy: 0.6285 - val_loss: 1.0549 - val_accuracy: 0.6765
#
# Epoch 00005: val_loss improved from 1.16068 to 1.05491, saving model to checkpoint\cp.ckpt
# Epoch 6/100
# 235/235 [==============================] - 55s 233ms/step - loss: 1.2332 - accuracy: 0.6408 - val_loss: 0.9914 - val_accuracy: 0.6941
#
# Epoch 00006: val_loss improved from 1.05491 to 0.99140, saving model to checkpoint\cp.ckpt
# Epoch 7/100
# 110/235 [=============>................] - ETA: 27s - loss: 1.1613 - accuracy: 0.6548

# %%
# 저장한 모델 불러오기
for i in range(5): # 모델 갯수
    globals()[f'model{i}'] = load_model(f'models/211008(2)_model_{i}.h5')

# %%
model0._name = 'Client0'
model1._name = 'Client1'
model2._name = 'Client2'
model3._name = 'Client3'
model4._name = 'Client4'

# %%
inputs = Input(shape=(n_steps, n_length, n_features))

merge = concatenate([model0(inputs), model1(inputs), model2(inputs), model4(inputs)])
hidden = Dense(10, activation='relu')(merge)
output = Dense(61, activation='softmax')(hidden)
model = tf.keras.models.Model(inputs=inputs, outputs=output)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

stfold = StratifiedKFold(n_splits=3, shuffle=True)
idx_iter = 0 
skf_accuracy=[]

for train_idx, valid_idx in stfold.split(X, y_train_total) : 
    Y_train, Y_valid = tf.gather(y, train_idx), tf.gather(y, valid_idx)
    X_train, X_valid = tf.gather(X, train_idx), tf.gather(X, valid_idx)

    checkpoint_path = "checkpoint/cp2.ckpt"
    cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

    early_stopping = EarlyStopping(monitor='loss', patience=4, mode='min')
    model.fit(X_train, Y_train, epochs=30, batch_size=batch_size, callbacks=[early_stopping, cp_callback])
    pred = model.predict(X_valid)

    # 반복 시 마다 정확도 측정 -> 수정해야함; 
    idx_iter += 1 
    y_pred = (pred > 0.5) 
    accuracy = np.round(accuracy_score(Y_valid, y_pred), 4)
    train_size = X_train.shape[0]
    test_size = X_valid.shape[0]

    print("\n##### 교차 검증: {}, 정확도: {}  #####" .format(idx_iter, accuracy))
    print('학습 레이블 데이터 분포:\n ', Y_train.shape[0])
    print('검증 레이블 데이터 분포:\n ', Y_valid.shape[0], '\n\n')
# Out:
# Epoch 1/30
# 196/196 [==============================] - 73s 370ms/step - loss: 0.4330 - accuracy: 0.8730
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 2/30
# 196/196 [==============================] - 74s 375ms/step - loss: 0.3912 - accuracy: 0.8861
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 3/30
# 196/196 [==============================] - 77s 391ms/step - loss: 0.3765 - accuracy: 0.8870
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 4/30
#  46/196 [======>.......................] - ETA: 1:01 - loss: 0.3249 - accuracy: 0.9035
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-6b26a8289dcb> in <module>
#      14
#      15     early_stopping = EarlyStopping(monitor='loss', patience=4, mode='min')
# ---> 16     model.fit(X_train, Y_train, epochs=30, batch_size=batch_size, callbacks=[early_stopping, cp_callback])
#      17     pred = model.predict(X_valid)
#      18
#
# c:\users\jy\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# c:\users\jy\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\users\jy\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# c:\users\jy\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# c:\users\jy\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# c:\users\jy\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# c:\users\jy\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
prediction = model.predict(test_X)
prediction.shape

# %%
submission

# %%
submission.iloc[:,1:]=prediction

# %%
submission.to_csv('cnn_LSTM_stacked5_fold3(jy_last(2)).csv', index=False)

# %%
submission

# %%
sub = pd.read_csv('test_c_l.csv')

# %%
def result_pred(sub1, sub2) :
    subpre1 = []
    subpre2 = []
    corcount = 0
    
    for i in range(len(sub1)) :
        subpre1.append(sub1.iloc[i,1:].idxmax())
        subpre2.append(sub2.iloc[i,1:].idxmax())

    subpre1 = pd.DataFrame(subpre1, columns = ['label'])
    subpre1.head()
    
    subpre2 = pd.DataFrame(subpre2, columns = ['label'])
    subpre2.head()
    
    print("파일 1 운동중 라벨 수 :", len(subpre1[subpre1['label'] != '26']), "\n파일 2 운동중 라벨 수 :", len(subpre2[subpre2['label'] != '26']))
    for i in range(len(subpre1)) :
        if (subpre1['label'][i] == subpre2['label'][i]) : 
            corcount += 1
    print("예측 결과 일치 개수 :", corcount)
    
    return subpre1

# %%
sub1 = pd.read_csv('cnn_LSTM_last(jun).csv')
sub2 = pd.read_csv('cnn_LSTM_stacked5_fold3(jy_epoch10_batch256).csv')

subpre1 = result_pred(sub1, sub2)
subpre1

# %%
y ==

# %%
subpre1.to_csv('subpre1.csv')

# %%
sub1 = pd.read_csv('cnn_LSTM_stacked(jun).csv')
sub2 = pd.read_csv('cnn_LSTM_stacked5_fold3(jy_last).csv')

subpre1 = result_pred(sub1, sub2)
subpre1.head(15)

# %%
sub1 = pd.read_csv(path+'baseline_aug_1.csv')
subpre3 = []

for i in range(len(sub1)) :
    subpre3.append(sub1.iloc[i,1:].idxmax())

subpre3 = pd.DataFrame(subpre3, columns = ['label'])
subpre3.head()

# %%
len(subpre3[subpre3['label'] != '26']) # 1.8747789247

# %%
sub1 = pd.read_csv(path+'baseline_aug(npTodf).csv')
subpre3 = []

for i in range(len(sub1)) :
    subpre3.append(sub1.iloc[i,1:].idxmax())

subpre3 = pd.DataFrame(subpre3, columns = ['label'])

len(subpre3[subpre3['label'] != '26']) # 168

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

stfold = StratifiedKFold(n_splits=3, shuffle=True)
idx_iter = 0 
skf_accuracy=[]
epochs = 10
batch_size = 256

for train_idx, valid_idx in stfold.split(X, y_train_total) : 
    Y_train, Y_valid = tf.gather(y, train_idx), tf.gather(y, valid_idx)
    X_train, X_valid = tf.gather(X, train_idx), tf.gather(X, valid_idx)

    checkpoint_path = "checkpoint/cp.ckpt"
    cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

    early_stopping = EarlyStopping(monitor='loss', patience=5, mode='min')
    model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, validation_split=0.02, callbacks=[early_stopping, cp_callback])
    pred = model.predict(X_valid)

    # 반복 시 마다 정확도 측정 -> 수정해야함; 
    idx_iter += 1 
    y_pred = (pred > 0.5) 
    accuracy = np.round(accuracy_score(Y_valid, y_pred), 4)
    train_size = X_train.shape[0]
    test_size = X_valid.shape[0]

    print("\n##### 교차 검증: {}, 정확도: {}  #####" .format(idx_iter, accuracy))
    print('학습 레이블 데이터 분포:\n ', Y_train.shape[0])
    print('검증 레이블 데이터 분포:\n ', Y_valid.shape[0], '\n\n')
